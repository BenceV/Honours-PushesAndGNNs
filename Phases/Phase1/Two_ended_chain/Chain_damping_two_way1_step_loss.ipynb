# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
# %matplotlib notebook
import time
import datetime

#Save experiment begin date
current_time = datetime.datetime.now()
print("Current_date: "+str(current_time))
current_time = "".join(current_time.strftime("%x").split('/'))

#Import usual things required for graph nets
import numpy as np
import pandas as pd
import networkx as nx
import sonnet as snt
import tensorflow as tf
import os
import sys
from matplotlib import pyplot as plt
from matplotlib import animation
import seaborn as sns

#Import graph nets
from graph_nets import blocks
from graph_nets import utils_tf
from graph_nets import utils_np
from graph_nets.demos import models

#Change here
num_training_iterations = 100000
batch_size_tr = 256
batch_size_ge = 100
num_time_steps = 50

desc = "ntr="+str(num_training_iterations)
desc = desc +"_btr="+str(batch_size_tr)
desc = desc +"_bge="+str(batch_size_ge)
desc = desc +"_date="+str(current_time)
desc = desc +"_stepError_"

#Set seed
SEED = 5
desc = desc +"seed="+str(SEED)

#Path to the scripts shared troughout phases
parent_path=os.path.abspath('..')
path_common =  '/'.join(parent_path.split('/')[:-1])
path_common = os.path.join(path_common,'Common','Scripts')
#Check if path exists
if(not os.path.exists(path_common)):
    print('The path: '+ os.path.exists(path_common)+' is not found!')
#Add shared scripts to our current paths for importing
sys.path.insert(0, path_common)

base = os.path.join(parent_path,'Two_ended_chain','damping','two_way','step_error')
if(not os.path.exists(base)):
    os.makedirs(base)
#Path to saved models and trajectories
path_saves = os.path.join(base,desc,'Saves')
if(not os.path.exists(path_saves)):
    os.makedirs(path_saves)
#Path to plots
path_plots = os.path.join(base,desc,'Plots')
if(not os.path.exists(path_plots)):
    os.makedirs(path_plots)
#Path to animations
path_animations = os.path.join(base,desc,'Animations')
if(not os.path.exists(path_animations)):
    os.makedirs(path_animations)



np.random.seed(SEED)
tf.set_random_seed(SEED)
# Out:
# Current_date: 2020-02-15 18:42:23.963441
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## Import functions

# %%
#Import functions for simulating
from Simulation_Functions_extended import SpringMassSimulator, generate_trajectory, roll_out_physics
#Import functions for creating graph
from Graph_creator_functions import chain_graph_extended_two_way
#Import visualisation functions

# %% [markdown]
# ## Define loss functions

# %%
def create_loss_ops(target_op, output_ops):
    """Create supervised loss operations from targets and outputs.

    Args:
        target_op: The target velocity tf.Tensor.
        output_ops: The list of output graphs from the model.

    Returns:
        A list of loss values (tf.Tensor), one per output op.""" 
    loss_ops = [
            tf.reduce_mean(
            tf.reduce_sum((tf.cast(output_op.nodes,tf.float64) - tf.cast(target_op[..., 2:4],tf.float64))**2, axis=-1))
            for output_op in output_ops
    ]
    return loss_ops


def make_all_runnable_in_session(*args):
    """Apply make_runnable_in_session to an iterable of graphs."""
    return [utils_tf.make_runnable_in_session(a) for a in args]

# %% [markdown]
# # Define the Model

# %%
tf.reset_default_graph()
# Create the model.
model = models.EncodeProcessDecode(node_output_size=2)
# Out:
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/base.py:177: The name tf.make_template is deprecated. Please use tf.compat.v1.make_template instead.
#
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/base.py:278: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/base.py:579: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.

# %% [markdown]
# # Training the Network: Chain
# ## Generate:
# - Model
# - Training trajectory 5 to 9 masses
# - Generalization trajectories: 4 mass, 7 mass and 11 mass

# %%
#@title Set up model training and evaluation  { form-width: "30%" }

# The model we explore includes three components:
# - An "Encoder" graph net, which independently encodes the edge, node, and
#   global attributes (does not compute relations etc.).
# - A "Core" graph net, which performs N rounds of processing (message-passing)
#   steps. The input to the Core is the concatenation of the Encoder's output
#   and the previous output of the Core (labeled "Hidden(t)" below, where "t" is
#   the processing step).
# - A "Decoder" graph net, which independently decodes the edge, node, and
#   global attributes (does not compute relations etc.), on each
#   message-passing step.
#
#                     Hidden(t)   Hidden(t+1)
#                        |            ^
#           *---------*  |  *------*  |  *---------*
#           |         |  |  |      |  |  |         |
# Input --->| Encoder |  *->| Core |--*->| Decoder |---> Output(t)
#           |         |---->|      |     |         |
#           *---------*     *------*     *---------*
#
# The model is trained by supervised learning. Input mass-spring systems are
# procedurally generated, where the nodes represent the positions, velocities,
# and indicators of whether the mass is fixed in space or free to move, the
# edges represent the spring constant and spring rest length, and the global
# attribute represents the variable coefficient of gravitational acceleration.
# The outputs/targets have the same structure, with the nodes representing the
# masses' next-step states.
#
# The training loss is computed on the output of each processing step. The
# reason for this is to encourage the model to try to solve the problem in as
# few steps as possible. It also helps make the output of intermediate steps
# more interpretable.
#
# There's no need for a separate evaluate dataset because the inputs are
# never repeated, so the training loss is the measure of performance on graphs
# from the input distribution.
#
# We also evaluate how well the models generalize to systems which are one mass
# larger, and smaller, than those from the training distribution. The loss is
# computed as the mean over a 50-step rollout, where each step's input is the
# the previous step's output.
#
# Variables with the suffix _tr are training parameters, and variables with the
# suffix _ge are test/generalization parameters.
#
# After around 10000-20000 training iterations the model reaches good
# performance on mass-spring systems with 5-8 masses.


rand = np.random.RandomState(SEED)

# Model parameters.
num_processing_steps_tr = 1
num_processing_steps_ge = 1

step_size = 0.1
num_masses_min_max_tr = (5, 9)
dist_between_masses_min_max_tr = (0.2, 1.0)
spring_constant_min_max_tr = (40,60)
damping_ratio_min_max_tr = (0.3,0.6)

# Data.
# Base graphs for training.
num_masses_tr = rand.randint(*num_masses_min_max_tr, size=batch_size_tr)
dist_between_masses_tr = rand.uniform(*dist_between_masses_min_max_tr, size=batch_size_tr)
spring_constants_tr = rand.randint(*spring_constant_min_max_tr, size=batch_size_tr)
damping_ratios_tr = rand.uniform(*damping_ratio_min_max_tr, size=batch_size_tr)


static_graph_tr = [chain_graph_extended_two_way(n,k,d,r) for n, d, k, r in zip(num_masses_tr,
                                                                               dist_between_masses_tr,
                                                                               spring_constants_tr,
                                                                               damping_ratios_tr)]
base_graph_tr = utils_tf.data_dicts_to_graphs_tuple(static_graph_tr)

# Base graphs for testing.
spring_constant_min_max_ge = (25,75)
damping_ratio_min_max_ge = (0.0,0.3)

spring_constants_ge = rand.randint(*spring_constant_min_max_ge, size=batch_size_ge)
damping_ratios_ge = rand.uniform(*damping_ratio_min_max_ge, size=batch_size_ge)


# 4 masses 1m apart in a chain like structure.
static_graph_4_ge = [chain_graph_extended_two_way(4, k ,0.5,r) for k, r in zip(spring_constants_ge,
                                                                               damping_ratios_ge)]
base_graph_4_ge = utils_tf.data_dicts_to_graphs_tuple(static_graph_4_ge)
    
# 7 masses 0.5m apart in a chain like structure.
static_graph_7_ge = [chain_graph_extended_two_way(7, k ,0.5,r) for k, r in zip(spring_constants_ge,
                                                                               damping_ratios_ge)]
base_graph_7_ge = utils_tf.data_dicts_to_graphs_tuple(static_graph_7_ge)

# 11 masses 0.5m apart in a chain like structure.
static_graph_11_ge = [chain_graph_extended_two_way(11, k ,0.5,r) for k, r in zip(spring_constants_ge,
                                                                               damping_ratios_ge)]
base_graph_11_ge = utils_tf.data_dicts_to_graphs_tuple(static_graph_11_ge)



# True physics simulator for data generation.
simulator = SpringMassSimulator(step_size=step_size)
# Training.
# Generate a training trajectory by adding noise to initial
# position, spring constants and gravity
initial_conditions_tr, true_trajectory_tr = generate_trajectory(
    simulator,
    base_graph_tr,
    num_time_steps,
    step_size,
    node_noise_level=0.04,
    edge_noise_level=5.0,
    global_noise_level=1.0,
    do_set_rest=True,
    do_apply_gravity=True)
# Random start step.
t = tf.random_uniform([], minval=0, maxval=num_time_steps - 1, dtype=tf.int32)
input_graph_tr = initial_conditions_tr.replace(nodes=true_trajectory_tr[t])
target_nodes_tr = true_trajectory_tr[t + 1]

output_ops_tr = model(input_graph_tr, num_processing_steps_tr)

# Test data: 4-mass string.
initial_conditions_4_ge, true_trajectory_4_ge = generate_trajectory(
    simulator,
    base_graph_4_ge,
    num_time_steps,
    step_size,
    node_noise_level=0.04,
    edge_noise_level=5.0,
    global_noise_level=1.0,
    do_set_rest=True,
    do_apply_gravity=True)

input_graph_4_ge = initial_conditions_4_ge.replace(nodes=true_trajectory_4_ge[t])
target_nodes_4_ge = true_trajectory_4_ge[t + 1]

output_ops_4_ge = model(input_graph_4_ge, num_processing_steps_ge)

_, true_nodes_rollout_4_ge = roll_out_physics(
    simulator, initial_conditions_4_ge, num_time_steps, step_size)
_, predicted_nodes_rollout_4_ge = roll_out_physics(
    lambda x: model(x, num_processing_steps_ge), initial_conditions_4_ge,
    num_time_steps, step_size)



# Test data: 7-mass string.
initial_conditions_7_ge, true_trajectory_7_ge = generate_trajectory(
    simulator,
    base_graph_7_ge,
    num_time_steps,
    step_size,
    node_noise_level=0.04,
    edge_noise_level=5.0,
    global_noise_level=1.0,
    do_set_rest=True,
    do_apply_gravity=True)

input_graph_7_ge = initial_conditions_7_ge.replace(nodes=true_trajectory_7_ge[t])
target_nodes_7_ge = true_trajectory_7_ge[t + 1]

output_ops_7_ge = model(input_graph_7_ge, num_processing_steps_ge)

_, true_nodes_rollout_7_ge = roll_out_physics(
    simulator, initial_conditions_7_ge, num_time_steps, step_size)
_, predicted_nodes_rollout_7_ge = roll_out_physics(
    lambda x: model(x, num_processing_steps_ge), initial_conditions_7_ge,
    num_time_steps, step_size)



# Test data: 11-mass string.
initial_conditions_11_ge, true_trajectory_11_ge = generate_trajectory(
    simulator,
    base_graph_11_ge,
    num_time_steps,
    step_size,
    node_noise_level=0.04,
    edge_noise_level=5.0,
    global_noise_level=1.0,
    do_set_rest=True,
    do_apply_gravity=True)
    
input_graph_11_ge = initial_conditions_11_ge.replace(nodes=true_trajectory_11_ge[t])
target_nodes_11_ge = true_trajectory_11_ge[t + 1]

output_ops_11_ge = model(input_graph_11_ge, num_processing_steps_ge)


_, true_nodes_rollout_11_ge = roll_out_physics(
    simulator, initial_conditions_11_ge, num_time_steps, step_size)
_, predicted_nodes_rollout_11_ge = roll_out_physics(
    lambda x: model(x, num_processing_steps_ge), initial_conditions_11_ge,
    num_time_steps, step_size)






# Training loss.
loss_ops_tr = create_loss_ops(target_nodes_tr, output_ops_tr)
# Training loss across processing steps.
loss_op_tr = sum(loss_ops_tr) / num_processing_steps_tr

# Test/generalization loss: 4-mass.
loss_ops_4_ge = create_loss_ops(target_nodes_4_ge,output_ops_4_ge)
loss_op_step_4_ge = sum(loss_ops_4_ge) / num_processing_steps_tr
loss_op_4_ge = tf.reduce_mean(
    tf.reduce_sum(
        (predicted_nodes_rollout_4_ge[..., 2:4] -
         true_nodes_rollout_4_ge[..., 2:4])**2,
        axis=-1))

#Test/generalization loss: 7-mass string.
loss_ops_7_ge = create_loss_ops(target_nodes_7_ge,output_ops_7_ge)
loss_op_step_7_ge = sum(loss_ops_7_ge) / num_processing_steps_ge
loss_op_7_ge = tf.reduce_mean(
    tf.reduce_sum(
        (predicted_nodes_rollout_7_ge[..., 2:4] -
         true_nodes_rollout_7_ge[..., 2:4])**2,
        axis=-1))

# Test/generalization loss: 11-mass string.
loss_ops_11_ge = create_loss_ops(target_nodes_11_ge,output_ops_11_ge)
loss_op_step_11_ge = sum(loss_ops_11_ge) / num_processing_steps_ge
loss_op_11_ge = tf.reduce_mean(
    tf.reduce_sum(
        (predicted_nodes_rollout_11_ge[..., 2:4] -
         true_nodes_rollout_11_ge[..., 2:4])**2,
        axis=-1))




# Optimizer.
learning_rate = 1e-3
optimizer = tf.train.AdamOptimizer(learning_rate)
step_op = optimizer.minimize(loss_op_tr)

input_graph_tr = make_all_runnable_in_session(input_graph_tr)
initial_conditions_4_ge = make_all_runnable_in_session(initial_conditions_4_ge)
initial_conditions_7_ge = make_all_runnable_in_session(initial_conditions_7_ge)
initial_conditions_11_ge = make_all_runnable_in_session(initial_conditions_11_ge)
# Out:
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/bence/git_workspace/Dyadic_Collaboration/Graph_Networks/Phases/Common/Scripts/Simulation_Functions_extended.py:75: The name tf.unsorted_segment_sum is deprecated. Please use tf.math.unsorted_segment_sum instead.
#
# WARNING:tensorflow:From /home/bence/git_workspace/Dyadic_Collaboration/Graph_Networks/Phases/Common/Scripts/Simulation_Functions_extended.py:185: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/basic.py:126: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/basic.py:131: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/basic.py:247: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.

# %% [markdown]
# ### Reset Tensorflow session, but keep the same computational graph.

# %%
#@title Reset session  { form-width: "30%" }


saver = tf.train.Saver()
# This cell resets the 
try:
    sess.close()
except NameError:
    pass
sess = tf.Session()
sess.run(tf.global_variables_initializer())

var = [v for v in tf.trainable_variables() if v.name == 'MLPGraphNetwork/graph_network/edge_block/mlp/linear_0/w:0']
pre_train_np = sess.run(var)
print(pre_train_np)


last_iteration = 0
logged_iterations = []
logged_timesteps = []
losses_tr = []
losses_4_ge = []
losses_4_step_ge = []
losses_7_ge = []
losses_7_step_ge = []
losses_11_ge = []
losses_11_step_ge = []
# Out:
# [array([[ 0.13994396,  0.00434755, -0.08806597, ..., -0.01814295,
#         -0.0260305 ,  0.00194879],
#        [ 0.15263185, -0.07144079,  0.01259622, ..., -0.05021881,
#         -0.16349208,  0.09897141],
#        [ 0.08737825, -0.02061945,  0.03737905, ..., -0.01561731,
#          0.00342687,  0.06709243],
#        ...,
#        [ 0.03678189,  0.00694761, -0.02133559, ...,  0.03898669,
#          0.06104496,  0.01226086],
#        [ 0.03779978, -0.06920423, -0.11025759, ..., -0.03418761,
#         -0.16592947, -0.03786828],
#        [-0.0046634 ,  0.07312618,  0.11583685, ..., -0.08122487,
#          0.09564007, -0.09065489]], dtype=float32)]

# %% [markdown]
# ### Train Network

# %%
#@title Run training  { form-width: "30%" }

# You can interrupt this cell's training loop at any time, and visualize the
# intermediate results by running the next cell (below). You can then resume
# training by simply executing this cell again.

# How much time between logging and printing the current results.
log_every_iteration = 250

print("# (iteration number), T (elapsed seconds), "
      "Ltr (training 1-step loss), "
      "Lge4 (test/generalization rollout loss for 4-mass strings), "
      "Lge9 (test/generalization rollout loss for 7-mass strings), "
      "Lge11 (test/generalization rollout loss for 11-mass strings)")

start_time = time.time()
last_log_time = start_time
for iteration in range(last_iteration, num_training_iterations):
    last_iteration = iteration
    train_values = sess.run({
        "step": step_op,
        "loss": loss_op_tr,
        "input_graph": input_graph_tr,
        "target_nodes": target_nodes_tr,
        "outputs": output_ops_tr,
        "time_step":t
    })
    if last_iteration % log_every_iteration == 0:
        
        the_time = time.time()
        elapsed_since_last_log = the_time - last_log_time
        last_log_time = the_time
        test_values = sess.run({
            "step_loss_4":loss_op_step_4_ge,
            "loss_4": loss_op_4_ge,
            "true_rollout_4": true_nodes_rollout_4_ge,
            "predicted_rollout_4": predicted_nodes_rollout_4_ge,
            "step_loss_7":loss_op_step_7_ge,
            "loss_7": loss_op_7_ge,
            "true_rollout_7": true_nodes_rollout_7_ge,
            "predicted_rollout_7": predicted_nodes_rollout_7_ge,
            "step_loss_11":loss_op_step_11_ge,
            "loss_11": loss_op_11_ge,
            "true_rollout_11": true_nodes_rollout_11_ge,
            "predicted_rollout_11": predicted_nodes_rollout_11_ge
        })
        elapsed = time.time() - start_time
        losses_tr.append(train_values["loss"])
        losses_4_ge.append(test_values["loss_4"])
        losses_4_step_ge.append(test_values["step_loss_4"])
        losses_7_ge.append(test_values["loss_7"])
        losses_7_step_ge.append(test_values["step_loss_7"])
        losses_11_ge.append(test_values["loss_11"])
        losses_11_step_ge.append(test_values["step_loss_11"])
        logged_iterations.append(iteration)
        logged_timesteps.append(train_values["time_step"])
        print("# {:05d}, T {:.1f}, Ltr {:.4f}, Lge4 {:.4f}, Lge7 {:.4f}, Lge11 {:.4f}, TimeStep {:03d}".format(
            iteration, elapsed, train_values["loss"], test_values["step_loss_4"],
            test_values["step_loss_7"],test_values["step_loss_11"],train_values["time_step"]))
# Out:
# # (iteration number), T (elapsed seconds), Ltr (training 1-step loss), Lge4 (test/generalization rollout loss for 4-mass strings), Lge9 (test/generalization rollout loss for 7-mass strings), Lge11 (test/generalization rollout loss for 11-mass strings)
# # 00000, T 2.2, Ltr 4.9924, Lge4 3.6679, Lge7 4.9819, Lge11 8.4970, TimeStep 006
# # 00250, T 7.9, Ltr 0.5571, Lge4 0.7224, Lge7 1.4864, Lge11 8.4834, TimeStep 013
# # 00500, T 13.4, Ltr 0.2824, Lge4 0.5772, Lge7 0.6929, Lge11 5.0702, TimeStep 022
# # 00750, T 18.9, Ltr 0.1697, Lge4 0.3719, Lge7 0.8943, Lge11 1.3652, TimeStep 034
# # 01000, T 24.3, Ltr 0.1630, Lge4 0.3808, Lge7 0.8226, Lge11 2.3550, TimeStep 004
# # 01250, T 29.6, Ltr 0.4075, Lge4 0.1628, Lge7 0.2281, Lge11 0.3570, TimeStep 006
# # 01500, T 35.1, Ltr 0.0590, Lge4 0.2828, Lge7 0.6996, Lge11 1.8305, TimeStep 047
# # 01750, T 40.5, Ltr 0.0817, Lge4 0.2277, Lge7 0.6551, Lge11 1.7141, TimeStep 035
# # 02000, T 45.8, Ltr 0.1893, Lge4 0.2843, Lge7 0.7075, Lge11 1.3133, TimeStep 004
# # 02250, T 51.2, Ltr 0.0908, Lge4 0.4224, Lge7 0.8330, Lge11 1.5206, TimeStep 033
# # 02500, T 56.6, Ltr 0.1026, Lge4 0.2450, Lge7 0.7363, Lge11 1.5202, TimeStep 004
# # 02750, T 62.0, Ltr 0.0658, Lge4 0.3157, Lge7 0.8370, Lge11 2.2608, TimeStep 046
# # 03000, T 67.4, Ltr 0.0617, Lge4 0.2111, Lge7 0.7388, Lge11 1.8587, TimeStep 043
# # 03250, T 72.8, Ltr 0.2076, Lge4 0.2632, Lge7 0.7117, Lge11 2.7035, TimeStep 016
# # 03500, T 78.2, Ltr 0.1889, Lge4 0.2449, Lge7 0.8072, Lge11 1.9050, TimeStep 009
# # 03750, T 83.6, Ltr 0.0615, Lge4 0.2404, Lge7 0.6704, Lge11 1.4137, TimeStep 045
# # 04000, T 89.0, Ltr 0.0429, Lge4 0.2334, Lge7 0.7542, Lge11 2.0472, TimeStep 002
# # 04250, T 94.3, Ltr 0.2096, Lge4 0.5271, Lge7 0.5852, Lge11 1.2773, TimeStep 023
# # 04500, T 99.7, Ltr 0.0418, Lge4 0.2044, Lge7 0.6654, Lge11 1.4283, TimeStep 048
# # 04750, T 105.1, Ltr 0.0601, Lge4 0.1760, Lge7 0.6186, Lge11 2.2224, TimeStep 037
# # 05000, T 110.5, Ltr 0.0508, Lge4 0.2689, Lge7 0.6827, Lge11 1.9644, TimeStep 043
# # 05250, T 115.9, Ltr 0.1514, Lge4 0.1505, Lge7 0.6237, Lge11 3.0306, TimeStep 026
# # 05500, T 121.2, Ltr 0.0548, Lge4 0.2338, Lge7 0.6523, Lge11 2.5528, TimeStep 037
# # 05750, T 126.6, Ltr 0.1918, Lge4 0.2075, Lge7 0.7118, Lge11 1.5984, TimeStep 018
# # 06000, T 132.0, Ltr 0.1433, Lge4 0.2082, Lge7 0.7590, Lge11 1.3591, TimeStep 027
# # 06250, T 137.4, Ltr 0.1801, Lge4 0.2082, Lge7 0.4539, Lge11 2.6639, TimeStep 024
# # 06500, T 142.8, Ltr 0.1910, Lge4 0.3495, Lge7 0.7560, Lge11 2.1490, TimeStep 024
# # 06750, T 148.3, Ltr 0.0261, Lge4 0.3622, Lge7 0.6754, Lge11 1.9812, TimeStep 003
# # 07000, T 153.7, Ltr 0.1373, Lge4 0.2841, Lge7 0.9439, Lge11 1.7541, TimeStep 014
# # 07250, T 159.1, Ltr 0.0229, Lge4 0.4064, Lge7 0.7013, Lge11 1.3549, TimeStep 000
# # 07500, T 164.4, Ltr 0.0880, Lge4 0.2858, Lge7 0.6216, Lge11 1.4181, TimeStep 032
# # 07750, T 169.8, Ltr 0.0428, Lge4 0.2486, Lge7 0.5700, Lge11 1.7591, TimeStep 045
# # 08000, T 175.2, Ltr 0.0905, Lge4 0.2101, Lge7 0.7399, Lge11 1.0511, TimeStep 033
# # 08250, T 180.6, Ltr 0.1681, Lge4 0.1526, Lge7 0.5376, Lge11 2.1433, TimeStep 022
# # 08500, T 186.2, Ltr 0.1419, Lge4 0.6017, Lge7 0.2467, Lge11 0.6933, TimeStep 009
# # 08750, T 191.8, Ltr 0.0459, Lge4 0.1136, Lge7 0.1893, Lge11 0.3765, TimeStep 040
# # 09000, T 197.2, Ltr 0.0378, Lge4 0.1858, Lge7 0.6996, Lge11 1.3835, TimeStep 046
# # 09250, T 202.6, Ltr 0.1137, Lge4 0.1981, Lge7 0.6980, Lge11 1.1766, TimeStep 026
# # 09500, T 208.0, Ltr 0.1644, Lge4 0.7385, Lge7 0.2603, Lge11 0.6650, TimeStep 022
# # 09750, T 213.4, Ltr 0.0502, Lge4 0.2080, Lge7 0.5628, Lge11 1.3323, TimeStep 005
# # 10000, T 218.9, Ltr 0.1464, Lge4 0.2764, Lge7 0.6904, Lge11 1.3288, TimeStep 018
# # 10250, T 224.3, Ltr 0.1127, Lge4 0.1914, Lge7 0.6159, Lge11 1.4575, TimeStep 007
# # 10500, T 229.9, Ltr 0.0381, Lge4 0.1797, Lge7 0.6298, Lge11 1.8020, TimeStep 046
# # 10750, T 235.5, Ltr 0.0480, Lge4 0.2997, Lge7 0.7421, Lge11 1.5541, TimeStep 038
# # 11000, T 240.9, Ltr 0.0577, Lge4 0.1562, Lge7 0.5450, Lge11 1.0324, TimeStep 035
# # 11250, T 246.4, Ltr 0.0184, Lge4 0.1607, Lge7 0.5672, Lge11 2.4303, TimeStep 002
# # 11500, T 251.9, Ltr 0.1003, Lge4 0.2217, Lge7 0.5275, Lge11 3.1754, TimeStep 005
# # 11750, T 257.4, Ltr 0.1886, Lge4 0.2545, Lge7 0.8244, Lge11 1.6356, TimeStep 019
# # 12000, T 262.9, Ltr 0.0291, Lge4 0.2264, Lge7 0.6986, Lge11 1.5919, TimeStep 046
# # 12250, T 268.3, Ltr 0.1306, Lge4 0.0271, Lge7 0.0159, Lge11 0.0275, TimeStep 019
# # 12500, T 273.9, Ltr 0.1168, Lge4 0.2543, Lge7 0.6221, Lge11 1.3769, TimeStep 014
# # 12750, T 279.5, Ltr 0.1152, Lge4 0.2917, Lge7 0.5317, Lge11 1.2754, TimeStep 023
# # 13000, T 285.0, Ltr 0.0684, Lge4 0.1549, Lge7 0.6683, Lge11 1.5153, TimeStep 030
# # 13250, T 290.5, Ltr 0.0325, Lge4 0.1561, Lge7 0.1999, Lge11 0.2732, TimeStep 046
# # 13500, T 296.1, Ltr 0.0301, Lge4 0.2564, Lge7 0.5180, Lge11 1.9298, TimeStep 044
# # 13750, T 301.6, Ltr 0.0371, Lge4 0.2232, Lge7 0.4602, Lge11 1.2031, TimeStep 041
# # 14000, T 307.1, Ltr 0.0564, Lge4 0.2220, Lge7 0.5373, Lge11 1.2885, TimeStep 039
# # 14250, T 312.5, Ltr 0.1048, Lge4 0.1643, Lge7 0.5047, Lge11 1.6062, TimeStep 017
# # 14500, T 318.0, Ltr 0.0436, Lge4 0.1440, Lge7 0.5409, Lge11 2.1666, TimeStep 005
# # 14750, T 323.4, Ltr 0.1160, Lge4 0.2162, Lge7 0.6645, Lge11 1.3998, TimeStep 023
# # 15000, T 328.8, Ltr 0.0932, Lge4 0.1609, Lge7 0.4243, Lge11 1.8008, TimeStep 035
# # 15250, T 334.3, Ltr 0.0708, Lge4 0.1647, Lge7 0.4778, Lge11 1.4902, TimeStep 031
# # 15500, T 339.7, Ltr 0.0434, Lge4 0.1566, Lge7 0.5658, Lge11 1.6341, TimeStep 038
# # 15750, T 345.2, Ltr 0.0163, Lge4 0.1908, Lge7 0.4973, Lge11 1.3557, TimeStep 002
# # 16000, T 350.7, Ltr 0.0787, Lge4 0.1904, Lge7 0.4854, Lge11 1.7848, TimeStep 030
# # 16250, T 356.1, Ltr 0.0945, Lge4 0.2137, Lge7 0.5390, Lge11 1.7279, TimeStep 027
# # 16500, T 361.6, Ltr 0.0250, Lge4 0.2783, Lge7 0.3776, Lge11 1.9554, TimeStep 046
# # 16750, T 367.1, Ltr 0.1047, Lge4 0.1420, Lge7 0.6254, Lge11 0.8942, TimeStep 022
# # 17000, T 372.6, Ltr 0.0904, Lge4 0.3749, Lge7 0.1161, Lge11 0.1598, TimeStep 026
# # 17250, T 378.0, Ltr 0.1338, Lge4 0.1394, Lge7 0.4256, Lge11 0.9685, TimeStep 024
# # 17500, T 383.6, Ltr 0.0814, Lge4 0.1206, Lge7 0.3539, Lge11 1.7493, TimeStep 016
# # 17750, T 389.2, Ltr 0.0359, Lge4 0.2095, Lge7 0.4544, Lge11 1.8357, TimeStep 042
# # 18000, T 394.7, Ltr 0.0494, Lge4 0.1738, Lge7 0.3573, Lge11 1.5303, TimeStep 033
# # 18250, T 400.2, Ltr 0.0587, Lge4 0.1306, Lge7 0.5407, Lge11 0.9368, TimeStep 007
# # 18500, T 405.6, Ltr 0.0371, Lge4 0.1349, Lge7 0.5882, Lge11 1.4651, TimeStep 039
# # 18750, T 411.1, Ltr 0.0344, Lge4 0.1356, Lge7 0.5655, Lge11 1.3891, TimeStep 042
# # 19000, T 416.6, Ltr 0.0510, Lge4 0.1921, Lge7 0.6256, Lge11 1.5391, TimeStep 034
# # 19250, T 422.4, Ltr 0.1432, Lge4 0.3332, Lge7 0.5599, Lge11 1.5886, TimeStep 018
# # 19500, T 427.9, Ltr 0.1089, Lge4 0.0276, Lge7 0.0252, Lge11 0.0319, TimeStep 023
# # 19750, T 433.3, Ltr 0.0379, Lge4 0.0093, Lge7 0.0238, Lge11 0.0363, TimeStep 036
# # 20000, T 438.8, Ltr 0.0465, Lge4 0.1278, Lge7 0.5418, Lge11 1.0013, TimeStep 036
# # 20250, T 444.3, Ltr 0.0290, Lge4 0.0112, Lge7 0.0108, Lge11 0.0147, TimeStep 045
# # 20500, T 449.7, Ltr 0.0890, Lge4 0.1969, Lge7 0.6013, Lge11 1.5837, TimeStep 009
# # 20750, T 455.1, Ltr 0.1447, Lge4 0.1508, Lge7 0.4100, Lge11 1.9590, TimeStep 014
# # 21000, T 460.6, Ltr 0.1008, Lge4 0.3159, Lge7 0.2585, Lge11 0.4018, TimeStep 014
# # 21250, T 466.1, Ltr 0.1459, Lge4 0.1553, Lge7 0.4852, Lge11 1.4563, TimeStep 011
# # 21500, T 471.7, Ltr 0.0200, Lge4 0.0170, Lge7 0.0140, Lge11 0.0160, TimeStep 048
# # 21750, T 477.2, Ltr 0.0975, Lge4 0.1638, Lge7 0.6372, Lge11 1.2329, TimeStep 019
# # 22000, T 482.6, Ltr 0.0279, Lge4 0.1143, Lge7 0.5763, Lge11 1.0218, TimeStep 041
# # 22250, T 488.1, Ltr 0.0936, Lge4 0.1538, Lge7 0.4358, Lge11 1.0975, TimeStep 026
# # 22500, T 493.6, Ltr 0.0513, Lge4 0.1720, Lge7 0.3996, Lge11 1.4594, TimeStep 032
# # 22750, T 499.1, Ltr 0.0861, Lge4 0.1453, Lge7 0.1755, Lge11 1.9181, TimeStep 020
# # 23000, T 504.6, Ltr 0.0706, Lge4 0.1484, Lge7 0.5452, Lge11 1.0678, TimeStep 034
# # 23250, T 510.0, Ltr 0.0770, Lge4 0.0107, Lge7 0.0131, Lge11 0.0233, TimeStep 018
# # 23500, T 515.5, Ltr 0.0395, Lge4 0.0678, Lge7 0.0967, Lge11 0.1064, TimeStep 038
# # 23750, T 521.0, Ltr 0.0775, Lge4 0.1555, Lge7 0.4118, Lge11 1.2889, TimeStep 010
# # 24000, T 526.5, Ltr 0.0305, Lge4 0.1705, Lge7 0.5983, Lge11 1.4392, TimeStep 046
# # 24250, T 532.0, Ltr 0.0448, Lge4 0.1347, Lge7 0.5441, Lge11 1.0740, TimeStep 004
# # 24500, T 537.5, Ltr 0.0398, Lge4 0.1270, Lge7 0.4672, Lge11 2.2581, TimeStep 038
# # 24750, T 543.0, Ltr 0.0499, Lge4 0.1132, Lge7 0.5627, Lge11 1.3027, TimeStep 032
# # 25000, T 548.5, Ltr 0.0084, Lge4 0.1102, Lge7 0.5873, Lge11 1.4585, TimeStep 000
# # 25250, T 553.9, Ltr 0.0169, Lge4 0.1255, Lge7 0.5810, Lge11 1.2599, TimeStep 002
# # 25500, T 559.4, Ltr 0.0300, Lge4 0.1056, Lge7 0.5422, Lge11 1.0891, TimeStep 041
# # 25750, T 564.9, Ltr 0.0726, Lge4 0.1521, Lge7 0.5388, Lge11 1.1659, TimeStep 018
# # 26000, T 570.4, Ltr 0.0802, Lge4 0.1313, Lge7 0.4671, Lge11 1.1949, TimeStep 008
# # 26250, T 575.9, Ltr 0.0432, Lge4 0.1301, Lge7 0.3902, Lge11 1.6868, TimeStep 036
# # 26500, T 581.4, Ltr 0.0827, Lge4 0.1454, Lge7 0.4157, Lge11 1.4151, TimeStep 014
# # 26750, T 586.9, Ltr 0.0816, Lge4 0.1420, Lge7 0.5170, Lge11 0.9495, TimeStep 024
# # 27000, T 592.3, Ltr 0.0690, Lge4 0.1680, Lge7 0.3961, Lge11 1.5433, TimeStep 018
# # 27250, T 597.8, Ltr 0.0545, Lge4 0.1383, Lge7 0.5121, Lge11 1.5836, TimeStep 008
# # 27500, T 603.3, Ltr 0.0763, Lge4 0.1609, Lge7 0.3341, Lge11 1.5918, TimeStep 011
# # 27750, T 608.8, Ltr 0.0728, Lge4 0.1332, Lge7 0.4291, Lge11 1.0741, TimeStep 016
# # 28000, T 614.3, Ltr 0.0491, Lge4 0.1520, Lge7 0.5618, Lge11 1.2560, TimeStep 030
# # 28250, T 619.8, Ltr 0.0733, Lge4 0.1051, Lge7 0.3218, Lge11 1.8456, TimeStep 009
# # 28500, T 625.2, Ltr 0.0513, Lge4 0.1215, Lge7 0.5197, Lge11 1.2698, TimeStep 007
# # 28750, T 630.7, Ltr 0.0338, Lge4 0.0159, Lge7 0.0131, Lge11 0.0146, TimeStep 003
# # 29000, T 636.2, Ltr 0.0385, Lge4 0.1130, Lge7 0.4977, Lge11 0.8649, TimeStep 035
# # 29250, T 641.7, Ltr 0.0774, Lge4 0.0943, Lge7 0.5449, Lge11 1.3780, TimeStep 013
# # 29500, T 647.2, Ltr 0.0327, Lge4 0.1201, Lge7 0.5539, Lge11 1.4624, TimeStep 040
# # 29750, T 652.7, Ltr 0.0547, Lge4 0.0164, Lge7 0.0325, Lge11 0.0566, TimeStep 027
# # 30000, T 658.1, Ltr 0.0335, Lge4 0.1280, Lge7 0.4487, Lge11 2.2162, TimeStep 037
# # 30250, T 663.6, Ltr 0.0372, Lge4 0.1056, Lge7 0.3136, Lge11 1.7563, TimeStep 036
# # 30500, T 669.1, Ltr 0.0556, Lge4 0.1549, Lge7 0.3537, Lge11 1.5576, TimeStep 027
# # 30750, T 674.6, Ltr 0.1075, Lge4 0.0355, Lge7 0.0220, Lge11 0.0290, TimeStep 009
# # 31000, T 680.1, Ltr 0.0731, Lge4 0.1141, Lge7 0.5128, Lge11 1.3383, TimeStep 017
# # 31250, T 685.5, Ltr 0.0769, Lge4 0.1115, Lge7 0.5720, Lge11 1.4161, TimeStep 021
# # 31500, T 691.0, Ltr 0.0208, Lge4 0.1332, Lge7 0.1618, Lge11 1.2328, TimeStep 046
# # 31750, T 696.5, Ltr 0.0726, Lge4 0.1018, Lge7 0.4040, Lge11 0.7404, TimeStep 020
# # 32000, T 702.0, Ltr 0.0302, Lge4 0.0541, Lge7 0.0332, Lge11 0.0349, TimeStep 042
# # 32250, T 707.5, Ltr 0.1751, Lge4 0.1014, Lge7 0.3897, Lge11 2.0528, TimeStep 011
# # 32500, T 712.9, Ltr 0.0732, Lge4 0.1034, Lge7 0.4636, Lge11 1.1229, TimeStep 016
# # 32750, T 718.4, Ltr 0.0690, Lge4 0.1187, Lge7 0.3766, Lge11 0.7410, TimeStep 030
# # 33000, T 723.9, Ltr 0.0769, Lge4 0.1445, Lge7 0.3779, Lge11 1.9287, TimeStep 027
# # 33250, T 729.4, Ltr 0.0209, Lge4 0.1033, Lge7 0.4912, Lge11 1.4321, TimeStep 047
# # 33500, T 734.8, Ltr 0.0390, Lge4 0.1755, Lge7 0.0959, Lge11 0.2146, TimeStep 035
# # 33750, T 740.3, Ltr 0.0726, Lge4 0.0951, Lge7 0.4153, Lge11 0.7307, TimeStep 024
# # 34000, T 745.7, Ltr 0.0308, Lge4 0.0186, Lge7 0.0107, Lge11 0.0114, TimeStep 040
# # 34250, T 751.2, Ltr 0.0270, Lge4 0.1193, Lge7 0.4208, Lge11 0.8608, TimeStep 042
# # 34500, T 756.7, Ltr 0.0491, Lge4 0.1567, Lge7 0.3616, Lge11 1.6638, TimeStep 028
# # 34750, T 762.2, Ltr 0.0218, Lge4 0.1225, Lge7 0.3814, Lge11 0.9658, TimeStep 001
# # 35000, T 767.7, Ltr 0.0100, Lge4 0.1097, Lge7 0.3760, Lge11 2.4305, TimeStep 003
# # 35250, T 773.2, Ltr 0.0697, Lge4 0.1269, Lge7 0.3681, Lge11 2.6112, TimeStep 040
# # 35500, T 778.7, Ltr 0.0458, Lge4 0.1278, Lge7 0.4640, Lge11 1.2392, TimeStep 005
# # 35750, T 784.2, Ltr 0.0606, Lge4 0.1111, Lge7 0.4615, Lge11 1.3380, TimeStep 026
# # 36000, T 789.6, Ltr 0.0579, Lge4 0.0991, Lge7 0.3618, Lge11 0.8278, TimeStep 019
# # 36250, T 795.1, Ltr 0.0611, Lge4 0.1166, Lge7 0.4317, Lge11 1.6052, TimeStep 023
# # 36500, T 800.6, Ltr 0.0192, Lge4 0.1028, Lge7 0.4114, Lge11 1.4105, TimeStep 045
# # 36750, T 806.0, Ltr 0.0092, Lge4 0.1438, Lge7 0.4298, Lge11 1.4736, TimeStep 000
# # 37000, T 811.5, Ltr 0.0435, Lge4 0.1061, Lge7 0.3693, Lge11 0.7440, TimeStep 038
# # 37250, T 817.1, Ltr 0.0752, Lge4 0.1217, Lge7 0.1787, Lge11 1.5759, TimeStep 019
# # 37500, T 822.6, Ltr 0.0431, Lge4 0.0999, Lge7 0.4147, Lge11 2.4204, TimeStep 007
# # 37750, T 828.1, Ltr 0.0409, Lge4 0.0892, Lge7 0.3513, Lge11 0.7560, TimeStep 034
# # 38000, T 833.7, Ltr 0.0416, Lge4 0.1133, Lge7 0.3747, Lge11 2.2231, TimeStep 030
# # 38250, T 839.2, Ltr 0.0193, Lge4 0.0884, Lge7 0.3542, Lge11 0.7785, TimeStep 046
# # 38500, T 844.8, Ltr 0.0730, Lge4 0.1002, Lge7 0.4474, Lge11 0.9185, TimeStep 014
# # 38750, T 850.3, Ltr 0.0688, Lge4 0.1055, Lge7 0.3776, Lge11 0.9030, TimeStep 012
# # 39000, T 855.7, Ltr 0.0453, Lge4 0.0885, Lge7 0.4085, Lge11 0.8907, TimeStep 036
# # 39250, T 861.2, Ltr 0.0082, Lge4 0.0925, Lge7 0.3579, Lge11 0.8054, TimeStep 002
# # 39500, T 866.6, Ltr 0.0371, Lge4 0.0792, Lge7 0.4362, Lge11 1.1704, TimeStep 037
# # 39750, T 872.1, Ltr 0.0723, Lge4 0.0938, Lge7 0.3917, Lge11 1.1046, TimeStep 018
# # 40000, T 877.5, Ltr 0.0227, Lge4 0.1511, Lge7 0.1505, Lge11 1.5315, TimeStep 047
# # 40250, T 882.9, Ltr 0.0167, Lge4 0.1320, Lge7 0.4848, Lge11 1.5697, TimeStep 003
# # 40500, T 888.3, Ltr 0.0282, Lge4 0.0927, Lge7 0.4208, Lge11 1.1566, TimeStep 005
# # 40750, T 893.8, Ltr 0.0195, Lge4 0.0219, Lge7 0.0247, Lge11 0.0259, TimeStep 043
# # 41000, T 899.2, Ltr 0.0219, Lge4 0.1135, Lge7 0.4097, Lge11 2.3716, TimeStep 042
# # 41250, T 904.6, Ltr 0.0607, Lge4 0.0981, Lge7 0.2890, Lge11 1.6080, TimeStep 023
# # 41500, T 910.0, Ltr 0.0642, Lge4 0.1349, Lge7 0.2781, Lge11 1.8550, TimeStep 020
# # 41750, T 915.5, Ltr 0.0711, Lge4 0.1568, Lge7 0.3610, Lge11 1.0862, TimeStep 022
# # 42000, T 920.9, Ltr 0.0540, Lge4 0.1032, Lge7 0.4289, Lge11 1.2597, TimeStep 015
# # 42250, T 926.3, Ltr 0.0336, Lge4 0.1292, Lge7 0.3338, Lge11 0.9580, TimeStep 032
# # 42500, T 931.7, Ltr 0.0281, Lge4 0.1282, Lge7 0.3120, Lge11 1.8012, TimeStep 037
# # 42750, T 937.1, Ltr 0.0935, Lge4 0.0884, Lge7 0.3225, Lge11 2.1061, TimeStep 011
# # 43000, T 942.6, Ltr 0.0585, Lge4 0.0978, Lge7 0.3638, Lge11 0.8581, TimeStep 022
# # 43250, T 948.0, Ltr 0.0563, Lge4 0.0912, Lge7 0.3186, Lge11 0.7023, TimeStep 020
# # 43500, T 953.4, Ltr 0.0245, Lge4 0.0550, Lge7 0.1195, Lge11 0.6804, TimeStep 040
# # 43750, T 958.8, Ltr 0.0243, Lge4 0.1159, Lge7 0.1251, Lge11 1.4709, TimeStep 040
# # 44000, T 964.2, Ltr 0.0580, Lge4 0.0958, Lge7 0.3808, Lge11 1.0052, TimeStep 011
# # 44250, T 969.7, Ltr 0.0087, Lge4 0.0891, Lge7 0.3644, Lge11 1.0562, TimeStep 002
# # 44500, T 975.1, Ltr 0.0464, Lge4 0.0488, Lge7 0.0499, Lge11 0.0518, TimeStep 027
# # 44750, T 980.5, Ltr 0.0274, Lge4 0.0970, Lge7 0.3550, Lge11 1.0097, TimeStep 040
# # 45000, T 985.9, Ltr 0.0634, Lge4 0.0298, Lge7 0.0291, Lge11 0.0361, TimeStep 011
# # 45250, T 991.4, Ltr 0.0548, Lge4 0.0137, Lge7 0.0079, Lge11 0.0117, TimeStep 025
# # 45500, T 996.8, Ltr 0.0554, Lge4 0.0730, Lge7 0.3227, Lge11 1.2285, TimeStep 016
# # 45750, T 1002.2, Ltr 0.0231, Lge4 0.0748, Lge7 0.3168, Lge11 0.7260, TimeStep 004
# # 46000, T 1007.7, Ltr 0.0624, Lge4 0.0104, Lge7 0.0556, Lge11 0.0837, TimeStep 010
# # 46250, T 1013.3, Ltr 0.0450, Lge4 0.0752, Lge7 0.3617, Lge11 1.1124, TimeStep 030
# # 46500, T 1018.8, Ltr 0.0213, Lge4 0.1255, Lge7 0.2162, Lge11 1.7969, TimeStep 039
# # 46750, T 1024.2, Ltr 0.0041, Lge4 0.1765, Lge7 0.1905, Lge11 0.5502, TimeStep 000
# # 47000, T 1029.7, Ltr 0.0905, Lge4 0.0968, Lge7 0.3925, Lge11 1.8693, TimeStep 011
# # 47250, T 1035.1, Ltr 0.0313, Lge4 0.0790, Lge7 0.2463, Lge11 1.5228, TimeStep 030
# # 47500, T 1040.5, Ltr 0.0457, Lge4 0.0717, Lge7 0.3320, Lge11 0.7631, TimeStep 018
# # 47750, T 1046.0, Ltr 0.0129, Lge4 0.0712, Lge7 0.3033, Lge11 0.6427, TimeStep 048
# # 48000, T 1051.5, Ltr 0.0272, Lge4 0.0760, Lge7 0.3281, Lge11 1.8231, TimeStep 034
# # 48250, T 1056.9, Ltr 0.0546, Lge4 0.1062, Lge7 0.1560, Lge11 1.3208, TimeStep 020
# # 48500, T 1062.3, Ltr 0.0351, Lge4 0.0962, Lge7 0.3067, Lge11 2.0476, TimeStep 032
# # 48750, T 1067.7, Ltr 0.0568, Lge4 0.0788, Lge7 0.2619, Lge11 1.6723, TimeStep 010
# # 49000, T 1073.2, Ltr 0.0509, Lge4 0.1213, Lge7 0.3725, Lge11 1.5780, TimeStep 009
# # 49250, T 1078.6, Ltr 0.0453, Lge4 0.0882, Lge7 0.3338, Lge11 0.9097, TimeStep 031
# # 49500, T 1084.1, Ltr 0.0242, Lge4 0.0908, Lge7 0.3578, Lge11 1.9458, TimeStep 035
# # 49750, T 1089.6, Ltr 0.0430, Lge4 0.0775, Lge7 0.2954, Lge11 0.8455, TimeStep 015
# # 50000, T 1095.1, Ltr 0.0270, Lge4 0.0023, Lge7 0.0070, Lge11 0.0099, TimeStep 044
# # 50250, T 1100.5, Ltr 0.0286, Lge4 0.0621, Lge7 0.3260, Lge11 0.9052, TimeStep 034
# # 50500, T 1106.0, Ltr 0.0217, Lge4 0.0792, Lge7 0.2609, Lge11 1.5103, TimeStep 042
# # 50750, T 1111.5, Ltr 0.0221, Lge4 0.0692, Lge7 0.1062, Lge11 0.6037, TimeStep 045
# # 51000, T 1117.0, Ltr 0.0125, Lge4 0.0024, Lge7 0.0094, Lge11 0.0149, TimeStep 047
# # 51250, T 1122.5, Ltr 0.0391, Lge4 0.0757, Lge7 0.2718, Lge11 1.4319, TimeStep 025
# # 51500, T 1128.0, Ltr 0.0175, Lge4 0.1320, Lge7 0.2326, Lge11 1.6190, TimeStep 048
# # 51750, T 1133.5, Ltr 0.0175, Lge4 0.0952, Lge7 0.2996, Lge11 1.9576, TimeStep 041
# # 52000, T 1138.9, Ltr 0.0172, Lge4 0.0805, Lge7 0.2782, Lge11 1.2577, TimeStep 048
# # 52250, T 1144.4, Ltr 0.0616, Lge4 0.0715, Lge7 0.0407, Lge11 0.1384, TimeStep 011
# # 52500, T 1149.9, Ltr 0.0500, Lge4 0.0641, Lge7 0.2946, Lge11 1.2826, TimeStep 027
# # 52750, T 1155.3, Ltr 0.0332, Lge4 0.0436, Lge7 0.3784, Lge11 1.8076, TimeStep 042
# # 53000, T 1160.8, Ltr 0.0188, Lge4 0.0446, Lge7 0.2603, Lge11 1.4821, TimeStep 036
# # 53250, T 1166.3, Ltr 0.0330, Lge4 0.0713, Lge7 0.3065, Lge11 0.7961, TimeStep 028
# # 53500, T 1171.7, Ltr 0.0370, Lge4 0.0565, Lge7 0.2623, Lge11 0.8358, TimeStep 020
# # 53750, T 1177.2, Ltr 0.0135, Lge4 0.1096, Lge7 0.3238, Lge11 1.9762, TimeStep 044
# # 54000, T 1182.7, Ltr 0.0090, Lge4 0.0896, Lge7 0.3028, Lge11 1.7262, TimeStep 002
# # 54250, T 1188.2, Ltr 0.0249, Lge4 0.1234, Lge7 0.2177, Lge11 1.8761, TimeStep 034
# # 54500, T 1193.6, Ltr 0.0215, Lge4 0.0485, Lge7 0.3351, Lge11 0.8565, TimeStep 038
# # 54750, T 1199.1, Ltr 0.0197, Lge4 0.0546, Lge7 0.3786, Lge11 1.8029, TimeStep 041
# # 55000, T 1204.6, Ltr 0.0121, Lge4 0.0512, Lge7 0.4053, Lge11 0.9704, TimeStep 001
# # 55250, T 1210.1, Ltr 0.0469, Lge4 0.1359, Lge7 0.0727, Lge11 1.1344, TimeStep 010
# # 55500, T 1215.5, Ltr 0.0588, Lge4 0.0696, Lge7 0.0507, Lge11 0.1907, TimeStep 011
# # 55750, T 1221.0, Ltr 0.0447, Lge4 0.0799, Lge7 0.3030, Lge11 1.3961, TimeStep 010
# # 56000, T 1226.5, Ltr 0.0146, Lge4 0.0865, Lge7 0.2955, Lge11 1.7439, TimeStep 042
# # 56250, T 1231.9, Ltr 0.0439, Lge4 0.0586, Lge7 0.2891, Lge11 0.6811, TimeStep 016
# # 56500, T 1237.4, Ltr 0.0132, Lge4 0.0079, Lge7 0.0262, Lge11 0.0408, TimeStep 045
# # 56750, T 1242.9, Ltr 0.0315, Lge4 0.0586, Lge7 0.2007, Lge11 0.8415, TimeStep 024
# # 57000, T 1248.5, Ltr 0.0533, Lge4 0.0586, Lge7 0.2244, Lge11 0.6543, TimeStep 013
# # 57250, T 1254.0, Ltr 0.0480, Lge4 0.0573, Lge7 0.3503, Lge11 0.8748, TimeStep 022
# # 57500, T 1259.4, Ltr 0.0096, Lge4 0.0920, Lge7 0.3243, Lge11 1.9668, TimeStep 001
# # 57750, T 1265.0, Ltr 0.0222, Lge4 0.0724, Lge7 0.2389, Lge11 1.2160, TimeStep 030
# # 58000, T 1270.4, Ltr 0.0207, Lge4 0.0582, Lge7 0.2632, Lge11 0.7990, TimeStep 004
# # 58250, T 1275.9, Ltr 0.0381, Lge4 0.0400, Lge7 0.0176, Lge11 0.0629, TimeStep 018
# # 58500, T 1281.4, Ltr 0.0150, Lge4 0.0756, Lge7 0.2744, Lge11 2.0292, TimeStep 048
# # 58750, T 1286.9, Ltr 0.0279, Lge4 0.0591, Lge7 0.2562, Lge11 0.7834, TimeStep 031
# # 59000, T 1292.5, Ltr 0.0303, Lge4 0.0654, Lge7 0.2623, Lge11 1.5504, TimeStep 018
# # 59250, T 1297.9, Ltr 0.0106, Lge4 0.0492, Lge7 0.1919, Lge11 0.7289, TimeStep 002
# # 59500, T 1303.5, Ltr 0.0249, Lge4 0.1036, Lge7 0.2497, Lge11 1.7717, TimeStep 030
# # 59750, T 1309.0, Ltr 0.0125, Lge4 0.0640, Lge7 0.2700, Lge11 0.8322, TimeStep 046
# # 60000, T 1314.5, Ltr 0.0321, Lge4 0.0743, Lge7 0.2847, Lge11 0.7949, TimeStep 042
# # 60250, T 1320.0, Ltr 0.0339, Lge4 0.0554, Lge7 0.2036, Lge11 1.7295, TimeStep 008
# # 60500, T 1325.4, Ltr 0.0237, Lge4 0.0801, Lge7 0.1955, Lge11 1.5084, TimeStep 040
# # 60750, T 1330.9, Ltr 0.0286, Lge4 0.0649, Lge7 0.2373, Lge11 1.7035, TimeStep 018
# # 61000, T 1336.4, Ltr 0.0289, Lge4 0.0741, Lge7 0.2041, Lge11 1.5075, TimeStep 017
# # 61250, T 1341.9, Ltr 0.0208, Lge4 0.0455, Lge7 0.2637, Lge11 0.9058, TimeStep 007
# # 61500, T 1347.4, Ltr 0.0165, Lge4 0.0401, Lge7 0.2132, Lge11 0.6950, TimeStep 040
# # 61750, T 1352.9, Ltr 0.0301, Lge4 0.1017, Lge7 0.2255, Lge11 3.0896, TimeStep 030
# # 62000, T 1358.4, Ltr 0.0181, Lge4 0.0460, Lge7 0.2678, Lge11 0.8474, TimeStep 029
# # 62250, T 1363.9, Ltr 0.0367, Lge4 0.0143, Lge7 0.0233, Lge11 0.0501, TimeStep 018
# # 62500, T 1369.3, Ltr 0.0240, Lge4 0.0449, Lge7 0.2552, Lge11 0.8763, TimeStep 007
# # 62750, T 1374.9, Ltr 0.0277, Lge4 0.0546, Lge7 0.2030, Lge11 0.6821, TimeStep 000
# # 63000, T 1380.3, Ltr 0.0320, Lge4 0.0472, Lge7 0.2766, Lge11 0.8604, TimeStep 016
# # 63250, T 1385.9, Ltr 0.0268, Lge4 0.0685, Lge7 0.2809, Lge11 1.2579, TimeStep 026
# # 63500, T 1391.4, Ltr 0.0301, Lge4 0.0113, Lge7 0.0035, Lge11 0.0080, TimeStep 017
# # 63750, T 1396.9, Ltr 0.0117, Lge4 0.0525, Lge7 0.2043, Lge11 0.8020, TimeStep 042
# # 64000, T 1402.4, Ltr 0.0163, Lge4 0.0517, Lge7 0.2200, Lge11 0.5746, TimeStep 001
# # 64250, T 1407.9, Ltr 0.0211, Lge4 0.0749, Lge7 0.0624, Lge11 0.2643, TimeStep 031
# # 64500, T 1413.4, Ltr 0.0068, Lge4 0.0834, Lge7 0.2614, Lge11 1.8374, TimeStep 001
# # 64750, T 1418.9, Ltr 0.0200, Lge4 0.0413, Lge7 0.2373, Lge11 0.8257, TimeStep 035
# # 65000, T 1424.3, Ltr 0.0228, Lge4 0.0567, Lge7 0.2255, Lge11 1.6644, TimeStep 033
# # 65250, T 1429.8, Ltr 0.0130, Lge4 0.0495, Lge7 0.2067, Lge11 1.5565, TimeStep 038
# # 65500, T 1435.3, Ltr 0.0185, Lge4 0.0884, Lge7 0.1110, Lge11 0.2248, TimeStep 045
# # 65750, T 1440.7, Ltr 0.0104, Lge4 0.0720, Lge7 0.2553, Lge11 1.8320, TimeStep 043
# # 66000, T 1446.2, Ltr 0.0401, Lge4 0.0615, Lge7 0.3118, Lge11 1.7824, TimeStep 011
# # 66250, T 1451.7, Ltr 0.0214, Lge4 0.0611, Lge7 0.2150, Lge11 1.1303, TimeStep 029
# # 66500, T 1457.1, Ltr 0.0205, Lge4 0.0479, Lge7 0.1941, Lge11 0.6104, TimeStep 026
# # 66750, T 1462.7, Ltr 0.0283, Lge4 0.0752, Lge7 0.2518, Lge11 1.7252, TimeStep 019
# # 67000, T 1468.1, Ltr 0.0172, Lge4 0.0499, Lge7 0.1944, Lge11 0.5135, TimeStep 033
# # 67250, T 1473.6, Ltr 0.0133, Lge4 0.0689, Lge7 0.2338, Lge11 1.1829, TimeStep 043
# # 67500, T 1479.1, Ltr 0.0191, Lge4 0.0972, Lge7 0.1621, Lge11 1.8866, TimeStep 031
# # 67750, T 1484.6, Ltr 0.0130, Lge4 0.0367, Lge7 0.2405, Lge11 0.7480, TimeStep 036
# # 68000, T 1490.1, Ltr 0.0437, Lge4 0.0901, Lge7 0.3960, Lge11 1.2062, TimeStep 031
# # 68250, T 1495.6, Ltr 0.0395, Lge4 0.0390, Lge7 0.0555, Lge11 0.1717, TimeStep 010
# # 68500, T 1501.1, Ltr 0.0115, Lge4 0.0644, Lge7 0.0756, Lge11 1.2409, TimeStep 042
# # 68750, T 1506.5, Ltr 0.0267, Lge4 0.0416, Lge7 0.2298, Lge11 0.9177, TimeStep 018
# # 69000, T 1511.9, Ltr 0.0189, Lge4 0.0358, Lge7 0.0262, Lge11 0.1050, TimeStep 035
# # 69250, T 1517.3, Ltr 0.0079, Lge4 0.0410, Lge7 0.2605, Lge11 0.8490, TimeStep 048
# # 69500, T 1522.8, Ltr 0.0106, Lge4 0.0484, Lge7 0.0621, Lge11 0.2253, TimeStep 004
# # 69750, T 1528.3, Ltr 0.0308, Lge4 0.0348, Lge7 0.3000, Lge11 0.8575, TimeStep 014
# # 70000, T 1533.8, Ltr 0.0073, Lge4 0.0450, Lge7 0.2553, Lge11 1.2954, TimeStep 002
# # 70250, T 1539.3, Ltr 0.0360, Lge4 0.0714, Lge7 0.2042, Lge11 1.1638, TimeStep 019
# # 70500, T 1544.8, Ltr 0.0180, Lge4 0.0691, Lge7 0.1888, Lge11 2.0063, TimeStep 033
# # 70750, T 1550.2, Ltr 0.0089, Lge4 0.0437, Lge7 0.2568, Lge11 1.3885, TimeStep 046
# # 71000, T 1555.7, Ltr 0.0201, Lge4 0.0501, Lge7 0.2040, Lge11 0.6431, TimeStep 037
# # 71250, T 1561.2, Ltr 0.0308, Lge4 0.0426, Lge7 0.1763, Lge11 0.5178, TimeStep 015
# # 71500, T 1566.7, Ltr 0.0107, Lge4 0.0692, Lge7 0.2427, Lge11 1.6913, TimeStep 005
# # 71750, T 1572.2, Ltr 0.0087, Lge4 0.0439, Lge7 0.1603, Lge11 0.5916, TimeStep 044
# # 72000, T 1577.8, Ltr 0.0079, Lge4 0.0489, Lge7 0.1663, Lge11 0.6495, TimeStep 000
# # 72250, T 1583.2, Ltr 0.0108, Lge4 0.0481, Lge7 0.2154, Lge11 1.4379, TimeStep 041
# # 72500, T 1588.7, Ltr 0.0212, Lge4 0.0390, Lge7 0.2126, Lge11 1.0602, TimeStep 027
# # 72750, T 1594.3, Ltr 0.0582, Lge4 0.0533, Lge7 0.2609, Lge11 0.8888, TimeStep 010
# # 73000, T 1599.8, Ltr 0.0251, Lge4 0.0656, Lge7 0.2225, Lge11 1.4141, TimeStep 023
# # 73250, T 1605.2, Ltr 0.0826, Lge4 0.1196, Lge7 0.2856, Lge11 0.9452, TimeStep 034
# # 73500, T 1610.7, Ltr 0.0227, Lge4 0.0671, Lge7 0.0695, Lge11 1.2786, TimeStep 026
# # 73750, T 1616.2, Ltr 0.0145, Lge4 0.0448, Lge7 0.2523, Lge11 1.6370, TimeStep 033
# # 74000, T 1621.8, Ltr 0.0228, Lge4 0.0490, Lge7 0.2490, Lge11 1.6086, TimeStep 026
# # 74250, T 1627.3, Ltr 0.0203, Lge4 0.0484, Lge7 0.2140, Lge11 1.7627, TimeStep 025
# # 74500, T 1632.8, Ltr 0.0226, Lge4 0.0237, Lge7 0.0504, Lge11 0.0794, TimeStep 028
# # 74750, T 1638.3, Ltr 0.0332, Lge4 0.0406, Lge7 0.2195, Lge11 0.8067, TimeStep 017
# # 75000, T 1643.8, Ltr 0.0337, Lge4 0.0329, Lge7 0.2073, Lge11 0.8660, TimeStep 028
# # 75250, T 1649.3, Ltr 0.0113, Lge4 0.0674, Lge7 0.2228, Lge11 0.7844, TimeStep 002
# # 75500, T 1654.8, Ltr 0.0070, Lge4 0.0490, Lge7 0.2290, Lge11 0.7515, TimeStep 002
# # 75750, T 1660.3, Ltr 0.0130, Lge4 0.0097, Lge7 0.0227, Lge11 0.0522, TimeStep 032
# # 76000, T 1665.8, Ltr 0.0299, Lge4 0.0392, Lge7 0.2379, Lge11 0.7959, TimeStep 010
# # 76250, T 1671.3, Ltr 0.0339, Lge4 0.0483, Lge7 0.1028, Lge11 1.2574, TimeStep 014
# # 76500, T 1676.7, Ltr 0.0212, Lge4 0.0455, Lge7 0.2010, Lge11 1.2406, TimeStep 030
# # 76750, T 1682.2, Ltr 0.0146, Lge4 0.0298, Lge7 0.2310, Lge11 1.4157, TimeStep 034
# # 77000, T 1687.7, Ltr 0.0341, Lge4 0.0538, Lge7 0.2379, Lge11 1.7502, TimeStep 012
# # 77250, T 1693.2, Ltr 0.0078, Lge4 0.0459, Lge7 0.1512, Lge11 0.5954, TimeStep 042
# # 77500, T 1698.9, Ltr 0.0142, Lge4 0.0544, Lge7 0.2365, Lge11 0.7672, TimeStep 040
# # 77750, T 1704.3, Ltr 0.0128, Lge4 0.0359, Lge7 0.2070, Lge11 1.1712, TimeStep 034
# # 78000, T 1709.8, Ltr 0.0101, Lge4 0.0662, Lge7 0.1687, Lge11 1.6512, TimeStep 040
# # 78250, T 1715.4, Ltr 0.0307, Lge4 0.0463, Lge7 0.2454, Lge11 0.7995, TimeStep 011
# # 78500, T 1720.8, Ltr 0.0220, Lge4 0.0493, Lge7 0.2348, Lge11 1.8068, TimeStep 009
# # 78750, T 1726.4, Ltr 0.0261, Lge4 0.0305, Lge7 0.2015, Lge11 1.5368, TimeStep 016
# # 79000, T 1731.8, Ltr 0.0031, Lge4 0.0415, Lge7 0.2377, Lge11 1.3024, TimeStep 001
# # 79250, T 1737.3, Ltr 0.0131, Lge4 0.0394, Lge7 0.2997, Lge11 1.3857, TimeStep 003
# # 79500, T 1742.7, Ltr 0.0081, Lge4 0.0362, Lge7 0.1376, Lge11 0.7908, TimeStep 044
# # 79750, T 1748.2, Ltr 0.0279, Lge4 0.0210, Lge7 0.0061, Lge11 0.0125, TimeStep 021
# # 80000, T 1753.7, Ltr 0.0089, Lge4 0.0337, Lge7 0.2521, Lge11 0.8239, TimeStep 003
# # 80250, T 1759.1, Ltr 0.0347, Lge4 0.0082, Lge7 0.0124, Lge11 0.0375, TimeStep 013
# # 80500, T 1764.6, Ltr 0.0136, Lge4 0.0446, Lge7 0.2481, Lge11 0.6723, TimeStep 029
# # 80750, T 1770.2, Ltr 0.0410, Lge4 0.1200, Lge7 0.3080, Lge11 0.5939, TimeStep 003
# # 81000, T 1775.7, Ltr 0.0261, Lge4 0.0264, Lge7 0.0232, Lge11 0.0487, TimeStep 007
# # 81250, T 1781.3, Ltr 0.0142, Lge4 0.0412, Lge7 0.2066, Lge11 0.7895, TimeStep 037
# # 81500, T 1786.8, Ltr 0.0195, Lge4 0.0410, Lge7 0.1417, Lge11 0.5074, TimeStep 020
# # 81750, T 1792.3, Ltr 0.0395, Lge4 0.0531, Lge7 0.2691, Lge11 1.1863, TimeStep 014
# # 82000, T 1797.9, Ltr 0.0189, Lge4 0.0588, Lge7 0.2736, Lge11 0.9316, TimeStep 032
# # 82250, T 1803.5, Ltr 0.0292, Lge4 0.0394, Lge7 0.2210, Lge11 1.4232, TimeStep 012
# # 82500, T 1809.0, Ltr 0.0205, Lge4 0.0684, Lge7 0.1278, Lge11 1.7789, TimeStep 009
# # 82750, T 1814.5, Ltr 0.0216, Lge4 0.0416, Lge7 0.1837, Lge11 0.8356, TimeStep 023
# # 83000, T 1820.0, Ltr 0.0225, Lge4 0.0582, Lge7 0.1971, Lge11 1.3878, TimeStep 021
# # 83250, T 1825.6, Ltr 0.0153, Lge4 0.0484, Lge7 0.0994, Lge11 1.1606, TimeStep 028
# # 83500, T 1831.2, Ltr 0.0130, Lge4 0.0350, Lge7 0.1919, Lge11 0.7713, TimeStep 004
# # 83750, T 1836.6, Ltr 0.0095, Lge4 0.0322, Lge7 0.1957, Lge11 0.9657, TimeStep 004
# # 84000, T 1842.1, Ltr 0.0244, Lge4 0.0353, Lge7 0.0625, Lge11 0.5180, TimeStep 015
# # 84250, T 1847.4, Ltr 0.0089, Lge4 0.0395, Lge7 0.1432, Lge11 0.6105, TimeStep 004
# # 84500, T 1853.0, Ltr 0.0155, Lge4 0.0257, Lge7 0.0319, Lge11 0.1064, TimeStep 006
# # 84750, T 1858.4, Ltr 0.0203, Lge4 0.0673, Lge7 0.1477, Lge11 1.7986, TimeStep 007
# # 85000, T 1863.9, Ltr 0.0084, Lge4 0.0566, Lge7 0.1639, Lge11 2.0491, TimeStep 041
# # 85250, T 1869.3, Ltr 0.0148, Lge4 0.0279, Lge7 0.0228, Lge11 0.0689, TimeStep 028
# # 85500, T 1874.8, Ltr 0.0294, Lge4 0.0516, Lge7 0.2632, Lge11 1.5306, TimeStep 015
# # 85750, T 1880.2, Ltr 0.0330, Lge4 0.0407, Lge7 0.1729, Lge11 1.1807, TimeStep 004
# # 86000, T 1885.6, Ltr 0.0208, Lge4 0.0358, Lge7 0.1926, Lge11 1.1446, TimeStep 016
# # 86250, T 1891.0, Ltr 0.0087, Lge4 0.0341, Lge7 0.2578, Lge11 0.6817, TimeStep 036
# # 86500, T 1896.4, Ltr 0.0141, Lge4 0.0423, Lge7 0.1243, Lge11 0.5753, TimeStep 028
# # 86750, T 1901.9, Ltr 0.0084, Lge4 0.0307, Lge7 0.1535, Lge11 1.2309, TimeStep 005
# # 87000, T 1907.3, Ltr 0.0092, Lge4 0.0349, Lge7 0.1766, Lge11 1.0935, TimeStep 004
# # 87250, T 1912.7, Ltr 0.0127, Lge4 0.0661, Lge7 0.1453, Lge11 1.5850, TimeStep 037
# # 87500, T 1918.2, Ltr 0.0179, Lge4 0.0419, Lge7 0.1867, Lge11 1.2576, TimeStep 007
# # 87750, T 1923.7, Ltr 0.0179, Lge4 0.0545, Lge7 0.2226, Lge11 1.5470, TimeStep 023
# # 88000, T 1929.1, Ltr 0.0162, Lge4 0.0042, Lge7 0.0030, Lge11 0.0076, TimeStep 025
# # 88250, T 1934.5, Ltr 0.0458, Lge4 0.0594, Lge7 0.2053, Lge11 1.2844, TimeStep 012
# # 88500, T 1939.9, Ltr 0.0088, Lge4 0.0443, Lge7 0.1901, Lge11 1.3044, TimeStep 005
# # 88750, T 1945.3, Ltr 0.0345, Lge4 0.0503, Lge7 0.2356, Lge11 1.3807, TimeStep 022
# # 89000, T 1950.8, Ltr 0.0135, Lge4 0.0869, Lge7 0.1229, Lge11 2.1997, TimeStep 003
# # 89250, T 1956.3, Ltr 0.0182, Lge4 0.0418, Lge7 0.1540, Lge11 0.7292, TimeStep 035
# # 89500, T 1961.9, Ltr 0.0073, Lge4 0.0124, Lge7 0.0040, Lge11 0.0064, TimeStep 040
# # 89750, T 1967.4, Ltr 0.0338, Lge4 0.0606, Lge7 0.1921, Lge11 1.6559, TimeStep 027
# # 90000, T 1972.9, Ltr 0.0192, Lge4 0.0306, Lge7 0.2045, Lge11 1.1518, TimeStep 016
# # 90250, T 1978.3, Ltr 0.0059, Lge4 0.0043, Lge7 0.0090, Lge11 0.0209, TimeStep 043
# # 90500, T 1983.7, Ltr 0.0119, Lge4 0.0495, Lge7 0.1724, Lge11 0.6019, TimeStep 044
# # 90750, T 1989.2, Ltr 0.0154, Lge4 0.0366, Lge7 0.1459, Lge11 0.4547, TimeStep 003
# # 91000, T 1994.6, Ltr 0.0138, Lge4 0.0309, Lge7 0.1911, Lge11 0.8185, TimeStep 027
# # 91250, T 2000.0, Ltr 0.0489, Lge4 0.0840, Lge7 0.2461, Lge11 0.8656, TimeStep 038
# # 91500, T 2005.4, Ltr 0.0108, Lge4 0.0623, Lge7 0.1512, Lge11 1.7291, TimeStep 034
# # 91750, T 2010.9, Ltr 0.0175, Lge4 0.0424, Lge7 0.1993, Lge11 0.6976, TimeStep 027
# # 92000, T 2016.4, Ltr 0.0065, Lge4 0.0386, Lge7 0.1299, Lge11 0.4907, TimeStep 045
# # 92250, T 2021.9, Ltr 0.0258, Lge4 0.0149, Lge7 0.0166, Lge11 0.0272, TimeStep 011
# # 92500, T 2027.4, Ltr 0.0266, Lge4 0.0380, Lge7 0.1184, Lge11 0.6644, TimeStep 010
# # 92750, T 2032.8, Ltr 0.0197, Lge4 0.0370, Lge7 0.1496, Lge11 0.4630, TimeStep 018
# # 93000, T 2038.4, Ltr 0.0316, Lge4 0.0441, Lge7 0.1945, Lge11 0.7312, TimeStep 015
# # 93250, T 2043.8, Ltr 0.0109, Lge4 0.0088, Lge7 0.0437, Lge11 0.0658, TimeStep 035
# # 93500, T 2049.3, Ltr 0.0069, Lge4 0.0391, Lge7 0.1255, Lge11 0.4834, TimeStep 046
# # 93750, T 2054.7, Ltr 0.0085, Lge4 0.0463, Lge7 0.0740, Lge11 0.9707, TimeStep 043
# # 94000, T 2060.2, Ltr 0.0142, Lge4 0.0400, Lge7 0.2186, Lge11 0.7384, TimeStep 025
# # 94250, T 2065.7, Ltr 0.0114, Lge4 0.0318, Lge7 0.1512, Lge11 0.6731, TimeStep 030
# # 94500, T 2071.2, Ltr 0.0105, Lge4 0.0366, Lge7 0.1625, Lge11 0.4909, TimeStep 032
# # 94750, T 2076.6, Ltr 0.0101, Lge4 0.0403, Lge7 0.1985, Lge11 0.5592, TimeStep 034
# # 95000, T 2082.0, Ltr 0.0184, Lge4 0.0509, Lge7 0.1358, Lge11 1.4618, TimeStep 003
# # 95250, T 2087.5, Ltr 0.0085, Lge4 0.0379, Lge7 0.1782, Lge11 0.6070, TimeStep 038
# # 95500, T 2092.9, Ltr 0.0078, Lge4 0.0376, Lge7 0.1669, Lge11 0.6578, TimeStep 003
# # 95750, T 2098.3, Ltr 0.0221, Lge4 0.0391, Lge7 0.2067, Lge11 0.6265, TimeStep 017
# # 96000, T 2103.8, Ltr 0.0248, Lge4 0.0454, Lge7 0.2103, Lge11 0.6971, TimeStep 012
# # 96250, T 2109.2, Ltr 0.0213, Lge4 0.0415, Lge7 0.1926, Lge11 1.2404, TimeStep 009
# # 96500, T 2114.7, Ltr 0.0097, Lge4 0.0342, Lge7 0.2084, Lge11 0.8230, TimeStep 033
# # 96750, T 2120.2, Ltr 0.0211, Lge4 0.0100, Lge7 0.0098, Lge11 0.0326, TimeStep 037
# # 97000, T 2125.6, Ltr 0.0029, Lge4 0.0563, Lge7 0.1511, Lge11 0.5306, TimeStep 000
# # 97250, T 2131.1, Ltr 0.0106, Lge4 0.0496, Lge7 0.2148, Lge11 1.3436, TimeStep 029
# # 97500, T 2136.5, Ltr 0.0137, Lge4 0.0574, Lge7 0.1740, Lge11 1.4388, TimeStep 006
# # 97750, T 2141.9, Ltr 0.0142, Lge4 0.0402, Lge7 0.1366, Lge11 0.9217, TimeStep 019
# # 98000, T 2147.4, Ltr 0.0284, Lge4 0.0485, Lge7 0.1428, Lge11 1.0757, TimeStep 021
# # 98250, T 2152.8, Ltr 0.0079, Lge4 0.0407, Lge7 0.1937, Lge11 1.2495, TimeStep 044
# # 98500, T 2158.2, Ltr 0.0029, Lge4 0.0462, Lge7 0.1677, Lge11 1.5499, TimeStep 000
# # 98750, T 2163.7, Ltr 0.0051, Lge4 0.0349, Lge7 0.1837, Lge11 1.3984, TimeStep 046
# # 99000, T 2169.2, Ltr 0.0059, Lge4 0.0399, Lge7 0.0393, Lge11 0.1548, TimeStep 044
# # 99250, T 2174.7, Ltr 0.0149, Lge4 0.0329, Lge7 0.2127, Lge11 1.1433, TimeStep 041
# # 99500, T 2180.2, Ltr 0.0055, Lge4 0.0389, Lge7 0.1235, Lge11 0.4578, TimeStep 045
# # 99750, T 2185.7, Ltr 0.0316, Lge4 0.0862, Lge7 0.2151, Lge11 1.6631, TimeStep 042

# %%
var = [v for v in tf.trainable_variables() if v.name == 'MLPGraphNetwork/graph_network/edge_block/mlp/linear_0/w:0']
post_train_np = sess.run(var)
print(np.array(post_train_np)-np.array(pre_train_np))
# Out:
# [[[-7.1721214e-01 -1.4410228e-01 -1.3467461e-02 ... -5.4658093e-02
#     1.6918700e-02 -3.9581391e-01]
#   [ 4.6999797e-01  2.7444395e-01  2.6579794e-02 ... -1.3086346e-01
#     8.8351168e-02  6.9256496e-01]
#   [-7.2662258e-01 -1.9932467e-01  3.8217753e-05 ...  2.9337801e-02
#     3.4624990e-02 -4.8849007e-01]
#   ...
#   [-3.0176509e-02  1.2448684e-02  4.3434825e-02 ... -7.6204948e-02
#     5.2108474e-02  1.0385527e-02]
#   [-4.1020658e-02  3.3172231e-02  2.9580437e-02 ... -7.0523992e-03
#     3.7461638e-02  6.9569886e-02]
#   [ 5.8949694e-02 -4.2858969e-02  2.7986668e-02 ...  1.0128364e-01
#     3.3036940e-02 -2.7200140e-02]]]

# %% [markdown]
# ## Save Model

# %%
if os.path.exists(os.path.join(path_saves, "model.ckpt")):
    print("The file: "+ "model.ckpt" + "already exists. Delete it before saving a new trajectory!")
else:
    save_path = saver.save(sess, os.path.join(path_saves)+"/model.ckpt")
    print("Model saved in path: %s" % save_path)
# Out:
# Model saved in path: /home/bence/git_workspace/Dyadic_Collaboration/Graph_Networks/Phases/Phase1/Two_ended_chain/damping/two_way/step_error/ntr=100000_btr=256_bge=100_date=021520_stepError_seed=5/Saves/model.ckpt

# %% [markdown]
# ## Load Model (Optional)

# %%
saver.restore(sess,os.path.join(path_saves)+"/model.ckpt")

var = [v for v in tf.trainable_variables() if v.name == 'MLPGraphNetwork/graph_network/edge_block/mlp/linear_0/w:0']
post_restore_np = sess.run(var)
print(np.array(post_restore_np))
# Out:
# INFO:tensorflow:Restoring parameters from /home/bence/git_workspace/Dyadic_Collaboration/Graph_Networks/Phases/Phase1/Two_ended_chain/Saves/ntr=3000_btr=256_bge=100date=020620/model.ckpt
# [[[-0.03615981  0.08480582  0.05031766 ...  0.00408229  0.15642138
#    -0.04161644]
#   [ 0.0719505  -0.01148265 -0.0835845  ...  0.10142673  0.12743555
#     0.00599778]
#   [-0.10257607  0.10264786  0.04341802 ...  0.06374927  0.1320276
#     0.04256159]
#   ...
#   [-0.00689922  0.05856967  0.15907852 ...  0.07085051  0.09101491
#    -0.14054282]
#   [ 0.06527713  0.02646459 -0.02397825 ... -0.0045441   0.01278247
#    -0.02234338]
#   [ 0.04215148 -0.15728731 -0.13071597 ... -0.15650336 -0.01082023
#     0.13159135]]]

# %% [markdown]
# ## Save Trajectories

# %%
#Describe the experiment


def get_node_trajectories(rollout_array, batch_size):
    return np.split(rollout_array[..., :2], batch_size, axis=1)

#Store the data
true_rollouts_4 = get_node_trajectories(test_values["true_rollout_4"],batch_size_ge)
true_trajectory_4_np = np.array(true_rollouts_4)

predicted_rollouts_4 = get_node_trajectories(test_values["predicted_rollout_4"],batch_size_ge)
predicted_trajectory_4_np=np.array(predicted_rollouts_4)

true_rollouts_7 = get_node_trajectories(test_values["true_rollout_7"],batch_size_ge)
true_trajectory_7_np = np.array(true_rollouts_7)

predicted_rollouts_7 = get_node_trajectories(test_values["predicted_rollout_7"],batch_size_ge)
predicted_trajectory_7_np=np.array(predicted_rollouts_7)

true_rollouts_11 = get_node_trajectories(test_values["true_rollout_11"],batch_size_ge)
true_trajectory_11_np = np.array(true_rollouts_11)

predicted_rollouts_11 = get_node_trajectories(test_values["predicted_rollout_11"],batch_size_ge)
predicted_trajectory_11_np=np.array(predicted_rollouts_11)


l_names = ["true_trajectory_4.npy",
           "predicted_trajectory_4.npy",
           "true_trajectory_7.npy",
           "predicted_trajectory_7.npy",
           "true_trajectory_11.npy",
           "predicted_trajectory_11.npy"]

l_data = [true_trajectory_4_np,
          predicted_trajectory_4_np,
          true_trajectory_7_np,
          predicted_trajectory_7_np,
          true_trajectory_11_np,
          predicted_trajectory_11_np]


for fname, fdata in zip(l_names,l_data):
    if os.path.exists(os.path.join(path_saves, fname)):
        print("The file: "+ fname + "already exists. Delete it before saving a new trajectory!")
    else:
        if not os.path.exists(os.path.join(path_saves)):
            os.mkdir(os.path.join(path_saves)) 
        np.save(os.path.join(path_saves, fname), fdata)

# %%
# Choose a simulated system
index_of_simulated_system = -1

spring_const = spring_constants_tr[index_of_simulated_system]
damping_ratio = damping_ratios_tr[index_of_simulated_system]

true_trajectory_4_np = true_trajectory_4_np[index_of_simulated_system]
predicted_trajectory_4_np = predicted_trajectory_4_np[index_of_simulated_system]
true_trajectory_7_np = true_trajectory_7_np[index_of_simulated_system]
predicted_trajectory_7_np = predicted_trajectory_7_np[index_of_simulated_system]
true_trajectory_11_np = true_trajectory_11_np[index_of_simulated_system]
predicted_trajectory_11_np = predicted_trajectory_11_np[index_of_simulated_system]

# %% [markdown]
# ## Plot and Save Convergence plot

# %%
fig = plt.figure(1, figsize=(16, 3))
fig.clf()
x = np.array(logged_iterations)



if os.path.exists(os.path.join(path_saves, "logged_iterations")):
    print("The file: "+ "logged_iterations" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "logged_iterations"), x)
    
if os.path.exists(os.path.join(path_saves, "logged_time_steps")):
    print("The file: "+ "logged_time_steps" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "logged_time_steps"), logged_timesteps)
        
# Next-step Loss.
y = losses_tr
ax = fig.add_subplot(1, 4, 1)
ax.plot(x, y, "k")
ax.set_title("Next step loss: Training")

if os.path.exists(os.path.join(path_saves, "losses_tr")):
    print("The file: "+ "losses_tr" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_tr"), losses_tr)


        
# Rollout 4 loss.
y = losses_4_step_ge
ax = fig.add_subplot(1, 4, 2)
ax.plot(x, y, "k")
ax.set_title("Rollout loss: 4-mass string")

if os.path.exists(os.path.join(path_saves, "losses_4_step_ge")):
    print("The file: "+ "losses_4_step_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_4_step_ge"), losses_4_step_ge)

if os.path.exists(os.path.join(path_saves, "losses_4_ge")):
    print("The file: "+ "losses_4_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_4_ge"), losses_4_ge)


# Rollout 7 loss.
y = losses_7_step_ge
ax = fig.add_subplot(1, 4, 3)
ax.plot(x, y, "k")
ax.set_title("Rollout loss: 7-mass string")

if os.path.exists(os.path.join(path_saves, "losses_7_step_ge")):
    print("The file: "+ "losses_7_step_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_7_step_ge"), losses_7_step_ge)

if os.path.exists(os.path.join(path_saves, "losses_7_ge")):
    print("The file: "+ "losses_7_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_7_ge"), losses_7_ge)

# Rollout 11 loss.
y = losses_11_step_ge
ax = fig.add_subplot(1, 4, 4)
ax.plot(x, y, "k")
ax.set_title("Rollout loss: 11-mass string")

if os.path.exists(os.path.join(path_saves, "losses_11_step_ge")):
    print("The file: "+ "losses_11_step_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_11_step_ge"), losses_11_step_ge)    
    
if os.path.exists(os.path.join(path_saves, "losses_11_ge")):
    print("The file: "+ "losses_11_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_11_ge"), losses_11_ge)   

plt.show()
#batch_size_tr = 256
#batch_size_ge = 100
        

#Save figure
if os.path.exists(os.path.join(path_plots,"ConvergencePlot.png")):
    print("The file: "+ "ConvergencePlot.png" + "already exists. Delete it before saving a new plot!")
else:
    if not os.path.exists(os.path.join(path_plots)):
        os.mkdir(os.path.join(path_plots))
                  
    fig.savefig(os.path.join(path_plots,"ConvergencePlot.png"))
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %% [markdown]
# ## Plot and Save Trajectories Error plot

# %% [markdown]
# ### Plot generated groundtruth for 4 mass system

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 4
edges = []
time_text = ax3.text(-5, 5, "Frame: "+str(0),fontsize=12)
num_nodes = true_trajectory_4_np.shape[1]
    
def init():
    for i in range(num_nodes-1):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
                     
    return edges,time_text
    
ax3.set_xlim(-6, 6)
ax3.set_ylim(-6, 6)


def animate(z):
    true_tr = true_trajectory_4_np[z]                               
    time_text.set_text("Frame: "+str(z))
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],[true_tr[left,1],true_tr[right,1]])
    legend = ax3.legend()
    return edges, legend,time_text

ax3.set_title("Trajectory: n = 4, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_4_masses.gif")):
    print("The file: "+ "ground_truth_trajectory_4_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations, "GroundTruth")):
        os.makedirs(os.path.join(path_animations, "GroundTruth"))
                  
    anim.save(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_4_masses.gif"), writer='imagemagick', fps=20)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### Plot generated groundtruth for 7 mass system

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 7
edges = []

time_text = ax3.text(-5, 5, "Frame: "+str(0),fontsize=12)
num_nodes = true_trajectory_7_np.shape[1]

def init():
    for i in range(num_nodes-1):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
                     
    return edges,time_text
    
ax3.set_xlim(-6, 6)
ax3.set_ylim(-6, 6)


def animate(z):
    true_tr = true_trajectory_7_np[z]                                
    time_text.set_text("Frame: "+str(z))        
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],
                                           [true_tr[left,1],true_tr[right,1]])
        
                     
    legend = ax3.legend()
    return legend, edges,time_text

ax3.set_title("Trajectory: n = 7, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_7_masses.gif")):
    print("The file: "+ "ground_truth_trajectory_7_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"GroundTruth")):
        os.makedirs(os.path.join(path_animations,"GroundTruth"))
                  
    anim.save(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_7_masses.gif"), writer='imagemagick', fps=20)

                     

plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### Plot generated groundtruth for 11 mass system

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 11
edges = []

time_text = ax3.text(-8, 8, "Frame: "+str(0),fontsize=12)
num_nodes = true_trajectory_11_np.shape[1]

def init():
    for i in range(num_nodes-1):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
                     
    return edges,time_text
    
ax3.set_xlim(-9, 9)
ax3.set_ylim(-9, 9)


def animate(z):
    true_tr = true_trajectory_11_np[z]                                
    time_text.set_text("Frame: "+str(z))        
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],
                                           [true_tr[left,1],true_tr[right,1]])
        
                     
    legend = ax3.legend()
    return legend, edges,time_text

ax3.set_title("Trajectory: n = 11, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_11_masses.gif")):
    print("The file: "+ "ground_truth_trajectory_11_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"GroundTruth")):
        os.makedirs(os.path.join(path_animations,"GroundTruth"))
                  
    anim.save(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_11_masses.gif"), writer='imagemagick', fps=20)

                     

plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### 4 masses

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 4

edges = []
edges1 = []

time_text = ax3.text(-5, 5, "Frame: "+str(0),fontsize=12)
num_nodes = true_trajectory_4_np.shape[1]
    
def init():
    for i in range(num_nodes-1):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k",label="Prediction"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k"))
    return edges,edges1,time_text
    
ax3.set_xlim(-6, 6)
ax3.set_ylim(-6, 6)


def animate(z):
    
    true_tr = true_trajectory_4_np[z]
    pred_tr = predicted_trajectory_4_np[z]                              
    time_text.set_text("Frame: "+str(z))
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],[true_tr[left,1],true_tr[right,1]])
        edges1[i][0].set_data([pred_tr[left,0],pred_tr[right,0]],[pred_tr[left,1],pred_tr[right,1]])
        
    legend = ax3.legend()
    return legend,edges,edges1,time_text


ax3.set_title("Rollout Trajectory: n = 4, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"FullRollout","trajectory_4_masses.gif")):
    print("The file: "+ "trajectory_4_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"FullRollout")):
        os.mkdir(os.path.join(path_animations,"FullRollout"))
                  
    anim.save(os.path.join(path_animations,"FullRollout","trajectory_4_masses.gif"), writer='imagemagick', fps=20)

               
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### 7 masses

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 7
edges = []
edges1 = []

num_nodes = true_trajectory_7_np.shape[1]
time_text = ax3.text(-5, 5, "Frame: "+str(0),fontsize=12)
    
def init():
    for i in range(num_nodes):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k",label="Prediction"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k"))
    return edges,edges1,time_text
    
ax3.set_xlim(-6, 6)
ax3.set_ylim(-6, 6)


def animate(z):
    true_tr = true_trajectory_7_np[z]
    pred_tr = predicted_trajectory_7_np[z]                              
    time_text.set_text("Frame: "+str(z))
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],[true_tr[left,1],true_tr[right,1]])
        edges1[i][0].set_data([pred_tr[left,0],pred_tr[right,0]],[pred_tr[left,1],pred_tr[right,1]])
    legend = ax3.legend()
    return edges,edges1,legend,time_text




ax3.set_title("Rollout Trajectory: n = 7, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"FullRollout","trajectory_7_msses.gif")):
    print("The file: "+ "trajectory_7_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"FullRollout")):
        os.mkdir(os.path.join(path_animations,"FullRollout"))
                  
    anim.save(os.path.join(path_animations,"FullRollout","trajectory_7_masses.gif"), writer='imagemagick', fps=20)

    
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### 11 masses

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 11
edges = []
edges1 = []

num_nodes = true_trajectory_11_np.shape[1]
time_text = ax3.text(-8, 8, "Frame: "+str(0),fontsize=12)
    
def init():
    for i in range(num_nodes):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k",label="Prediction"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k"))
    return edges,edges1,time_text
    
ax3.set_xlim(-9, 9)
ax3.set_ylim(-9, 9)


def animate(z):
    true_tr = true_trajectory_11_np[z]
    pred_tr = predicted_trajectory_11_np[z]                              
    time_text.set_text("Frame: "+str(z))
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],[true_tr[left,1],true_tr[right,1]])
        edges1[i][0].set_data([pred_tr[left,0],pred_tr[right,0]],[pred_tr[left,1],pred_tr[right,1]])
    legend = ax3.legend()
    return edges,edges1,legend,time_text




ax3.set_title("Rollout Trajectory: n = 11, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"FullRollout","trajectory_11_msses.gif")):
    print("The file: "+ "trajectory_11_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"FullRollout")):
        os.mkdir(os.path.join(path_animations,"FullRollout"))
                  
    anim.save(os.path.join(path_animations,"FullRollout","trajectory_11_masses.gif"), writer='imagemagick', fps=20)

    
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">
