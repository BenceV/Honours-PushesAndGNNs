# %%
# %matplotlib notebook
import numpy as np
import os
import sys
from matplotlib import pyplot as plt
#from matplotlib import animation
#Path to the scripts shared troughout phases
parent_path=os.path.abspath('..')
path_common =  '/'.join(parent_path.split('/')[:-1])
save_path = os.path.join(parent_path,'Two_ended_chain','Plots','Damping','rollout_performance')
if(not os.path.exists(save_path)):
    os.makedirs(save_path)

# %%
basis_path = os.path.join(parent_path,'Two_ended_chain','damping')
one_basis = os.path.join(basis_path,'one_way','step_error')

means_4_one = []
means_7_one = []
means_11_one = []

means_4_one_fix = []
means_7_one_fix = []
means_11_one_fix = []

for folder in os.listdir(one_basis):
    path_to_saves = os.path.join(one_basis,folder,'Saves')
    pred_4 = np.load(os.path.join(path_to_saves,'predicted_trajectory_4.npy'))
    true_4 = np.load(os.path.join(path_to_saves,'true_trajectory_4.npy'))
    pred_7 = np.load(os.path.join(path_to_saves,'predicted_trajectory_7.npy'))
    true_7 = np.load(os.path.join(path_to_saves,'true_trajectory_7.npy'))
    pred_11 = np.load(os.path.join(path_to_saves,'predicted_trajectory_11.npy'))
    true_11 = np.load(os.path.join(path_to_saves,'true_trajectory_11.npy'))
    
    mean_4 = np.square(pred_4 - true_4) # Difference in x and y
    mean_4 = np.sum(mean_4,axis=-1) # Distance between the nodes
    mean_4_fix = mean_4[:,:,[0,-1]]
    mean_4 = np.sum(mean_4,axis=-1) # Sum distance between the nodes
    mean_4 = np.mean(mean_4,axis=0) # Average of the average distance in many graphs at a timestep
    means_4_one.append(mean_4)
    mean_4_fix = np.sum(mean_4_fix,axis=-1) # Sum distance between the nodes
    mean_4_fix = np.mean(mean_4_fix,axis=0) # Average of the average distance in many graphs at a timestep
    means_4_one_fix.append(mean_4_fix)
    
    mean_7 = np.square(pred_7 - true_7)
    mean_7 = np.sum(mean_7,axis=-1)
    mean_7_fix = mean_7[:,:,[0,-1]]
    mean_7 = np.sum(mean_7,axis=-1)
    mean_7 = np.mean(mean_7,axis=0)
    means_7_one.append(mean_7)
    mean_7_fix = np.sum(mean_7_fix,axis=-1) # Sum distance between the nodes
    mean_7_fix = np.mean(mean_7_fix,axis=0) # Average of the average distance in many graphs at a timestep
    means_7_one_fix.append(mean_7_fix)
    
    mean_11 = np.square(pred_11 - true_11)
    mean_11 = np.sum(mean_11,axis=-1)
    mean_11_fix = mean_11[:,:,[0,-1]]
    mean_11 = np.sum(mean_11,axis=-1)
    mean_11 = np.mean(mean_11,axis=0)
    means_11_one.append(mean_11)
    mean_11_fix = np.sum(mean_11_fix,axis=-1) # Sum distance between the nodes
    mean_11_fix = np.mean(mean_11_fix,axis=0) # Average of the average distance in many graphs at a timestep
    means_11_one_fix.append(mean_11_fix)


means_4_one = np.array(means_4_one)
means_7_one = np.array(means_7_one)
means_11_one = np.array(means_11_one)

means_4_one_fix = np.array(means_4_one_fix)
means_7_one_fix = np.array(means_7_one_fix)
means_11_one_fix = np.array(means_11_one_fix)
"""
means_4_two = []
means_7_two = []
means_11_two = []
    
means_4_two_fix = []
means_7_two_fix = []
means_11_two_fix = []

two_basis = os.path.join(basis_path,'two_way','step_error')
for folder in os.listdir(two_basis):
    path_to_saves = os.path.join(two_basis,folder,'Saves')
    pred_4 = np.load(os.path.join(path_to_saves,'predicted_trajectory_4.npy'))
    true_4 = np.load(os.path.join(path_to_saves,'true_trajectory_4.npy'))
    pred_7 = np.load(os.path.join(path_to_saves,'predicted_trajectory_7.npy'))
    true_7 = np.load(os.path.join(path_to_saves,'true_trajectory_7.npy'))
    pred_11 = np.load(os.path.join(path_to_saves,'predicted_trajectory_11.npy'))
    true_11 = np.load(os.path.join(path_to_saves,'true_trajectory_11.npy'))
    
    mean_4 = np.square(pred_4 - true_4) # Difference in x and y
    mean_4 = np.sum(mean_4,axis=-1) # Distance between the nodes
    mean_4_fix = mean_4[:,:,[0,-1]]
    mean_4 = np.sum(mean_4,axis=-1) # Sum distance between the nodes
    mean_4 = np.mean(mean_4,axis=0) # Average of the sum distance in many graphs at a timestep
    means_4_two.append(mean_4)
    mean_4_fix = np.sum(mean_4_fix,axis=-1) # Sum distance between the nodes
    mean_4_fix = np.mean(mean_4_fix,axis=0) # Average of the average distance in many graphs at a timestep
    means_4_two_fix.append(mean_4_fix)
    
    mean_7 = np.square(pred_7 - true_7)
    mean_7 = np.sum(mean_7,axis=-1)
    mean_7_fix = mean_7[:,:,[0,-1]]
    mean_7 = np.sum(mean_7,axis=-1)
    mean_7 = np.mean(mean_7,axis=0)
    means_7_two.append(mean_7)
    mean_7_fix = np.sum(mean_7_fix,axis=-1) # Sum distance between the nodes
    mean_7_fix = np.mean(mean_7_fix,axis=0) # Average of the average distance in many graphs at a timestep
    means_7_two_fix.append(mean_7_fix)
    
    mean_11 = np.square(pred_11 - true_11)
    mean_11 = np.sum(mean_11,axis=-1)
    mean_11_fix = mean_11[:,:,[0,-1]]
    mean_11 = np.sum(mean_11,axis=-1)
    mean_11 = np.mean(mean_11,axis=0)
    means_11_two.append(mean_11)
    mean_11_fix = np.sum(mean_11_fix,axis=-1) # Sum distance between the nodes
    mean_11_fix = np.mean(mean_11_fix,axis=0) # Average of the average distance in many graphs at a timestep
    means_11_two_fix.append(mean_11_fix)

means_4_two = np.array(means_4_two)
means_7_two = np.array(means_7_two)
means_11_two = np.array(means_11_two)
means_4_two_fix = np.array(means_4_two_fix)
means_7_two_fix = np.array(means_7_two_fix)
means_11_two_fix = np.array(means_11_two_fix)
"""
# Out:
# "\nmeans_4_two = []\nmeans_7_two = []\nmeans_11_two = []\n    \nmeans_4_two_fix = []\nmeans_7_two_fix = []\nmeans_11_two_fix = []\n\ntwo_basis = os.path.join(basis_path,'two_way','step_error')\nfor folder in os.listdir(two_basis):\n    path_to_saves = os.path.join(two_basis,folder,'Saves')\n    pred_4 = np.load(os.path.join(path_to_saves,'predicted_trajectory_4.npy'))\n    true_4 = np.load(os.path.join(path_to_saves,'true_trajectory_4.npy'))\n    pred_7 = np.load(os.path.join(path_to_saves,'predicted_trajectory_7.npy'))\n    true_7 = np.load(os.path.join(path_to_saves,'true_trajectory_7.npy'))\n    pred_11 = np.load(os.path.join(path_to_saves,'predicted_trajectory_11.npy'))\n    true_11 = np.load(os.path.join(path_to_saves,'true_trajectory_11.npy'))\n    \n    mean_4 = np.square(pred_4 - true_4) # Difference in x and y\n    mean_4 = np.sum(mean_4,axis=-1) # Distance between the nodes\n    mean_4_fix = mean_4[:,:,[0,-1]]\n    mean_4 = np.sum(mean_4,axis=-1) # Sum distance between the 
# ...

# %%
one_way_ge_mean = np.mean(means_7_one,axis = 0)
one_way_ge_std = np.std(means_7_one,axis = 0)

#two_way_ge_mean = np.mean(means_7_two,axis = 0)
#two_way_ge_std = np.std(means_7_two,axis = 0)

x = list(range(len(one_way_ge_mean)))
y1 = one_way_ge_mean
e1 = one_way_ge_std
#y2 = two_way_ge_mean
#e2 = two_way_ge_std

plt.close('all')
fig = plt.figure(1, figsize=(18, 6))
fig.clf()
ax = fig.add_subplot(1, 3, 1)
#ax.plot(x, y2, "r",label="Two way edge")
#plt.fill_between(x, y2-e2, y2+e2, color = "r",alpha=0.4)
ax.plot(x, y1, "b")
plt.fill_between(x, y1-e1, y1+e1, color = "b",alpha=0.4)

ax.set_title("Testing: 7 nodes, Position error over time:")
ax.set_xlabel("time steps (0.1s)")
ax.set_ylabel("MSE")
ax.set_xlim([0,15])


one_way_ge_mean = np.mean(means_4_one,axis = 0)
one_way_ge_std = np.std(means_4_one,axis = 0)

#two_way_ge_mean = np.mean(means_4_two,axis = 0)
#two_way_ge_std = np.std(means_4_two,axis = 0)

x = list(range(len(one_way_ge_mean)))
y1 = one_way_ge_mean
e1 = one_way_ge_std
#y2 = two_way_ge_mean
#e2 = two_way_ge_std

ax1 = fig.add_subplot(1, 3, 2)
#ax.plot(x, y2, "r",label="Two way edge")
#plt.fill_between(x, y2-e2, y2+e2, color = "r",alpha=0.4)
ax1.plot(x, y1, "b",label="mean")
plt.fill_between(x, y1-e1, y1+e1, color = "b",alpha=0.4,label="One standard deviation")

ax1.set_title("Generalisation: 4 nodes, Position error over time:")
ax1.set_xlabel("time steps (0.1s)")
ax1.set_ylabel("MSE")
ax1.set_xlim([0,15])
ax1.set_ylim([-0.3,0.3])

one_way_ge_mean = np.mean(means_11_one,axis = 0)
one_way_ge_std = np.std(means_11_one,axis = 0)

#two_way_ge_mean = np.mean(means_11_two,axis = 0)
#two_way_ge_std = np.std(means_11_two,axis = 0)

x = list(range(len(one_way_ge_mean)))
y1 = one_way_ge_mean
e1 = one_way_ge_std
#y2 = two_way_ge_mean
#e2 = two_way_ge_std

ax2 = fig.add_subplot(1, 3, 3)
#ax.plot(x, y2, "r",label="Two way edge")
#plt.fill_between(x, y2-e2, y2+e2, color = "r",alpha=0.4)
ax2.plot(x, y1, "b")
plt.fill_between(x, y1-e1, y1+e1, color = "b",alpha=0.4)

ax2.set_title("Generalisation: 11 nodes, Position error over time:")
ax2.set_xlabel("time steps (0.1s)")
ax2.set_ylabel("MSE")
ax2.set_xlim([0,15])
ax2.set_ylim([-0.01,50])

fig.legend()
fig.suptitle("Mean squared error over a fully model based rollout over 15 timesteps")
plt.show()
#Save figure                  
fig.savefig(os.path.join(save_path,"Prediction_errors_standard_Error.pdf"))
# Out:
# <img src="data:image/png;base64,..." width="1800">

# %%
one_way_ge_mean = np.mean(means_7_one_fix,axis = 0)
one_way_ge_std = np.std(means_7_one_fix,axis = 0)

two_way_ge_mean = np.mean(means_7_two_fix,axis = 0)
two_way_ge_std = np.std(means_7_two_fix,axis = 0)

x = list(range(len(one_way_ge_mean)))
y1 = one_way_ge_mean
e1 = one_way_ge_std
y2 = two_way_ge_mean
e2 = two_way_ge_std

plt.close('all')
fig = plt.figure(1, figsize=(18, 6))
fig.clf()
ax = fig.add_subplot(1, 3, 1)
ax.plot(x, y2, "r",label="Two way edge")
plt.fill_between(x, y2-e2, y2+e2, color = "r",alpha=0.4)
ax.plot(x, y1, "b",label="One way edge")
plt.fill_between(x, y1-e1, y1+e1, color = "b",alpha=0.4)

ax.legend()
ax.set_title("Testing, Position error over time:")
ax.set_xlabel("time steps (0.1s)")


one_way_ge_mean = np.mean(means_4_one_fix,axis = 0)
one_way_ge_std = np.std(means_4_one_fix,axis = 0)

two_way_ge_mean = np.mean(means_4_two_fix,axis = 0)
two_way_ge_std = np.std(means_4_two_fix,axis = 0)

x = list(range(len(one_way_ge_mean)))
y1 = one_way_ge_mean
e1 = one_way_ge_std
y2 = two_way_ge_mean
e2 = two_way_ge_std

ax = fig.add_subplot(1, 3, 2)
ax.plot(x, y2, "r",label="Two way edge")
plt.fill_between(x, y2-e2, y2+e2, color = "r",alpha=0.4)
ax.plot(x, y1, "b",label="One way edge")
plt.fill_between(x, y1-e1, y1+e1, color = "b",alpha=0.4)

ax.legend()
ax.set_title("Generalisation: 4 nodes, Position error over time:")
ax.set_xlabel("time steps (0.1s)")

one_way_ge_mean = np.mean(means_11_one_fix,axis = 0)
one_way_ge_std = np.std(means_11_one_fix,axis = 0)

two_way_ge_mean = np.mean(means_11_two_fix,axis = 0)
two_way_ge_std = np.std(means_11_two_fix,axis = 0)

x = list(range(len(one_way_ge_mean)))
y1 = one_way_ge_mean
e1 = one_way_ge_std
y2 = two_way_ge_mean
e2 = two_way_ge_std

ax = fig.add_subplot(1, 3, 3)
ax.plot(x, y2, "r",label="Two way edge")
plt.fill_between(x, y2-e2, y2+e2, color = "r",alpha=0.4)
ax.plot(x, y1, "b",label="One way edge")
plt.fill_between(x, y1-e1, y1+e1, color = "b",alpha=0.4)

ax.legend()
ax.set_title("Generalisation: 11 nodes, Position error over time:")
ax.set_xlabel("time steps (0.1s)")



plt.show()
#Save figure                  
fig.savefig(os.path.join(save_path,"Prediction_errors_fixed_only.pdf"))
# Out:
# <img src="data:image/png;base64,..." width="1800">
