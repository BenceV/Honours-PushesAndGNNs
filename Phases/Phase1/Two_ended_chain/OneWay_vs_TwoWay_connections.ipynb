# %%
# %matplotlib notebook
import numpy as np
import os
import sys
from matplotlib import pyplot as plt
#from matplotlib import animation

# %%
#Path to the scripts shared troughout phases
parent_path=os.path.abspath('..')
path_common =  '/'.join(parent_path.split('/')[:-1])
save_path = os.path.join(parent_path,'Two_ended_chain','Plots')


# Load test results seed = 1
twoway = os.path.join(parent_path,'Two_ended_chain','damping','two_way')
path_saves_twoway = os.path.join(twoway,'ntr=100000_btr=256_bge=100date=021120_seed=1','Saves')
oneway = os.path.join(parent_path,'Two_ended_chain','damping','one_way')
path_saves_oneway = os.path.join(oneway,'ntr=100000_btr=256_bge=100date=021120_seed=1','Saves')

one_way_loss_tr_1 = np.load(os.path.join(path_saves_oneway,'losses_tr.npy'))
two_way_loss_tr_1 = np.load(os.path.join(path_saves_twoway,'losses_tr.npy'))
one_way_loss_ge_1 = np.load(os.path.join(path_saves_oneway,'losses_4_ge.npy'))
two_way_loss_ge_1 = np.load(os.path.join(path_saves_twoway,'losses_4_ge.npy'))
one_way_loss_ts_1 = np.load(os.path.join(path_saves_oneway,'losses_9_ge.npy'))
two_way_loss_ts_1 = np.load(os.path.join(path_saves_twoway,'losses_9_ge.npy'))
one_way_logged_1 = np.load(os.path.join(path_saves_oneway,'Logged_Iterations.npy'))
two_way_logged_1 = np.load(os.path.join(path_saves_twoway,'Logged_Iterations.npy'))


# Load test results seed = 2
twoway = os.path.join(parent_path,'Two_ended_chain','damping','two_way')
path_saves_twoway = os.path.join(twoway,'ntr=100000_btr=256_bge=100date=021220_seed=2','Saves')
oneway = os.path.join(parent_path,'Two_ended_chain','damping','one_way')
path_saves_oneway = os.path.join(oneway,'ntr=100000_btr=256_bge=100date=021220_seed=2','Saves')

one_way_loss_tr_2 = np.load(os.path.join(path_saves_oneway,'losses_tr.npy'))
two_way_loss_tr_2 = np.load(os.path.join(path_saves_twoway,'losses_tr.npy'))
one_way_loss_ge_2 = np.load(os.path.join(path_saves_oneway,'losses_4_ge.npy'))
two_way_loss_ge_2 = np.load(os.path.join(path_saves_twoway,'losses_4_ge.npy'))
one_way_loss_ts_2 = np.load(os.path.join(path_saves_oneway,'losses_9_ge.npy'))
two_way_loss_ts_2 = np.load(os.path.join(path_saves_twoway,'losses_9_ge.npy'))
one_way_logged_2 = np.load(os.path.join(path_saves_oneway,'Logged_Iterations.npy'))
two_way_logged_2 = np.load(os.path.join(path_saves_twoway,'Logged_Iterations.npy'))


# Load test results seed = 3
twoway = os.path.join(parent_path,'Two_ended_chain','damping','two_way')
path_saves_twoway = os.path.join(twoway,'ntr=100000_btr=256_bge=100date=021220_seed=3','Saves')
oneway = os.path.join(parent_path,'Two_ended_chain','damping','one_way')
path_saves_oneway = os.path.join(oneway,'ntr=100000_btr=256_bge=100date=021220_seed=3','Saves')

one_way_loss_tr_3 = np.load(os.path.join(path_saves_oneway,'losses_tr.npy'))
two_way_loss_tr_3 = np.load(os.path.join(path_saves_twoway,'losses_tr.npy'))
one_way_loss_ge_3 = np.load(os.path.join(path_saves_oneway,'losses_4_ge.npy'))
two_way_loss_ge_3 = np.load(os.path.join(path_saves_twoway,'losses_4_ge.npy'))
one_way_loss_ts_3 = np.load(os.path.join(path_saves_oneway,'losses_9_ge.npy'))
two_way_loss_ts_3 = np.load(os.path.join(path_saves_twoway,'losses_9_ge.npy'))
one_way_logged_3 = np.load(os.path.join(path_saves_oneway,'Logged_Iterations.npy'))
two_way_logged_3 = np.load(os.path.join(path_saves_twoway,'Logged_Iterations.npy'))


# Load test results seed = 4
twoway = os.path.join(parent_path,'Two_ended_chain','damping','two_way')
path_saves_twoway = os.path.join(twoway,'ntr=100000_btr=256_bge=100date=021220_seed=4','Saves')
oneway = os.path.join(parent_path,'Two_ended_chain','damping','one_way')
path_saves_oneway = os.path.join(oneway,'ntr=100000_btr=256_bge=100date=021220_seed=4','Saves')

one_way_loss_tr_4 = np.load(os.path.join(path_saves_oneway,'losses_tr.npy'))
two_way_loss_tr_4 = np.load(os.path.join(path_saves_twoway,'losses_tr.npy'))
one_way_loss_ge_4 = np.load(os.path.join(path_saves_oneway,'losses_4_ge.npy'))
two_way_loss_ge_4 = np.load(os.path.join(path_saves_twoway,'losses_4_ge.npy'))
one_way_loss_ts_4 = np.load(os.path.join(path_saves_oneway,'losses_9_ge.npy'))
two_way_loss_ts_4 = np.load(os.path.join(path_saves_twoway,'losses_9_ge.npy'))
one_way_logged_4 = np.load(os.path.join(path_saves_oneway,'Logged_Iterations.npy'))
two_way_logged_4 = np.load(os.path.join(path_saves_twoway,'Logged_Iterations.npy'))


# Load test results seed = 5
twoway = os.path.join(parent_path,'Two_ended_chain','damping','two_way')
path_saves_twoway = os.path.join(twoway,'ntr=100000_btr=256_bge=100date=021220_seed=5','Saves')
oneway = os.path.join(parent_path,'Two_ended_chain','damping','one_way')
path_saves_oneway = os.path.join(oneway,'ntr=100000_btr=256_bge=100date=021220_seed=5','Saves')

one_way_loss_tr_5 = np.load(os.path.join(path_saves_oneway,'losses_tr.npy'))
two_way_loss_tr_5 = np.load(os.path.join(path_saves_twoway,'losses_tr.npy'))
one_way_loss_ge_5 = np.load(os.path.join(path_saves_oneway,'losses_4_ge.npy'))
two_way_loss_ge_5 = np.load(os.path.join(path_saves_twoway,'losses_4_ge.npy'))
one_way_loss_ts_5 = np.load(os.path.join(path_saves_oneway,'losses_9_ge.npy'))
two_way_loss_ts_5 = np.load(os.path.join(path_saves_twoway,'losses_9_ge.npy'))
one_way_logged_5 = np.load(os.path.join(path_saves_oneway,'Logged_Iterations.npy'))
two_way_logged_5 = np.load(os.path.join(path_saves_twoway,'Logged_Iterations.npy'))

# %%
def combine_list(dict_avg,indr,valr,n):
    
    for e, v in zip(indr,valr):
        es = [e+i for i in range(-250,250)]
        is_not_in = True
        is_in = 0
        
        for ex in es:
            if ex in dict_avg.keys():
                is_not_in = False
                is_in = ex
        
        if is_not_in:
            dict_avg[e] = v
        else:
            dict_avg[is_in] = dict_avg[is_in] + (v - dict_avg[is_in])/n
            
    return dict_avg


def do_help(dict_avg,l,v):
    dict_avg[l]=v 
    return dict_avg

# %%
dict_avgs_one_tr = dict(zip(one_way_logged_1, one_way_loss_tr_1))
dict_avgs_two_tr = dict(zip(two_way_logged_1, two_way_loss_tr_1))


#dict_avgs_one_tr = combine_list(dict_avgs_one_tr,one_way_logged_1,one_way_loss_tr_1,1)
dict_avgs_one_tr = combine_list(dict_avgs_one_tr,one_way_logged_2,one_way_loss_tr_2,2)
dict_avgs_one_tr = combine_list(dict_avgs_one_tr,one_way_logged_3,one_way_loss_tr_3,3)
dict_avgs_one_tr = combine_list(dict_avgs_one_tr,one_way_logged_4,one_way_loss_tr_4,4)
dict_avgs_one_tr = combine_list(dict_avgs_one_tr,one_way_logged_5,one_way_loss_tr_5,5)

#dict_avgs_two_tr = combine_list(dict_avgs_two_tr,two_way_logged_1,two_way_loss_tr_1,1)
dict_avgs_two_tr = combine_list(dict_avgs_two_tr,two_way_logged_2,two_way_loss_tr_2,2)
dict_avgs_two_tr = combine_list(dict_avgs_two_tr,two_way_logged_3,two_way_loss_tr_3,3)
dict_avgs_two_tr = combine_list(dict_avgs_two_tr,two_way_logged_4,two_way_loss_tr_4,4)
dict_avgs_two_tr = combine_list(dict_avgs_two_tr,two_way_logged_5,two_way_loss_tr_5,5)

# %%
plt.close('all')
fig = plt.figure(1, figsize=(18, 6))
fig.clf()

ax = fig.add_subplot(1, 1, 1)
ks = list(dict_avgs_two_tr.keys())
vs = list(dict_avgs_two_tr.values())
ax.plot(ks, np.log(vs), "r",label="Two way edge")
ks = list(dict_avgs_one_tr.keys())
vs = list(dict_avgs_one_tr.values())
ax.plot(ks, np.log(vs), "b",label="One way edge")
ax.legend()
ax.set_title("Next step loss: Training")
ax.set_xlabel("")
plt.show()

#Save figure                  
fig.savefig(os.path.join(save_path,"ConvergencePlots_avg_tr_log_scale.png"))
# Out:
# <img src="data:image/png;base64,..." width="1800">

# %%
dict_avgs_one_ge = dict(zip(one_way_logged_1, one_way_loss_ge_1))
dict_avgs_two_ge = dict(zip(two_way_logged_1, two_way_loss_ge_1))


#dict_avgs_one_ge = combine_list(dict_avgs_one_ge,one_way_logged_1,one_way_loss_ge_1,1)
dict_avgs_one_ge = combine_list(dict_avgs_one_ge,one_way_logged_2,one_way_loss_ge_2,2)
dict_avgs_one_ge = combine_list(dict_avgs_one_ge,one_way_logged_3,one_way_loss_ge_3,3)
dict_avgs_one_ge = combine_list(dict_avgs_one_ge,one_way_logged_4,one_way_loss_ge_4,4)
dict_avgs_one_ge = combine_list(dict_avgs_one_ge,one_way_logged_5,one_way_loss_ge_5,5)

#dict_avgs_two_ge = combine_list(dict_avgs_two_ge,two_way_logged_1,two_way_loss_ge_1,1)
dict_avgs_two_ge = combine_list(dict_avgs_two_ge,two_way_logged_2,two_way_loss_ge_2,2)
dict_avgs_two_ge = combine_list(dict_avgs_two_ge,two_way_logged_3,two_way_loss_ge_3,3)
dict_avgs_two_ge = combine_list(dict_avgs_two_ge,two_way_logged_4,two_way_loss_ge_4,4)
dict_avgs_two_ge = combine_list(dict_avgs_two_ge,two_way_logged_5,two_way_loss_ge_5,5)

# %%
plt.close('all')
fig = plt.figure(1, figsize=(18, 6))
fig.clf()

ax = fig.add_subplot(1, 1, 1)
ks = list(dict_avgs_two_ge.keys())
vs = list(dict_avgs_two_ge.values())
ax.plot(ks, vs, "r",label="Two way edge")
ks = list(dict_avgs_one_ge.keys())
vs = list(dict_avgs_one_ge.values())
ax.plot(ks, vs, "b",label="One way edge")
ax.legend()
ax.set_title("Generalisation, Full-rollout: 4 nodes")
ax.set_xlabel("")
plt.show()

#Save figure                  
fig.savefig(os.path.join(save_path,"ConvergencePlots_avg_ge.png"))
# Out:
# <img src="data:image/png;base64,..." width="1800">

# %%
dict_avgs_one_ts = dict(zip(one_way_logged_1, one_way_loss_ts_1))
dict_avgs_two_ts = dict(zip(two_way_logged_1, two_way_loss_ts_1))

#dict_avgs_one_ts = combine_list(dict_avgs_one_ts,one_way_logged_1,one_way_loss_ts_1,1)
dict_avgs_one_ts = combine_list(dict_avgs_one_ts,one_way_logged_2,one_way_loss_ts_2,2)
dict_avgs_one_ts = combine_list(dict_avgs_one_ts,one_way_logged_3,one_way_loss_ts_3,3)
dict_avgs_one_ts = combine_list(dict_avgs_one_ts,one_way_logged_4,one_way_loss_ts_4,4)
dict_avgs_one_ts = combine_list(dict_avgs_one_ts,one_way_logged_5,one_way_loss_ts_5,5)

#dict_avgs_two_ts = combine_list(dict_avgs_two_ts,two_way_logged_1,two_way_loss_ts_1,1)
dict_avgs_two_ts = combine_list(dict_avgs_two_ts,two_way_logged_2,two_way_loss_ts_2,2)
dict_avgs_two_ts = combine_list(dict_avgs_two_ts,two_way_logged_3,two_way_loss_ts_3,3)
dict_avgs_two_ts = combine_list(dict_avgs_two_ts,two_way_logged_4,two_way_loss_ts_4,4)
dict_avgs_two_ts = combine_list(dict_avgs_two_ts,two_way_logged_5,two_way_loss_ts_5,5)

# %%
plt.close('all')
fig = plt.figure(1, figsize=(18, 6))
fig.clf()

ax = fig.add_subplot(1, 1, 1)
ks = list(dict_avgs_two_ts.keys())
vs = list(dict_avgs_two_ts.values())
ax.plot(ks, vs, "r",label="Two way edge")
ks = list(dict_avgs_one_ts.keys())
vs = list(dict_avgs_one_ts.values())
ax.plot(ks, vs, "b",label="One way edge")
ax.legend()
ax.set_title("Test, Full-rollout: 9 nodes")
ax.set_xlabel("")
plt.show()

#Save figure                  
fig.savefig(os.path.join(save_path,"ConvergencePlots_avg_ts.png"))
# Out:
# <img src="data:image/png;base64,..." width="1800">
