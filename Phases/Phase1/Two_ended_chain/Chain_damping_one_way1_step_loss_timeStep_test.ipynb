# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
# %matplotlib notebook
import time
import datetime

#Save experiment begin date
current_time = datetime.datetime.now()
print("Current_date: "+str(current_time))
current_time = "".join(current_time.strftime("%x").split('/'))

#Import usual things required for graph nets
import numpy as np
import pandas as pd
import networkx as nx
import sonnet as snt
import tensorflow as tf
import os
import sys
from matplotlib import pyplot as plt
from matplotlib import animation
import seaborn as sns

#Import graph nets
from graph_nets import blocks
from graph_nets import utils_tf
from graph_nets import utils_np
from graph_nets.demos import models

#Change here
num_training_iterations = 100000
batch_size_tr = 256
batch_size_ge = 100
num_time_steps = 50

desc = "ntr="+str(num_training_iterations)
desc = desc +"_btr="+str(batch_size_tr)
desc = desc +"_bge="+str(batch_size_ge)
desc = desc +"_date="+str(current_time)
desc = desc +"_stepError_"

#Set seed
SEED = 2
desc = desc +"seed="+str(SEED)

#Path to the scripts shared troughout phases
parent_path=os.path.abspath('..')
path_common =  '/'.join(parent_path.split('/')[:-1])
path_common = os.path.join(path_common,'Common','Scripts')
#Check if path exists
if(not os.path.exists(path_common)):
    print('The path: '+ os.path.exists(path_common)+' is not found!')
#Add shared scripts to our current paths for importing
sys.path.insert(0, path_common)

base = os.path.join(parent_path,'Two_ended_chain','damping','one_way','timeStep_test')
if(not os.path.exists(base)):
    os.makedirs(base)
#Path to saved models and trajectories
path_saves = os.path.join(base,desc,'Saves')
if(not os.path.exists(path_saves)):
    os.makedirs(path_saves)
#Path to plots
path_plots = os.path.join(base,desc,'Plots')
if(not os.path.exists(path_plots)):
    os.makedirs(path_plots)
#Path to animations
path_animations = os.path.join(base,desc,'Animations')
if(not os.path.exists(path_animations)):
    os.makedirs(path_animations)



np.random.seed(SEED)
tf.set_random_seed(SEED)
# Out:
# Current_date: 2020-04-10 17:38:03.499858
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## Import functions

# %%
#Import functions for simulating
from Simulation_Functions_extended import SpringMassSimulator, generate_trajectory, roll_out_physics
#Import functions for creating graph
from Graph_creator_functions import chain_graph_extended_one_way
#Import visualisation functions

# %% [markdown]
# ## Define loss functions

# %%
def create_loss_ops(target_op, output_ops):
    """Create supervised loss operations from targets and outputs.

    Args:
        target_op: The target velocity tf.Tensor.
        output_ops: The list of output graphs from the model.

    Returns:
        A list of loss values (tf.Tensor), one per output op.""" 
    loss_ops = [
            tf.reduce_mean(
            tf.reduce_sum((tf.cast(output_op.nodes,tf.float64) - tf.cast(target_op[..., 2:4],tf.float64))**2, axis=-1))
            for output_op in output_ops
    ]
    return loss_ops


def make_all_runnable_in_session(*args):
    """Apply make_runnable_in_session to an iterable of graphs."""
    return [utils_tf.make_runnable_in_session(a) for a in args]

# %% [markdown]
# # Define the Model

# %%
tf.reset_default_graph()
# Create the model.
model = models.EncodeProcessDecode(node_output_size=2)
# Out:
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/base.py:177: The name tf.make_template is deprecated. Please use tf.compat.v1.make_template instead.
#
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/base.py:278: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/base.py:579: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.

# %% [markdown]
# # Training the Network: Chain
# ## Generate:
# - Model
# - Training trajectory 5 to 9 masses
# - Generalization trajectories: 4 mass, 7 mass and 11 mass

# %%
#@title Set up model training and evaluation  { form-width: "30%" }

# The model we explore includes three components:
# - An "Encoder" graph net, which independently encodes the edge, node, and
#   global attributes (does not compute relations etc.).
# - A "Core" graph net, which performs N rounds of processing (message-passing)
#   steps. The input to the Core is the concatenation of the Encoder's output
#   and the previous output of the Core (labeled "Hidden(t)" below, where "t" is
#   the processing step).
# - A "Decoder" graph net, which independently decodes the edge, node, and
#   global attributes (does not compute relations etc.), on each
#   message-passing step.
#
#                     Hidden(t)   Hidden(t+1)
#                        |            ^
#           *---------*  |  *------*  |  *---------*
#           |         |  |  |      |  |  |         |
# Input --->| Encoder |  *->| Core |--*->| Decoder |---> Output(t)
#           |         |---->|      |     |         |
#           *---------*     *------*     *---------*
#
# The model is trained by supervised learning. Input mass-spring systems are
# procedurally generated, where the nodes represent the positions, velocities,
# and indicators of whether the mass is fixed in space or free to move, the
# edges represent the spring constant and spring rest length, and the global
# attribute represents the variable coefficient of gravitational acceleration.
# The outputs/targets have the same structure, with the nodes representing the
# masses' next-step states.
#
# The training loss is computed on the output of each processing step. The
# reason for this is to encourage the model to try to solve the problem in as
# few steps as possible. It also helps make the output of intermediate steps
# more interpretable.
#
# There's no need for a separate evaluate dataset because the inputs are
# never repeated, so the training loss is the measure of performance on graphs
# from the input distribution.
#
# We also evaluate how well the models generalize to systems which are one mass
# larger, and smaller, than those from the training distribution. The loss is
# computed as the mean over a 50-step rollout, where each step's input is the
# the previous step's output.
#
# Variables with the suffix _tr are training parameters, and variables with the
# suffix _ge are test/generalization parameters.
#
# After around 10000-20000 training iterations the model reaches good
# performance on mass-spring systems with 5-8 masses.


rand = np.random.RandomState(SEED)

# Model parameters.
num_processing_steps_tr = 1
num_processing_steps_ge = 1

step_size = 0.1
num_masses_min_max_tr = (5, 9)
dist_between_masses_min_max_tr = (0.2, 1.0)
spring_constant_min_max_tr = (40,60)
damping_ratio_min_max_tr = (0.3,0.6)

# Data.
# Base graphs for training.
num_masses_tr = rand.randint(*num_masses_min_max_tr, size=batch_size_tr)
dist_between_masses_tr = rand.uniform(*dist_between_masses_min_max_tr, size=batch_size_tr)
spring_constants_tr = rand.randint(*spring_constant_min_max_tr, size=batch_size_tr)
damping_ratios_tr = rand.uniform(*damping_ratio_min_max_tr, size=batch_size_tr)

dict_rands = {"num_masses":num_masses_tr,
              "distances":dist_between_masses_tr,
              "spring_constants":spring_constants_tr,
              "damping_ratios":damping_ratios_tr}


if os.path.exists(os.path.join(path_saves, "training_examples")):
    print("The file: "+ "training_examples" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "training_examples"), dict_rands)
    


static_graph_tr = [chain_graph_extended_one_way(n,k,d,r) for n, d, k, r in zip(num_masses_tr,
                                                                               dist_between_masses_tr,
                                                                               spring_constants_tr,
                                                                               damping_ratios_tr)]
base_graph_tr = utils_tf.data_dicts_to_graphs_tuple(static_graph_tr)

# Base graphs for testing.
spring_constant_min_max_ge = (25,75)
damping_ratio_min_max_ge = (0.0,0.3)

spring_constants_ge = rand.randint(*spring_constant_min_max_ge, size=batch_size_ge)
damping_ratios_ge = rand.uniform(*damping_ratio_min_max_ge, size=batch_size_ge)


# 4 masses 1m apart in a chain like structure.
static_graph_4_ge = [chain_graph_extended_one_way(4, k ,0.5,r) for k, r in zip(spring_constants_ge,
                                                                               damping_ratios_ge)]
base_graph_4_ge = utils_tf.data_dicts_to_graphs_tuple(static_graph_4_ge)
    
# 7 masses 0.5m apart in a chain like structure.
static_graph_7_ge = [chain_graph_extended_one_way(7, k ,0.5,r) for k, r in zip(spring_constants_ge,
                                                                               damping_ratios_ge)]
base_graph_7_ge = utils_tf.data_dicts_to_graphs_tuple(static_graph_7_ge)

# 11 masses 0.5m apart in a chain like structure.
static_graph_11_ge = [chain_graph_extended_one_way(11, k ,0.5,r) for k, r in zip(spring_constants_ge,
                                                                               damping_ratios_ge)]
base_graph_11_ge = utils_tf.data_dicts_to_graphs_tuple(static_graph_11_ge)



# True physics simulator for data generation.
simulator = SpringMassSimulator(step_size=step_size)
# Training.
# Generate a training trajectory by adding noise to initial
# position, spring constants and gravity
initial_conditions_tr, true_trajectory_tr = generate_trajectory(
    simulator,
    base_graph_tr,
    num_time_steps,
    step_size,
    node_noise_level=0.04,
    edge_noise_level=5.0,
    global_noise_level=1.0,
    do_set_rest=True,
    do_apply_gravity=True)
# Random start step.
t = tf.random_uniform([], minval=0, maxval=num_time_steps - 1, dtype=tf.int32)
input_graph_tr = initial_conditions_tr.replace(nodes=true_trajectory_tr[t])
target_nodes_tr = true_trajectory_tr[t + 1]

output_ops_tr = model(input_graph_tr, num_processing_steps_tr)

# Test data: 4-mass string.
initial_conditions_4_ge, true_trajectory_4_ge = generate_trajectory(
    simulator,
    base_graph_4_ge,
    num_time_steps,
    step_size,
    node_noise_level=0.04,
    edge_noise_level=5.0,
    global_noise_level=1.0,
    do_set_rest=True,
    do_apply_gravity=True)

input_graph_4_ge = initial_conditions_4_ge.replace(nodes=true_trajectory_4_ge[t])
target_nodes_4_ge = true_trajectory_4_ge[t + 1]

output_ops_4_ge = model(input_graph_4_ge, num_processing_steps_ge)

_, true_nodes_rollout_4_ge = roll_out_physics(
    simulator, initial_conditions_4_ge, num_time_steps, step_size)
_, predicted_nodes_rollout_4_ge = roll_out_physics(
    lambda x: model(x, num_processing_steps_ge), initial_conditions_4_ge,
    num_time_steps, step_size)



# Test data: 7-mass string.
initial_conditions_7_ge, true_trajectory_7_ge = generate_trajectory(
    simulator,
    base_graph_7_ge,
    num_time_steps,
    step_size,
    node_noise_level=0.04,
    edge_noise_level=5.0,
    global_noise_level=1.0,
    do_set_rest=True,
    do_apply_gravity=True)

input_graph_7_ge = initial_conditions_7_ge.replace(nodes=true_trajectory_7_ge[t])
target_nodes_7_ge = true_trajectory_7_ge[t + 1]

output_ops_7_ge = model(input_graph_7_ge, num_processing_steps_ge)

_, true_nodes_rollout_7_ge = roll_out_physics(
    simulator, initial_conditions_7_ge, num_time_steps, step_size)
_, predicted_nodes_rollout_7_ge = roll_out_physics(
    lambda x: model(x, num_processing_steps_ge), initial_conditions_7_ge,
    num_time_steps, step_size)



# Test data: 11-mass string.
initial_conditions_11_ge, true_trajectory_11_ge = generate_trajectory(
    simulator,
    base_graph_11_ge,
    num_time_steps,
    step_size,
    node_noise_level=0.04,
    edge_noise_level=5.0,
    global_noise_level=1.0,
    do_set_rest=True,
    do_apply_gravity=True)
    
input_graph_11_ge = initial_conditions_11_ge.replace(nodes=true_trajectory_11_ge[t])
target_nodes_11_ge = true_trajectory_11_ge[t + 1]

output_ops_11_ge = model(input_graph_11_ge, num_processing_steps_ge)


_, true_nodes_rollout_11_ge = roll_out_physics(
    simulator, initial_conditions_11_ge, num_time_steps, step_size)
_, predicted_nodes_rollout_11_ge = roll_out_physics(
    lambda x: model(x, num_processing_steps_ge), initial_conditions_11_ge,
    num_time_steps, step_size)






# Training loss.
loss_ops_tr = create_loss_ops(target_nodes_tr, output_ops_tr)
# Training loss across processing steps.
loss_op_tr = sum(loss_ops_tr) / num_processing_steps_tr

# Test/generalization loss: 4-mass.
loss_ops_4_ge = create_loss_ops(target_nodes_4_ge,output_ops_4_ge)
loss_op_step_4_ge = sum(loss_ops_4_ge) / num_processing_steps_tr
loss_op_4_ge = tf.reduce_mean(
    tf.reduce_sum(
        (predicted_nodes_rollout_4_ge[..., 2:4] -
         true_nodes_rollout_4_ge[..., 2:4])**2,
        axis=-1))

#Test/generalization loss: 7-mass string.
loss_ops_7_ge = create_loss_ops(target_nodes_7_ge,output_ops_7_ge)
loss_op_step_7_ge = sum(loss_ops_7_ge) / num_processing_steps_ge
loss_op_7_ge = tf.reduce_mean(
    tf.reduce_sum(
        (predicted_nodes_rollout_7_ge[..., 2:4] -
         true_nodes_rollout_7_ge[..., 2:4])**2,
        axis=-1))

# Test/generalization loss: 11-mass string.
loss_ops_11_ge = create_loss_ops(target_nodes_11_ge,output_ops_11_ge)
loss_op_step_11_ge = sum(loss_ops_11_ge) / num_processing_steps_ge
loss_op_11_ge = tf.reduce_mean(
    tf.reduce_sum(
        (predicted_nodes_rollout_11_ge[..., 2:4] -
         true_nodes_rollout_11_ge[..., 2:4])**2,
        axis=-1))




# Optimizer.
learning_rate = 1e-3
optimizer = tf.train.AdamOptimizer(learning_rate)
step_op = optimizer.minimize(loss_op_tr)

input_graph_tr = make_all_runnable_in_session(input_graph_tr)
initial_conditions_4_ge = make_all_runnable_in_session(initial_conditions_4_ge)
initial_conditions_7_ge = make_all_runnable_in_session(initial_conditions_7_ge)
initial_conditions_11_ge = make_all_runnable_in_session(initial_conditions_11_ge)
# Out:
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/bence/git_workspace/Dyadic_Collaboration/Graph_Networks/Phases/Common/Scripts/Simulation_Functions_extended.py:75: The name tf.unsorted_segment_sum is deprecated. Please use tf.math.unsorted_segment_sum instead.
#
# WARNING:tensorflow:From /home/bence/git_workspace/Dyadic_Collaboration/Graph_Networks/Phases/Common/Scripts/Simulation_Functions_extended.py:185: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/basic.py:126: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/basic.py:131: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/basic.py:247: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.

# %%
print(spring_constants_ge)
print(damping_ratios_ge)
# Out:
# [45 40 58 61 40 52 28 61 41 70 33 38 50 59 55 61 45 58 60 72 34 65 70 73
#  26 35 59 26 56 69 50 37 27 32 32 44 64 32 69 57 28 55 35 56 32 33 37 71
#  48 64 52 59 43 32 36 68 39 32 68 26 31 69 72 37 41 43 51 50 29 46 69 43
#  27 58 70 25 61 68 35 39 73 29 70 29 54 37 43 27 49 61 49 27 27 33 40 40
#  62 60 62 26]
# [0.18932536 0.01326155 0.09533919 0.03311085 0.2354872  0.19118475
#  0.21329686 0.24505419 0.27489815 0.12536384 0.18459731 0.17052883
#  0.28991074 0.21262451 0.1727378  0.2576606  0.04674935 0.15626409
#  0.05651719 0.13123481 0.07913649 0.14432435 0.12508545 0.08375442
#  0.1555486  0.13422776 0.10936557 0.29341717 0.08591944 0.22805126
#  0.0220036  0.07431575 0.01384053 0.18661398 0.11010322 0.19172532
#  0.13779788 0.02294355 0.03759131 0.20145783 0.12127528 0.21096994
#  0.18324972 0.23281382 0.25014135 0.19223742 0.18830462 0.16238991
#  0.04729281 0.16649525 0.022933   0.0641046  0.18834199 0.27189232
#  0.14583428 0.16350069 0.21120434 0.29155941 0.20465056 0.223027
#  0.18872593 0.0196247  0.19205665 0.10906158 0.01708453 0.0701224
#  0.22731435 0.04232249 0.01890386 0.28441451 0.05299106 0.00381685
#  0.15814291 0.17998832 0.03321143 0.01379517 0.10641162 0.17471263
#  0.27711806 0.13819056 0.29134336 0.01958078 0.11494002 0.2114634
#  0.01687253 0.08547215 0.18321578 0.03719622 0.26229555 0.00682256
#  0.22547643 0.04490746 0.08982724 0.10137217 0.1148184  0.28589819
#  0.0101106  0.12364807 0.28548097 0.17362913]

# %% [markdown]
# ### Reset Tensorflow session, but keep the same computational graph.

# %%
#@title Reset session  { form-width: "30%" }


saver = tf.train.Saver()
# This cell resets the 
try:
    sess.close()
except NameError:
    pass
sess = tf.Session()
sess.run(tf.global_variables_initializer())

var = [v for v in tf.trainable_variables() if v.name == 'MLPGraphNetwork/graph_network/edge_block/mlp/linear_0/w:0']
pre_train_np = sess.run(var)
print(pre_train_np)


last_iteration = 0
logged_iterations = []
logged_timesteps = []
losses_tr = []
losses_4_ge = []
losses_4_step_ge = []
losses_7_ge = []
losses_7_step_ge = []
losses_11_ge = []
losses_11_step_ge = []
# Out:
# [array([[ 0.1420259 , -0.0274126 , -0.06481791, ..., -0.10165764,
#         -0.01685222,  0.1490121 ],
#        [-0.02477477,  0.01034909,  0.11981626, ..., -0.04069889,
#          0.02827128, -0.03894875],
#        [ 0.08924192,  0.02533397,  0.10092739, ..., -0.01664429,
#         -0.13110799,  0.06233411],
#        ...,
#        [ 0.01240455, -0.07139522,  0.02585906, ..., -0.05556417,
#         -0.05922392, -0.05624824],
#        [ 0.05385862, -0.13682464,  0.01329185, ...,  0.02782405,
#         -0.01023056,  0.04068496],
#        [ 0.02964506,  0.05981861, -0.00937709, ..., -0.03602629,
#         -0.05091435,  0.02708249]], dtype=float32)]

# %% [markdown]
# ### Train Network

# %%
#@title Run training  { form-width: "30%" }

# You can interrupt this cell's training loop at any time, and visualize the
# intermediate results by running the next cell (below). You can then resume
# training by simply executing this cell again.

# How much time between logging and printing the current results.
log_every_iteration = 250

print("# (iteration number), T (elapsed seconds), "
      "Ltr (training 1-step loss), "
      "Lge4 (test/generalization rollout loss for 4-mass strings), "
      "Lge9 (test/generalization rollout loss for 7-mass strings), "
      "Lge11 (test/generalization rollout loss for 11-mass strings)")

start_time = time.time()
last_log_time = start_time
for iteration in range(last_iteration, num_training_iterations):
    last_iteration = iteration
    train_values = sess.run({
        "step": step_op,
        "loss": loss_op_tr,
        "input_graph": input_graph_tr,
        "target_nodes": target_nodes_tr,
        "outputs": output_ops_tr,
        "time_step":t
    })
    if last_iteration % log_every_iteration == 0:
        
        the_time = time.time()
        elapsed_since_last_log = the_time - last_log_time
        last_log_time = the_time
        test_values = sess.run({
            "step_loss_4":loss_op_step_4_ge,
            "loss_4": loss_op_4_ge,
            "true_rollout_4": true_nodes_rollout_4_ge,
            "predicted_rollout_4": predicted_nodes_rollout_4_ge,
            "step_loss_7":loss_op_step_7_ge,
            "loss_7": loss_op_7_ge,
            "true_rollout_7": true_nodes_rollout_7_ge,
            "predicted_rollout_7": predicted_nodes_rollout_7_ge,
            "step_loss_11":loss_op_step_11_ge,
            "loss_11": loss_op_11_ge,
            "true_rollout_11": true_nodes_rollout_11_ge,
            "predicted_rollout_11": predicted_nodes_rollout_11_ge
        })
        elapsed = time.time() - start_time
        losses_tr.append(train_values["loss"])
        losses_4_ge.append(test_values["loss_4"])
        losses_4_step_ge.append(test_values["step_loss_4"])
        losses_7_ge.append(test_values["loss_7"])
        losses_7_step_ge.append(test_values["step_loss_7"])
        losses_11_ge.append(test_values["loss_11"])
        losses_11_step_ge.append(test_values["step_loss_11"])
        logged_iterations.append(iteration)
        logged_timesteps.append(train_values["time_step"])
        print("# {:05d}, T {:.1f}, Ltr {:.4f}, Lge4 {:.4f}, Lge7 {:.4f}, Lge11 {:.4f}, TimeStep {:03d}".format(
            iteration, elapsed, train_values["loss"], test_values["step_loss_4"],
            test_values["step_loss_7"],test_values["step_loss_11"],train_values["time_step"]))
# Out:
# # (iteration number), T (elapsed seconds), Ltr (training 1-step loss), Lge4 (test/generalization rollout loss for 4-mass strings), Lge9 (test/generalization rollout loss for 7-mass strings), Lge11 (test/generalization rollout loss for 11-mass strings)
# # 00000, T 2.0, Ltr 2.7239, Lge4 0.9015, Lge7 2.5177, Lge11 7.0578, TimeStep 010
# # 00250, T 7.3, Ltr 0.5182, Lge4 0.6219, Lge7 2.2701, Lge11 9.6436, TimeStep 017
# # 00500, T 12.6, Ltr 1.0742, Lge4 0.8254, Lge7 1.1331, Lge11 3.1802, TimeStep 006
# # 00750, T 17.9, Ltr 0.5768, Lge4 0.7648, Lge7 2.5099, Lge11 4.6293, TimeStep 010
# # 01000, T 23.2, Ltr 0.4058, Lge4 0.2680, Lge7 0.7792, Lge11 2.1996, TimeStep 011
# # 01250, T 28.5, Ltr 0.0801, Lge4 0.2416, Lge7 0.7882, Lge11 2.3332, TimeStep 044
# # 01500, T 33.8, Ltr 0.1104, Lge4 0.3231, Lge7 0.6962, Lge11 1.8719, TimeStep 032
# # 01750, T 39.1, Ltr 0.1125, Lge4 0.1295, Lge7 0.1459, Lge11 0.2430, TimeStep 030
# # 02000, T 44.4, Ltr 0.0551, Lge4 0.6140, Lge7 0.6973, Lge11 2.8782, TimeStep 046
# # 02250, T 49.7, Ltr 0.2551, Lge4 0.0381, Lge7 0.1319, Lge11 0.2914, TimeStep 022
# # 02500, T 55.0, Ltr 0.2626, Lge4 0.3105, Lge7 0.8073, Lge11 2.5908, TimeStep 012
# # 02750, T 60.3, Ltr 0.0409, Lge4 0.1037, Lge7 0.5273, Lge11 3.9386, TimeStep 047
# # 03000, T 65.6, Ltr 0.0906, Lge4 0.1776, Lge7 0.6094, Lge11 2.7473, TimeStep 039
# # 03250, T 70.9, Ltr 0.0600, Lge4 0.1294, Lge7 0.5425, Lge11 3.3010, TimeStep 039
# # 03500, T 76.2, Ltr 0.0694, Lge4 0.1953, Lge7 0.6623, Lge11 1.7753, TimeStep 042
# # 03750, T 81.6, Ltr 0.0603, Lge4 0.1003, Lge7 0.3791, Lge11 3.4029, TimeStep 039
# # 04000, T 86.9, Ltr 0.0986, Lge4 0.2338, Lge7 0.6939, Lge11 2.3055, TimeStep 030
# # 04250, T 92.2, Ltr 0.1681, Lge4 0.2211, Lge7 0.7443, Lge11 1.8182, TimeStep 021
# # 04500, T 97.6, Ltr 0.1490, Lge4 0.1976, Lge7 0.6097, Lge11 1.5346, TimeStep 028
# # 04750, T 102.9, Ltr 0.0890, Lge4 0.2103, Lge7 0.7984, Lge11 2.1848, TimeStep 033
# # 05000, T 108.2, Ltr 0.0645, Lge4 0.1010, Lge7 0.3881, Lge11 3.2631, TimeStep 035
# # 05250, T 113.5, Ltr 0.0396, Lge4 0.0260, Lge7 0.0111, Lge11 0.0212, TimeStep 046
# # 05500, T 118.8, Ltr 0.0182, Lge4 0.2150, Lge7 0.8193, Lge11 1.9352, TimeStep 002
# # 05750, T 124.1, Ltr 0.0382, Lge4 0.2414, Lge7 0.5525, Lge11 2.8403, TimeStep 047
# # 06000, T 129.4, Ltr 0.1378, Lge4 0.2905, Lge7 0.8374, Lge11 2.1535, TimeStep 016
# # 06250, T 134.7, Ltr 0.2895, Lge4 0.3396, Lge7 0.7564, Lge11 2.4261, TimeStep 009
# # 06500, T 140.0, Ltr 0.0618, Lge4 0.1572, Lge7 0.0360, Lge11 0.0438, TimeStep 041
# # 06750, T 145.3, Ltr 0.0308, Lge4 0.1832, Lge7 0.6780, Lge11 1.6822, TimeStep 048
# # 07000, T 150.6, Ltr 0.0604, Lge4 0.1014, Lge7 0.4514, Lge11 3.0087, TimeStep 038
# # 07250, T 155.9, Ltr 0.1545, Lge4 0.0172, Lge7 0.0230, Lge11 0.0478, TimeStep 012
# # 07500, T 161.2, Ltr 0.0683, Lge4 0.2091, Lge7 0.6684, Lge11 1.6799, TimeStep 035
# # 07750, T 166.5, Ltr 0.0703, Lge4 0.2057, Lge7 0.7636, Lge11 2.0537, TimeStep 034
# # 08000, T 171.8, Ltr 0.1326, Lge4 0.2223, Lge7 0.8008, Lge11 1.9258, TimeStep 020
# # 08250, T 177.1, Ltr 0.0537, Lge4 0.1131, Lge7 0.0609, Lge11 0.0812, TimeStep 038
# # 08500, T 182.4, Ltr 0.0420, Lge4 0.2337, Lge7 0.6242, Lge11 2.1206, TimeStep 043
# # 08750, T 187.7, Ltr 0.0547, Lge4 0.1668, Lge7 0.6266, Lge11 1.5981, TimeStep 045
# # 09000, T 193.1, Ltr 0.0187, Lge4 0.1747, Lge7 0.6455, Lge11 1.4314, TimeStep 001
# # 09250, T 198.4, Ltr 0.1387, Lge4 0.2370, Lge7 0.7842, Lge11 2.1456, TimeStep 023
# # 09500, T 203.7, Ltr 0.1547, Lge4 0.1825, Lge7 0.5993, Lge11 1.5484, TimeStep 009
# # 09750, T 209.0, Ltr 0.0514, Lge4 0.2004, Lge7 0.6796, Lge11 1.6848, TimeStep 035
# # 10000, T 214.3, Ltr 0.0240, Lge4 0.0406, Lge7 0.0138, Lge11 0.0212, TimeStep 001
# # 10250, T 219.6, Ltr 0.0739, Lge4 0.2745, Lge7 0.5481, Lge11 1.8053, TimeStep 000
# # 10500, T 224.9, Ltr 0.1053, Lge4 0.2511, Lge7 0.6846, Lge11 1.7018, TimeStep 009
# # 10750, T 230.2, Ltr 0.0985, Lge4 0.2558, Lge7 0.6501, Lge11 1.9397, TimeStep 026
# # 11000, T 235.5, Ltr 0.0270, Lge4 0.1370, Lge7 0.5827, Lge11 1.6342, TimeStep 004
# # 11250, T 240.7, Ltr 0.0255, Lge4 0.1526, Lge7 0.5145, Lge11 1.9663, TimeStep 048
# # 11500, T 246.1, Ltr 0.1031, Lge4 0.2075, Lge7 0.5525, Lge11 1.9627, TimeStep 020
# # 11750, T 251.4, Ltr 0.1204, Lge4 0.1253, Lge7 0.4602, Lge11 2.6502, TimeStep 016
# # 12000, T 256.7, Ltr 0.0366, Lge4 0.1219, Lge7 0.5618, Lge11 1.2263, TimeStep 043
# # 12250, T 262.0, Ltr 0.0278, Lge4 0.2090, Lge7 0.5776, Lge11 1.9230, TimeStep 045
# # 12500, T 267.3, Ltr 0.0447, Lge4 0.1452, Lge7 0.5383, Lge11 1.8290, TimeStep 039
# # 12750, T 272.6, Ltr 0.0635, Lge4 0.1416, Lge7 0.5452, Lge11 1.2431, TimeStep 034
# # 13000, T 277.9, Ltr 0.0219, Lge4 0.1573, Lge7 0.5706, Lge11 1.3506, TimeStep 002
# # 13250, T 283.2, Ltr 0.0960, Lge4 0.1528, Lge7 0.6182, Lge11 1.2862, TimeStep 019
# # 13500, T 288.5, Ltr 0.0493, Lge4 0.2531, Lge7 0.3799, Lge11 2.0323, TimeStep 039
# # 13750, T 293.8, Ltr 0.0459, Lge4 0.0143, Lge7 0.0122, Lge11 0.0207, TimeStep 040
# # 14000, T 299.1, Ltr 0.0984, Lge4 0.1412, Lge7 0.4858, Lge11 2.5023, TimeStep 019
# # 14250, T 304.4, Ltr 0.0582, Lge4 0.1598, Lge7 0.5094, Lge11 1.1092, TimeStep 034
# # 14500, T 309.8, Ltr 0.0294, Lge4 0.2574, Lge7 0.7330, Lge11 2.0384, TimeStep 044
# # 14750, T 315.2, Ltr 0.0465, Lge4 0.1859, Lge7 0.5646, Lge11 1.6947, TimeStep 005
# # 15000, T 320.5, Ltr 0.0287, Lge4 0.0975, Lge7 0.3786, Lge11 2.0613, TimeStep 047
# # 15250, T 325.7, Ltr 0.1255, Lge4 0.3923, Lge7 0.7609, Lge11 1.4527, TimeStep 047
# # 15500, T 331.1, Ltr 0.0090, Lge4 0.0062, Lge7 0.0070, Lge11 0.0184, TimeStep 001
# # 15750, T 336.4, Ltr 0.1084, Lge4 0.1454, Lge7 0.6134, Lge11 1.6370, TimeStep 025
# # 16000, T 341.7, Ltr 0.0551, Lge4 0.1663, Lge7 0.6405, Lge11 1.4781, TimeStep 036
# # 16250, T 347.0, Ltr 0.0925, Lge4 0.1289, Lge7 0.5336, Lge11 1.4167, TimeStep 014
# # 16500, T 352.3, Ltr 0.0280, Lge4 0.1567, Lge7 0.2864, Lge11 1.2766, TimeStep 047
# # 16750, T 357.6, Ltr 0.0142, Lge4 0.1059, Lge7 0.0338, Lge11 0.0566, TimeStep 002
# # 17000, T 362.9, Ltr 0.0940, Lge4 0.1776, Lge7 0.6123, Lge11 1.4896, TimeStep 021
# # 17250, T 368.2, Ltr 0.0864, Lge4 0.1531, Lge7 0.5732, Lge11 1.6030, TimeStep 009
# # 17500, T 373.5, Ltr 0.0967, Lge4 0.1013, Lge7 0.6981, Lge11 2.2027, TimeStep 028
# # 17750, T 378.9, Ltr 0.0278, Lge4 0.1493, Lge7 0.3099, Lge11 0.7389, TimeStep 047
# # 18000, T 384.2, Ltr 0.0795, Lge4 0.1251, Lge7 0.5116, Lge11 1.3400, TimeStep 017
# # 18250, T 389.5, Ltr 0.0849, Lge4 0.2453, Lge7 0.1401, Lge11 0.3388, TimeStep 014
# # 18500, T 394.8, Ltr 0.0180, Lge4 0.1622, Lge7 0.5295, Lge11 1.5092, TimeStep 001
# # 18750, T 400.0, Ltr 0.0281, Lge4 0.1499, Lge7 0.5476, Lge11 1.7622, TimeStep 047
# # 19000, T 405.4, Ltr 0.0994, Lge4 0.1469, Lge7 0.4691, Lge11 1.9654, TimeStep 010
# # 19250, T 410.7, Ltr 0.0655, Lge4 0.1594, Lge7 0.4965, Lge11 1.2158, TimeStep 030
# # 19500, T 416.0, Ltr 0.0562, Lge4 0.1623, Lge7 0.4542, Lge11 1.6468, TimeStep 033
# # 19750, T 421.4, Ltr 0.0237, Lge4 0.0913, Lge7 0.3414, Lge11 2.3426, TimeStep 000
# # 20000, T 426.7, Ltr 0.0378, Lge4 0.1201, Lge7 0.4341, Lge11 1.2338, TimeStep 038
# # 20250, T 432.0, Ltr 0.0584, Lge4 0.0123, Lge7 0.0126, Lge11 0.0259, TimeStep 003
# # 20500, T 437.3, Ltr 0.0702, Lge4 0.1834, Lge7 0.5140, Lge11 1.9708, TimeStep 028
# # 20750, T 442.6, Ltr 0.0950, Lge4 0.1130, Lge7 0.4920, Lge11 1.2013, TimeStep 025
# # 21000, T 448.0, Ltr 0.0939, Lge4 0.1445, Lge7 0.6010, Lge11 1.5803, TimeStep 007
# # 21250, T 453.3, Ltr 0.0478, Lge4 0.1353, Lge7 0.6576, Lge11 1.7055, TimeStep 039
# # 21500, T 458.5, Ltr 0.1008, Lge4 0.1074, Lge7 0.5582, Lge11 1.7574, TimeStep 021
# # 21750, T 463.9, Ltr 0.0318, Lge4 0.1476, Lge7 0.6083, Lge11 1.3253, TimeStep 003
# # 22000, T 469.2, Ltr 0.0150, Lge4 0.1094, Lge7 0.5887, Lge11 1.3940, TimeStep 003
# # 22250, T 474.5, Ltr 0.0097, Lge4 0.1216, Lge7 0.5774, Lge11 1.5281, TimeStep 003
# # 22500, T 479.8, Ltr 0.0794, Lge4 0.1403, Lge7 0.5236, Lge11 1.3702, TimeStep 016
# # 22750, T 485.1, Ltr 0.0846, Lge4 0.1394, Lge7 0.6232, Lge11 1.6478, TimeStep 016
# # 23000, T 490.4, Ltr 0.0570, Lge4 0.1288, Lge7 0.5686, Lge11 1.4412, TimeStep 032
# # 23250, T 495.8, Ltr 0.2164, Lge4 0.1438, Lge7 0.6211, Lge11 1.6279, TimeStep 011
# # 23500, T 501.1, Ltr 0.0492, Lge4 0.1420, Lge7 0.6217, Lge11 1.4185, TimeStep 007
# # 23750, T 506.4, Ltr 0.0792, Lge4 0.1880, Lge7 0.6088, Lge11 1.7008, TimeStep 014
# # 24000, T 511.7, Ltr 0.0942, Lge4 0.1600, Lge7 0.5059, Lge11 1.3660, TimeStep 021
# # 24250, T 517.0, Ltr 0.0184, Lge4 0.1180, Lge7 0.4046, Lge11 2.1846, TimeStep 004
# # 24500, T 522.3, Ltr 0.0793, Lge4 0.2199, Lge7 0.1768, Lge11 1.3583, TimeStep 007
# # 24750, T 527.6, Ltr 0.0821, Lge4 0.1286, Lge7 0.5446, Lge11 0.9245, TimeStep 029
# # 25000, T 532.8, Ltr 0.0333, Lge4 0.1430, Lge7 0.5427, Lge11 1.5004, TimeStep 006
# # 25250, T 538.1, Ltr 0.0647, Lge4 0.1889, Lge7 0.4178, Lge11 1.5314, TimeStep 030
# # 25500, T 543.4, Ltr 0.0692, Lge4 0.1413, Lge7 0.4290, Lge11 1.0607, TimeStep 013
# # 25750, T 548.8, Ltr 0.0543, Lge4 0.1363, Lge7 0.4103, Lge11 2.8641, TimeStep 032
# # 26000, T 554.1, Ltr 0.1101, Lge4 0.1581, Lge7 0.4699, Lge11 0.9267, TimeStep 021
# # 26250, T 559.4, Ltr 0.0263, Lge4 0.1538, Lge7 0.4949, Lge11 1.4045, TimeStep 043
# # 26500, T 564.7, Ltr 0.0285, Lge4 0.0824, Lge7 0.2896, Lge11 2.3535, TimeStep 045
# # 26750, T 570.0, Ltr 0.0977, Lge4 0.1043, Lge7 0.4016, Lge11 1.6563, TimeStep 020
# # 27000, T 575.3, Ltr 0.0752, Lge4 0.0043, Lge7 0.0067, Lge11 0.0264, TimeStep 020
# # 27250, T 580.6, Ltr 0.0504, Lge4 0.0892, Lge7 0.0316, Lge11 0.0514, TimeStep 031
# # 27500, T 585.9, Ltr 0.0666, Lge4 0.1187, Lge7 0.5305, Lge11 1.3611, TimeStep 030
# # 27750, T 591.2, Ltr 0.0883, Lge4 0.1683, Lge7 0.4881, Lge11 1.6773, TimeStep 023
# # 28000, T 596.5, Ltr 0.0814, Lge4 0.0676, Lge7 0.3165, Lge11 2.1862, TimeStep 022
# # 28250, T 601.8, Ltr 0.0420, Lge4 0.0692, Lge7 0.3022, Lge11 2.0999, TimeStep 036
# # 28500, T 607.1, Ltr 0.0755, Lge4 0.1488, Lge7 0.5407, Lge11 1.6454, TimeStep 035
# # 28750, T 612.4, Ltr 0.0323, Lge4 0.1110, Lge7 0.5430, Lge11 1.3817, TimeStep 039
# # 29000, T 617.7, Ltr 0.0404, Lge4 0.0712, Lge7 0.3313, Lge11 1.8263, TimeStep 037
# # 29250, T 623.0, Ltr 0.0999, Lge4 0.1350, Lge7 0.5376, Lge11 1.5547, TimeStep 025
# # 29500, T 628.3, Ltr 0.0468, Lge4 0.0577, Lge7 0.0319, Lge11 0.0443, TimeStep 034
# # 29750, T 633.6, Ltr 0.0731, Lge4 0.1135, Lge7 0.4387, Lge11 1.8185, TimeStep 015
# # 30000, T 638.9, Ltr 0.0445, Lge4 0.0569, Lge7 0.0446, Lge11 0.0573, TimeStep 033
# # 30250, T 644.2, Ltr 0.0278, Lge4 0.0791, Lge7 0.3999, Lge11 1.9232, TimeStep 042
# # 30500, T 649.5, Ltr 0.0373, Lge4 0.1241, Lge7 0.4222, Lge11 1.1146, TimeStep 035
# # 30750, T 654.9, Ltr 0.0665, Lge4 0.1557, Lge7 0.5243, Lge11 1.5058, TimeStep 016
# # 31000, T 660.2, Ltr 0.0265, Lge4 0.1000, Lge7 0.4303, Lge11 1.4388, TimeStep 047
# # 31250, T 665.5, Ltr 0.0638, Lge4 0.1273, Lge7 0.4567, Lge11 1.4764, TimeStep 016
# # 31500, T 670.8, Ltr 0.0151, Lge4 0.1345, Lge7 0.3623, Lge11 0.8829, TimeStep 002
# # 31750, T 676.0, Ltr 0.0743, Lge4 0.1015, Lge7 0.4455, Lge11 1.1305, TimeStep 013
# # 32000, T 681.3, Ltr 0.0549, Lge4 0.1181, Lge7 0.5343, Lge11 1.4586, TimeStep 029
# # 32250, T 686.6, Ltr 0.0841, Lge4 0.0565, Lge7 0.0287, Lge11 0.0365, TimeStep 018
# # 32500, T 691.9, Ltr 0.0643, Lge4 0.1039, Lge7 0.1865, Lge11 0.5624, TimeStep 009
# # 32750, T 697.2, Ltr 0.0354, Lge4 0.0815, Lge7 0.3896, Lge11 1.9088, TimeStep 036
# # 33000, T 702.6, Ltr 0.0719, Lge4 0.1820, Lge7 0.1304, Lge11 0.2806, TimeStep 014
# # 33250, T 707.8, Ltr 0.0681, Lge4 0.0607, Lge7 0.0290, Lge11 0.0325, TimeStep 017
# # 33500, T 713.1, Ltr 0.0521, Lge4 0.1275, Lge7 0.1275, Lge11 0.2021, TimeStep 029
# # 33750, T 718.5, Ltr 0.0241, Lge4 0.0914, Lge7 0.4460, Lge11 1.0716, TimeStep 044
# # 34000, T 723.8, Ltr 0.1110, Lge4 0.0993, Lge7 0.2841, Lge11 2.2329, TimeStep 027
# # 34250, T 729.0, Ltr 0.0391, Lge4 0.1187, Lge7 0.4438, Lge11 1.6006, TimeStep 033
# # 34500, T 734.3, Ltr 0.0622, Lge4 0.0641, Lge7 0.0416, Lge11 0.0554, TimeStep 015
# # 34750, T 739.6, Ltr 0.0707, Lge4 0.1271, Lge7 0.3303, Lge11 1.2066, TimeStep 023
# # 35000, T 744.9, Ltr 0.0215, Lge4 0.1542, Lge7 0.3929, Lge11 1.3092, TimeStep 048
# # 35250, T 750.3, Ltr 0.0273, Lge4 0.1065, Lge7 0.3540, Lge11 0.8875, TimeStep 002
# # 35500, T 755.5, Ltr 0.0617, Lge4 0.1035, Lge7 0.3946, Lge11 1.1722, TimeStep 009
# # 35750, T 760.9, Ltr 0.0641, Lge4 0.0731, Lge7 0.1740, Lge11 1.7833, TimeStep 024
# # 36000, T 766.2, Ltr 0.0650, Lge4 0.0317, Lge7 0.0261, Lge11 0.0348, TimeStep 014
# # 36250, T 771.6, Ltr 0.0259, Lge4 0.1210, Lge7 0.1313, Lge11 1.1405, TimeStep 040
# # 36500, T 776.8, Ltr 0.0439, Lge4 0.0888, Lge7 0.3636, Lge11 0.9397, TimeStep 032
# # 36750, T 782.2, Ltr 0.0110, Lge4 0.1064, Lge7 0.4874, Lge11 1.9340, TimeStep 002
# # 37000, T 787.4, Ltr 0.0403, Lge4 0.0378, Lge7 0.0229, Lge11 0.0379, TimeStep 035
# # 37250, T 792.7, Ltr 0.0131, Lge4 0.1060, Lge7 0.3606, Lge11 1.0367, TimeStep 000
# # 37500, T 798.0, Ltr 0.0176, Lge4 0.0790, Lge7 0.3655, Lge11 1.7764, TimeStep 001
# # 37750, T 803.3, Ltr 0.0811, Lge4 0.1148, Lge7 0.4691, Lge11 1.4808, TimeStep 025
# # 38000, T 808.6, Ltr 0.0571, Lge4 0.1016, Lge7 0.3096, Lge11 0.9384, TimeStep 025
# # 38250, T 814.0, Ltr 0.0399, Lge4 0.0978, Lge7 0.3307, Lge11 1.1217, TimeStep 033
# # 38500, T 819.3, Ltr 0.0108, Lge4 0.1032, Lge7 0.3316, Lge11 1.4426, TimeStep 003
# # 38750, T 824.6, Ltr 0.0321, Lge4 0.0981, Lge7 0.4714, Lge11 1.2179, TimeStep 007
# # 39000, T 829.8, Ltr 0.0772, Lge4 0.0989, Lge7 0.4134, Lge11 1.5912, TimeStep 009
# # 39250, T 835.1, Ltr 0.0171, Lge4 0.0082, Lge7 0.0137, Lge11 0.0541, TimeStep 046
# # 39500, T 840.4, Ltr 0.0754, Lge4 0.0851, Lge7 0.3370, Lge11 0.9621, TimeStep 011
# # 39750, T 845.8, Ltr 0.0757, Lge4 0.1111, Lge7 0.4159, Lge11 1.2452, TimeStep 020
# # 40000, T 851.1, Ltr 0.0188, Lge4 0.0945, Lge7 0.3254, Lge11 1.6921, TimeStep 046
# # 40250, T 856.4, Ltr 0.0468, Lge4 0.0792, Lge7 0.3417, Lge11 2.0280, TimeStep 016
# # 40500, T 861.6, Ltr 0.0384, Lge4 0.0865, Lge7 0.3827, Lge11 1.4070, TimeStep 007
# # 40750, T 866.9, Ltr 0.0407, Lge4 0.1007, Lge7 0.3477, Lge11 1.6110, TimeStep 002
# # 41000, T 872.2, Ltr 0.0301, Lge4 0.0792, Lge7 0.4162, Lge11 1.5632, TimeStep 038
# # 41250, T 877.6, Ltr 0.0584, Lge4 0.1173, Lge7 0.3949, Lge11 1.1558, TimeStep 028
# # 41500, T 882.9, Ltr 0.0485, Lge4 0.0656, Lge7 0.0429, Lge11 0.0456, TimeStep 026
# # 41750, T 888.2, Ltr 0.0346, Lge4 0.0139, Lge7 0.0128, Lge11 0.0357, TimeStep 039
# # 42000, T 893.5, Ltr 0.0480, Lge4 0.0950, Lge7 0.3253, Lge11 0.8750, TimeStep 027
# # 42250, T 898.8, Ltr 0.0133, Lge4 0.1032, Lge7 0.4362, Lge11 2.2113, TimeStep 001
# # 42500, T 904.1, Ltr 0.0105, Lge4 0.0958, Lge7 0.3634, Lge11 1.1369, TimeStep 000
# # 42750, T 909.4, Ltr 0.0429, Lge4 0.0720, Lge7 0.2889, Lge11 0.9215, TimeStep 026
# # 43000, T 914.7, Ltr 0.0348, Lge4 0.0750, Lge7 0.2684, Lge11 1.6642, TimeStep 033
# # 43250, T 920.0, Ltr 0.0646, Lge4 0.0999, Lge7 0.3868, Lge11 1.3734, TimeStep 032
# # 43500, T 925.3, Ltr 0.0175, Lge4 0.0877, Lge7 0.2970, Lge11 0.7212, TimeStep 043
# # 43750, T 930.7, Ltr 0.0116, Lge4 0.0770, Lge7 0.2602, Lge11 0.6231, TimeStep 003
# # 44000, T 936.0, Ltr 0.0560, Lge4 0.0862, Lge7 0.3102, Lge11 0.9328, TimeStep 013
# # 44250, T 941.3, Ltr 0.0367, Lge4 0.0851, Lge7 0.3876, Lge11 0.8942, TimeStep 033
# # 44500, T 946.6, Ltr 0.0121, Lge4 0.0948, Lge7 0.3410, Lge11 1.2647, TimeStep 001
# # 44750, T 951.9, Ltr 0.0536, Lge4 0.0639, Lge7 0.3468, Lge11 1.5007, TimeStep 021
# # 45000, T 957.2, Ltr 0.0383, Lge4 0.0671, Lge7 0.2581, Lge11 1.6398, TimeStep 029
# # 45250, T 962.5, Ltr 0.0323, Lge4 0.0806, Lge7 0.3214, Lge11 1.4319, TimeStep 033
# # 45500, T 967.8, Ltr 0.0290, Lge4 0.0800, Lge7 0.3562, Lge11 1.3811, TimeStep 032
# # 45750, T 973.1, Ltr 0.0274, Lge4 0.0690, Lge7 0.2825, Lge11 1.4028, TimeStep 035
# # 46000, T 978.4, Ltr 0.0619, Lge4 0.0801, Lge7 0.4539, Lge11 0.9496, TimeStep 019
# # 46250, T 983.7, Ltr 0.0514, Lge4 0.0906, Lge7 0.3013, Lge11 1.0830, TimeStep 019
# # 46500, T 989.0, Ltr 0.0476, Lge4 0.1007, Lge7 0.4177, Lge11 1.3445, TimeStep 026
# # 46750, T 994.3, Ltr 0.0525, Lge4 0.1051, Lge7 0.2471, Lge11 1.1046, TimeStep 017
# # 47000, T 999.7, Ltr 0.0496, Lge4 0.0624, Lge7 0.2631, Lge11 1.1500, TimeStep 013
# # 47250, T 1004.9, Ltr 0.0559, Lge4 0.0852, Lge7 0.2919, Lge11 0.8809, TimeStep 020
# # 47500, T 1010.3, Ltr 0.0285, Lge4 0.0805, Lge7 0.3504, Lge11 1.7278, TimeStep 043
# # 47750, T 1015.6, Ltr 0.0175, Lge4 0.0797, Lge7 0.3728, Lge11 0.8432, TimeStep 002
# # 48000, T 1020.9, Ltr 0.0096, Lge4 0.0715, Lge7 0.2575, Lge11 0.7367, TimeStep 001
# # 48250, T 1026.2, Ltr 0.0259, Lge4 0.0722, Lge7 0.3155, Lge11 1.2095, TimeStep 034
# # 48500, T 1031.4, Ltr 0.0357, Lge4 0.1104, Lge7 0.4065, Lge11 1.0326, TimeStep 005
# # 48750, T 1036.7, Ltr 0.0309, Lge4 0.0895, Lge7 0.2918, Lge11 1.4272, TimeStep 033
# # 49000, T 1042.0, Ltr 0.0420, Lge4 0.0595, Lge7 0.1908, Lge11 1.9268, TimeStep 016
# # 49250, T 1047.3, Ltr 0.0146, Lge4 0.0734, Lge7 0.2662, Lge11 1.2706, TimeStep 047
# # 49500, T 1052.6, Ltr 0.0878, Lge4 0.0462, Lge7 0.0501, Lge11 0.0577, TimeStep 016
# # 49750, T 1057.9, Ltr 0.0347, Lge4 0.0585, Lge7 0.2570, Lge11 0.7100, TimeStep 008
# # 50000, T 1063.2, Ltr 0.0177, Lge4 0.0613, Lge7 0.3078, Lge11 1.1651, TimeStep 039
# # 50250, T 1068.6, Ltr 0.0477, Lge4 0.0738, Lge7 0.3020, Lge11 1.3161, TimeStep 018
# # 50500, T 1073.9, Ltr 0.0205, Lge4 0.0753, Lge7 0.2739, Lge11 1.3474, TimeStep 037
# # 50750, T 1079.2, Ltr 0.0192, Lge4 0.0715, Lge7 0.2638, Lge11 0.9172, TimeStep 038
# # 51000, T 1084.5, Ltr 0.0424, Lge4 0.0688, Lge7 0.3227, Lge11 1.1389, TimeStep 013
# # 51250, T 1089.8, Ltr 0.0266, Lge4 0.0809, Lge7 0.2057, Lge11 2.0958, TimeStep 045
# # 51500, T 1095.1, Ltr 0.0334, Lge4 0.0743, Lge7 0.2842, Lge11 1.7326, TimeStep 027
# # 51750, T 1100.4, Ltr 0.0184, Lge4 0.0654, Lge7 0.3367, Lge11 0.8384, TimeStep 041
# # 52000, T 1105.7, Ltr 0.0202, Lge4 0.0566, Lge7 0.2937, Lge11 1.6776, TimeStep 039
# # 52250, T 1111.0, Ltr 0.0495, Lge4 0.0818, Lge7 0.2717, Lge11 0.7198, TimeStep 021
# # 52500, T 1116.3, Ltr 0.0202, Lge4 0.0594, Lge7 0.3228, Lge11 1.7828, TimeStep 036
# # 52750, T 1121.6, Ltr 0.0139, Lge4 0.0793, Lge7 0.3649, Lge11 1.6243, TimeStep 044
# # 53000, T 1126.8, Ltr 0.1159, Lge4 0.0506, Lge7 0.1279, Lge11 1.5753, TimeStep 008
# # 53250, T 1132.1, Ltr 0.0518, Lge4 0.0663, Lge7 0.2828, Lge11 1.6829, TimeStep 010
# # 53500, T 1137.4, Ltr 0.0232, Lge4 0.0679, Lge7 0.2993, Lge11 1.6065, TimeStep 038
# # 53750, T 1142.7, Ltr 0.0348, Lge4 0.0878, Lge7 0.3049, Lge11 1.8629, TimeStep 040
# # 54000, T 1148.0, Ltr 0.0199, Lge4 0.0883, Lge7 0.1424, Lge11 0.6546, TimeStep 039
# # 54250, T 1153.3, Ltr 0.0116, Lge4 0.0645, Lge7 0.2818, Lge11 0.8279, TimeStep 044
# # 54500, T 1158.6, Ltr 0.0283, Lge4 0.0657, Lge7 0.3000, Lge11 1.4743, TimeStep 029
# # 54750, T 1163.9, Ltr 0.0106, Lge4 0.0624, Lge7 0.3259, Lge11 0.9095, TimeStep 002
# # 55000, T 1169.2, Ltr 0.0434, Lge4 0.0769, Lge7 0.3266, Lge11 0.8557, TimeStep 010
# # 55250, T 1174.5, Ltr 0.0619, Lge4 0.0676, Lge7 0.0492, Lge11 0.0633, TimeStep 025
# # 55500, T 1179.9, Ltr 0.0326, Lge4 0.0648, Lge7 0.2967, Lge11 1.3122, TimeStep 024
# # 55750, T 1185.2, Ltr 0.0163, Lge4 0.0645, Lge7 0.2256, Lge11 0.8202, TimeStep 042
# # 56000, T 1190.5, Ltr 0.0317, Lge4 0.0706, Lge7 0.3316, Lge11 0.9050, TimeStep 027
# # 56250, T 1195.8, Ltr 0.0279, Lge4 0.0619, Lge7 0.2653, Lge11 1.5460, TimeStep 038
# # 56500, T 1201.1, Ltr 0.0132, Lge4 0.0676, Lge7 0.2657, Lge11 1.0895, TimeStep 042
# # 56750, T 1206.4, Ltr 0.0296, Lge4 0.0172, Lge7 0.0109, Lge11 0.0385, TimeStep 007
# # 57000, T 1211.7, Ltr 0.0292, Lge4 0.0467, Lge7 0.0344, Lge11 0.0482, TimeStep 035
# # 57250, T 1217.0, Ltr 0.0406, Lge4 0.0445, Lge7 0.1966, Lge11 1.9334, TimeStep 020
# # 57500, T 1222.3, Ltr 0.0195, Lge4 0.0531, Lge7 0.3138, Lge11 1.5561, TimeStep 043
# # 57750, T 1227.6, Ltr 0.0419, Lge4 0.0714, Lge7 0.3349, Lge11 1.2987, TimeStep 008
# # 58000, T 1232.9, Ltr 0.0146, Lge4 0.0851, Lge7 0.3271, Lge11 0.7582, TimeStep 041
# # 58250, T 1238.2, Ltr 0.0148, Lge4 0.0597, Lge7 0.2154, Lge11 0.5942, TimeStep 003
# # 58500, T 1243.5, Ltr 0.0177, Lge4 0.0671, Lge7 0.2943, Lge11 1.6139, TimeStep 037
# # 58750, T 1248.8, Ltr 0.0117, Lge4 0.0648, Lge7 0.2229, Lge11 0.9000, TimeStep 044
# # 59000, T 1254.1, Ltr 0.0309, Lge4 0.0674, Lge7 0.1311, Lge11 0.5318, TimeStep 026
# # 59250, T 1259.5, Ltr 0.0264, Lge4 0.0676, Lge7 0.2588, Lge11 1.4285, TimeStep 032
# # 59500, T 1264.8, Ltr 0.0265, Lge4 0.0603, Lge7 0.2940, Lge11 0.7994, TimeStep 026
# # 59750, T 1270.1, Ltr 0.0431, Lge4 0.0620, Lge7 0.2956, Lge11 1.1866, TimeStep 016
# # 60000, T 1275.4, Ltr 0.0198, Lge4 0.0762, Lge7 0.2176, Lge11 1.0481, TimeStep 005
# # 60250, T 1280.7, Ltr 0.0586, Lge4 0.1751, Lge7 0.5432, Lge11 1.2392, TimeStep 038
# # 60500, T 1286.0, Ltr 0.0195, Lge4 0.0679, Lge7 0.3721, Lge11 1.5467, TimeStep 036
# # 60750, T 1291.3, Ltr 0.0113, Lge4 0.0616, Lge7 0.2609, Lge11 0.6689, TimeStep 044
# # 61000, T 1296.6, Ltr 0.0318, Lge4 0.0712, Lge7 0.3712, Lge11 1.5101, TimeStep 024
# # 61250, T 1301.9, Ltr 0.0202, Lge4 0.0549, Lge7 0.2773, Lge11 1.4804, TimeStep 033
# # 61500, T 1307.3, Ltr 0.0394, Lge4 0.0633, Lge7 0.2397, Lge11 1.6811, TimeStep 022
# # 61750, T 1312.6, Ltr 0.0441, Lge4 0.0625, Lge7 0.2481, Lge11 1.0730, TimeStep 014
# # 62000, T 1317.9, Ltr 0.0381, Lge4 0.0696, Lge7 0.2415, Lge11 1.3160, TimeStep 009
# # 62250, T 1323.2, Ltr 0.0536, Lge4 0.0763, Lge7 0.3222, Lge11 1.2564, TimeStep 009
# # 62500, T 1328.5, Ltr 0.0328, Lge4 0.0763, Lge7 0.2252, Lge11 0.7046, TimeStep 018
# # 62750, T 1333.9, Ltr 0.0196, Lge4 0.0673, Lge7 0.2774, Lge11 1.3061, TimeStep 042
# # 63000, T 1339.2, Ltr 0.0471, Lge4 0.0532, Lge7 0.2246, Lge11 0.6289, TimeStep 014
# # 63250, T 1344.5, Ltr 0.0118, Lge4 0.0529, Lge7 0.1230, Lge11 0.4958, TimeStep 040
# # 63500, T 1349.8, Ltr 0.0178, Lge4 0.0649, Lge7 0.2602, Lge11 1.2209, TimeStep 040
# # 63750, T 1355.0, Ltr 0.0137, Lge4 0.0557, Lge7 0.2317, Lge11 0.5843, TimeStep 044
# # 64000, T 1360.4, Ltr 0.0351, Lge4 0.0620, Lge7 0.2570, Lge11 1.3240, TimeStep 018
# # 64250, T 1365.6, Ltr 0.0317, Lge4 0.0618, Lge7 0.2808, Lge11 1.1554, TimeStep 024
# # 64500, T 1371.0, Ltr 0.0335, Lge4 0.0579, Lge7 0.2633, Lge11 1.1529, TimeStep 022
# # 64750, T 1376.2, Ltr 0.0090, Lge4 0.0566, Lge7 0.2274, Lge11 0.7865, TimeStep 002
# # 65000, T 1381.5, Ltr 0.0155, Lge4 0.0766, Lge7 0.3307, Lge11 1.2738, TimeStep 041
# # 65250, T 1386.9, Ltr 0.0204, Lge4 0.0495, Lge7 0.2717, Lge11 1.4876, TimeStep 040
# # 65500, T 1392.2, Ltr 0.0291, Lge4 0.0420, Lge7 0.2484, Lge11 1.6128, TimeStep 008
# # 65750, T 1397.6, Ltr 0.0328, Lge4 0.0693, Lge7 0.2632, Lge11 1.5484, TimeStep 022
# # 66000, T 1403.0, Ltr 0.0120, Lge4 0.0602, Lge7 0.2453, Lge11 1.4508, TimeStep 004
# # 66250, T 1408.4, Ltr 0.0191, Lge4 0.0720, Lge7 0.2450, Lge11 0.5954, TimeStep 042
# # 66500, T 1413.8, Ltr 0.0212, Lge4 0.0622, Lge7 0.2697, Lge11 1.3123, TimeStep 036
# # 66750, T 1419.1, Ltr 0.0452, Lge4 0.0472, Lge7 0.2571, Lge11 1.6718, TimeStep 016
# # 67000, T 1424.5, Ltr 0.0331, Lge4 0.0561, Lge7 0.2333, Lge11 0.5517, TimeStep 016
# # 67250, T 1429.7, Ltr 0.0164, Lge4 0.0429, Lge7 0.0383, Lge11 0.0635, TimeStep 037
# # 67500, T 1435.1, Ltr 0.0361, Lge4 0.0735, Lge7 0.0733, Lge11 0.2052, TimeStep 009
# # 67750, T 1440.5, Ltr 0.0235, Lge4 0.0464, Lge7 0.1167, Lge11 1.4864, TimeStep 026
# # 68000, T 1445.9, Ltr 0.0136, Lge4 0.0523, Lge7 0.1112, Lge11 0.5399, TimeStep 038
# # 68250, T 1451.2, Ltr 0.0144, Lge4 0.0230, Lge7 0.0219, Lge11 0.0689, TimeStep 005
# # 68500, T 1456.5, Ltr 0.0274, Lge4 0.0436, Lge7 0.2841, Lge11 0.7764, TimeStep 019
# # 68750, T 1461.8, Ltr 0.0363, Lge4 0.0519, Lge7 0.2015, Lge11 0.5264, TimeStep 016
# # 69000, T 1467.1, Ltr 0.0207, Lge4 0.0230, Lge7 0.0126, Lge11 0.0432, TimeStep 044
# # 69250, T 1472.4, Ltr 0.0310, Lge4 0.0518, Lge7 0.2148, Lge11 0.6005, TimeStep 015
# # 69500, T 1477.7, Ltr 0.0079, Lge4 0.0424, Lge7 0.2012, Lge11 1.2131, TimeStep 048
# # 69750, T 1483.0, Ltr 0.0345, Lge4 0.0545, Lge7 0.0557, Lge11 0.1539, TimeStep 016
# # 70000, T 1488.3, Ltr 0.0231, Lge4 0.0050, Lge7 0.0070, Lge11 0.0350, TimeStep 041
# # 70250, T 1493.5, Ltr 0.0302, Lge4 0.0461, Lge7 0.2695, Lge11 1.2756, TimeStep 015
# # 70500, T 1498.9, Ltr 0.0328, Lge4 0.0546, Lge7 0.2406, Lge11 1.7294, TimeStep 012
# # 70750, T 1504.2, Ltr 0.0067, Lge4 0.0569, Lge7 0.1068, Lge11 0.4570, TimeStep 000
# # 71000, T 1509.5, Ltr 0.0266, Lge4 0.0542, Lge7 0.2972, Lge11 1.5388, TimeStep 019
# # 71250, T 1514.8, Ltr 0.0207, Lge4 0.0468, Lge7 0.1996, Lge11 0.7623, TimeStep 036
# # 71500, T 1520.1, Ltr 0.0654, Lge4 0.0614, Lge7 0.2108, Lge11 1.0858, TimeStep 030
# # 71750, T 1525.4, Ltr 0.0338, Lge4 0.0538, Lge7 0.1789, Lge11 1.7116, TimeStep 036
# # 72000, T 1530.7, Ltr 0.0130, Lge4 0.0466, Lge7 0.1878, Lge11 1.3686, TimeStep 041
# # 72250, T 1536.0, Ltr 0.0368, Lge4 0.0688, Lge7 0.2833, Lge11 1.2537, TimeStep 012
# # 72500, T 1541.4, Ltr 0.0104, Lge4 0.0513, Lge7 0.1855, Lge11 0.7377, TimeStep 040
# # 72750, T 1546.7, Ltr 0.0211, Lge4 0.0478, Lge7 0.2407, Lge11 0.7763, TimeStep 035
# # 73000, T 1552.0, Ltr 0.0267, Lge4 0.0423, Lge7 0.2055, Lge11 1.4928, TimeStep 022
# # 73250, T 1557.3, Ltr 0.0117, Lge4 0.0476, Lge7 0.2228, Lge11 0.5518, TimeStep 042
# # 73500, T 1562.7, Ltr 0.0303, Lge4 0.0666, Lge7 0.3360, Lge11 1.6081, TimeStep 004
# # 73750, T 1568.0, Ltr 0.0189, Lge4 0.0495, Lge7 0.1691, Lge11 0.9498, TimeStep 028
# # 74000, T 1573.3, Ltr 0.0250, Lge4 0.0277, Lge7 0.0406, Lge11 0.1152, TimeStep 018
# # 74250, T 1578.7, Ltr 0.0122, Lge4 0.0496, Lge7 0.2533, Lge11 1.2231, TimeStep 041
# # 74500, T 1583.9, Ltr 0.0285, Lge4 0.0206, Lge7 0.0199, Lge11 0.0670, TimeStep 020
# # 74750, T 1589.3, Ltr 0.0188, Lge4 0.0462, Lge7 0.2319, Lge11 1.3210, TimeStep 029
# # 75000, T 1594.6, Ltr 0.0278, Lge4 0.0393, Lge7 0.1478, Lge11 1.7782, TimeStep 025
# # 75250, T 1599.9, Ltr 0.0280, Lge4 0.0641, Lge7 0.2025, Lge11 0.6396, TimeStep 024
# # 75500, T 1605.2, Ltr 0.0115, Lge4 0.0454, Lge7 0.2393, Lge11 1.2742, TimeStep 039
# # 75750, T 1610.6, Ltr 0.0265, Lge4 0.0432, Lge7 0.2266, Lge11 1.2069, TimeStep 008
# # 76000, T 1615.9, Ltr 0.0249, Lge4 0.0523, Lge7 0.2351, Lge11 0.6601, TimeStep 026
# # 76250, T 1621.3, Ltr 0.0087, Lge4 0.0382, Lge7 0.2288, Lge11 1.3409, TimeStep 042
# # 76500, T 1626.6, Ltr 0.0142, Lge4 0.0430, Lge7 0.1041, Lge11 0.9260, TimeStep 031
# # 76750, T 1631.9, Ltr 0.0162, Lge4 0.0529, Lge7 0.2025, Lge11 0.7854, TimeStep 030
# # 77000, T 1637.2, Ltr 0.0396, Lge4 0.1089, Lge7 0.2866, Lge11 1.0857, TimeStep 027
# # 77250, T 1642.5, Ltr 0.0089, Lge4 0.0570, Lge7 0.2518, Lge11 0.7629, TimeStep 044
# # 77500, T 1647.8, Ltr 0.0217, Lge4 0.0379, Lge7 0.2085, Lge11 1.0635, TimeStep 032
# # 77750, T 1653.1, Ltr 0.0080, Lge4 0.0400, Lge7 0.2051, Lge11 0.5924, TimeStep 003
# # 78000, T 1658.5, Ltr 0.0110, Lge4 0.0636, Lge7 0.2709, Lge11 1.2457, TimeStep 042
# # 78250, T 1663.8, Ltr 0.0289, Lge4 0.0395, Lge7 0.1984, Lge11 0.6053, TimeStep 011
# # 78500, T 1669.1, Ltr 0.0157, Lge4 0.0498, Lge7 0.2284, Lge11 1.5143, TimeStep 030
# # 78750, T 1674.4, Ltr 0.0507, Lge4 0.0430, Lge7 0.2307, Lge11 0.5319, TimeStep 010
# # 79000, T 1679.7, Ltr 0.0113, Lge4 0.0357, Lge7 0.2358, Lge11 1.3680, TimeStep 003
# # 79250, T 1685.0, Ltr 0.0122, Lge4 0.0378, Lge7 0.1609, Lge11 1.2313, TimeStep 005
# # 79500, T 1690.3, Ltr 0.0235, Lge4 0.0174, Lge7 0.0179, Lge11 0.0547, TimeStep 014
# # 79750, T 1695.6, Ltr 0.0064, Lge4 0.0632, Lge7 0.2444, Lge11 1.2970, TimeStep 000
# # 80000, T 1700.9, Ltr 0.0798, Lge4 0.0804, Lge7 0.0878, Lge11 0.1602, TimeStep 018
# # 80250, T 1706.2, Ltr 0.0134, Lge4 0.0060, Lge7 0.0078, Lge11 0.0237, TimeStep 034
# # 80500, T 1711.6, Ltr 0.0439, Lge4 0.0367, Lge7 0.2431, Lge11 1.3014, TimeStep 011
# # 80750, T 1716.9, Ltr 0.0136, Lge4 0.0295, Lge7 0.0505, Lge11 0.1567, TimeStep 035
# # 81000, T 1722.2, Ltr 0.0143, Lge4 0.0423, Lge7 0.1065, Lge11 0.1724, TimeStep 033
# # 81250, T 1727.5, Ltr 0.0214, Lge4 0.0686, Lge7 0.2713, Lge11 1.4484, TimeStep 028
# # 81500, T 1732.8, Ltr 0.0220, Lge4 0.0428, Lge7 0.1869, Lge11 1.6139, TimeStep 020
# # 81750, T 1738.2, Ltr 0.0105, Lge4 0.0523, Lge7 0.2372, Lge11 0.5798, TimeStep 038
# # 82000, T 1743.5, Ltr 0.0088, Lge4 0.0393, Lge7 0.2197, Lge11 1.4546, TimeStep 041
# # 82250, T 1748.8, Ltr 0.0090, Lge4 0.0425, Lge7 0.0782, Lge11 0.7908, TimeStep 041
# # 82500, T 1754.2, Ltr 0.0124, Lge4 0.0476, Lge7 0.2092, Lge11 1.1982, TimeStep 002
# # 82750, T 1759.5, Ltr 0.0105, Lge4 0.0433, Lge7 0.0748, Lge11 0.3511, TimeStep 038
# # 83000, T 1764.8, Ltr 0.0408, Lge4 0.0732, Lge7 0.3151, Lge11 1.6471, TimeStep 023
# # 83250, T 1770.1, Ltr 0.0098, Lge4 0.0100, Lge7 0.0137, Lge11 0.0402, TimeStep 038
# # 83500, T 1775.4, Ltr 0.0240, Lge4 0.0437, Lge7 0.2157, Lge11 1.6082, TimeStep 020
# # 83750, T 1780.8, Ltr 0.0196, Lge4 0.0368, Lge7 0.1804, Lge11 1.1310, TimeStep 017
# # 84000, T 1786.1, Ltr 0.0131, Lge4 0.0522, Lge7 0.3171, Lge11 1.7512, TimeStep 038
# # 84250, T 1791.5, Ltr 0.0156, Lge4 0.0501, Lge7 0.2054, Lge11 1.1498, TimeStep 028
# # 84500, T 1796.8, Ltr 0.0189, Lge4 0.0466, Lge7 0.1836, Lge11 0.5109, TimeStep 029
# # 84750, T 1802.1, Ltr 0.0095, Lge4 0.0427, Lge7 0.2429, Lge11 1.2390, TimeStep 043
# # 85000, T 1807.4, Ltr 0.0168, Lge4 0.0251, Lge7 0.1875, Lge11 1.1686, TimeStep 032
# # 85250, T 1812.8, Ltr 0.0134, Lge4 0.0440, Lge7 0.2201, Lge11 1.1267, TimeStep 035
# # 85500, T 1818.1, Ltr 0.0065, Lge4 0.0368, Lge7 0.2197, Lge11 1.6170, TimeStep 048
# # 85750, T 1823.4, Ltr 0.0146, Lge4 0.0461, Lge7 0.1967, Lge11 1.5243, TimeStep 027
# # 86000, T 1828.8, Ltr 0.0060, Lge4 0.0415, Lge7 0.1977, Lge11 1.4011, TimeStep 045
# # 86250, T 1834.1, Ltr 0.0123, Lge4 0.0425, Lge7 0.2032, Lge11 1.6711, TimeStep 038
# # 86500, T 1839.4, Ltr 0.0193, Lge4 0.0365, Lge7 0.1382, Lge11 0.9421, TimeStep 019
# # 86750, T 1844.7, Ltr 0.0079, Lge4 0.0258, Lge7 0.0352, Lge11 0.0809, TimeStep 003
# # 87000, T 1850.0, Ltr 0.0139, Lge4 0.0493, Lge7 0.1916, Lge11 0.9207, TimeStep 006
# # 87250, T 1855.3, Ltr 0.0100, Lge4 0.0393, Lge7 0.2270, Lge11 1.5968, TimeStep 038
# # 87500, T 1860.6, Ltr 0.0107, Lge4 0.0379, Lge7 0.1999, Lge11 1.6084, TimeStep 034
# # 87750, T 1865.9, Ltr 0.0526, Lge4 0.0444, Lge7 0.1898, Lge11 0.7344, TimeStep 014
# # 88000, T 1871.2, Ltr 0.0170, Lge4 0.0438, Lge7 0.1505, Lge11 0.7676, TimeStep 025
# # 88250, T 1876.6, Ltr 0.0154, Lge4 0.0412, Lge7 0.1708, Lge11 1.9438, TimeStep 035
# # 88500, T 1881.9, Ltr 0.0427, Lge4 0.0530, Lge7 0.1925, Lge11 1.4388, TimeStep 005
# # 88750, T 1887.2, Ltr 0.0159, Lge4 0.0333, Lge7 0.1909, Lge11 0.4795, TimeStep 026
# # 89000, T 1892.5, Ltr 0.0180, Lge4 0.0093, Lge7 0.0059, Lge11 0.0211, TimeStep 016
# # 89250, T 1897.9, Ltr 0.0121, Lge4 0.0504, Lge7 0.2116, Lge11 1.1870, TimeStep 042
# # 89500, T 1903.2, Ltr 0.0193, Lge4 0.0440, Lge7 0.1371, Lge11 0.5312, TimeStep 024
# # 89750, T 1908.6, Ltr 0.0286, Lge4 0.0423, Lge7 0.1812, Lge11 1.2947, TimeStep 020
# # 90000, T 1913.9, Ltr 0.0168, Lge4 0.0431, Lge7 0.2148, Lge11 0.6757, TimeStep 038
# # 90250, T 1919.2, Ltr 0.0157, Lge4 0.0381, Lge7 0.1659, Lge11 0.9163, TimeStep 023
# # 90500, T 1924.5, Ltr 0.0093, Lge4 0.0387, Lge7 0.1861, Lge11 0.5068, TimeStep 041
# # 90750, T 1929.8, Ltr 0.0108, Lge4 0.0481, Lge7 0.0456, Lge11 0.0630, TimeStep 034
# # 91000, T 1935.1, Ltr 0.0399, Lge4 0.0395, Lge7 0.1664, Lge11 0.5505, TimeStep 009
# # 91250, T 1940.4, Ltr 0.0152, Lge4 0.0508, Lge7 0.1536, Lge11 0.2519, TimeStep 034
# # 91500, T 1945.7, Ltr 0.0254, Lge4 0.0331, Lge7 0.1601, Lge11 1.0773, TimeStep 013
# # 91750, T 1951.0, Ltr 0.0169, Lge4 0.0536, Lge7 0.2214, Lge11 0.6078, TimeStep 038
# # 92000, T 1956.3, Ltr 0.0155, Lge4 0.0472, Lge7 0.1460, Lge11 0.4886, TimeStep 008
# # 92250, T 1961.7, Ltr 0.0093, Lge4 0.0502, Lge7 0.1376, Lge11 0.4654, TimeStep 039
# # 92500, T 1966.9, Ltr 0.0156, Lge4 0.0379, Lge7 0.1861, Lge11 1.6459, TimeStep 035
# # 92750, T 1972.2, Ltr 0.0079, Lge4 0.0292, Lge7 0.1866, Lge11 1.4577, TimeStep 038
# # 93000, T 1977.6, Ltr 0.0275, Lge4 0.0381, Lge7 0.1791, Lge11 0.5728, TimeStep 024
# # 93250, T 1982.9, Ltr 0.0462, Lge4 0.0398, Lge7 0.1012, Lge11 1.1610, TimeStep 011
# # 93500, T 1988.2, Ltr 0.0175, Lge4 0.0282, Lge7 0.1519, Lge11 0.4114, TimeStep 018
# # 93750, T 1993.6, Ltr 0.0467, Lge4 0.0790, Lge7 0.2773, Lge11 1.5696, TimeStep 001
# # 94000, T 1998.9, Ltr 0.0199, Lge4 0.0442, Lge7 0.1369, Lge11 0.5714, TimeStep 015
# # 94250, T 2004.2, Ltr 0.0097, Lge4 0.0410, Lge7 0.1169, Lge11 1.5876, TimeStep 031
# # 94500, T 2009.5, Ltr 0.0073, Lge4 0.0381, Lge7 0.1445, Lge11 1.0667, TimeStep 042
# # 94750, T 2014.8, Ltr 0.0146, Lge4 0.0173, Lge7 0.0086, Lge11 0.0293, TimeStep 029
# # 95000, T 2020.1, Ltr 0.0071, Lge4 0.0314, Lge7 0.1836, Lge11 1.0937, TimeStep 002
# # 95250, T 2025.4, Ltr 0.0168, Lge4 0.0431, Lge7 0.1477, Lge11 0.4849, TimeStep 019
# # 95500, T 2030.7, Ltr 0.0264, Lge4 0.0398, Lge7 0.1757, Lge11 1.0527, TimeStep 018
# # 95750, T 2036.1, Ltr 0.0181, Lge4 0.0105, Lge7 0.0125, Lge11 0.0278, TimeStep 034
# # 96000, T 2041.4, Ltr 0.0132, Lge4 0.0436, Lge7 0.2134, Lge11 1.3579, TimeStep 031
# # 96250, T 2046.7, Ltr 0.0218, Lge4 0.0348, Lge7 0.1840, Lge11 1.1336, TimeStep 013
# # 96500, T 2052.1, Ltr 0.0323, Lge4 0.0368, Lge7 0.1612, Lge11 1.4082, TimeStep 036
# # 96750, T 2057.4, Ltr 0.0159, Lge4 0.0429, Lge7 0.1534, Lge11 0.4658, TimeStep 029
# # 97000, T 2062.8, Ltr 0.0161, Lge4 0.0320, Lge7 0.1944, Lge11 1.1179, TimeStep 024
# # 97250, T 2068.1, Ltr 0.0113, Lge4 0.0394, Lge7 0.1468, Lge11 0.6192, TimeStep 027
# # 97500, T 2073.4, Ltr 0.0132, Lge4 0.0376, Lge7 0.0392, Lge11 0.0704, TimeStep 034
# # 97750, T 2078.8, Ltr 0.0086, Lge4 0.0478, Lge7 0.1441, Lge11 0.4663, TimeStep 040
# # 98000, T 2084.1, Ltr 0.0128, Lge4 0.0400, Lge7 0.1944, Lge11 0.4567, TimeStep 032
# # 98250, T 2089.5, Ltr 0.0097, Lge4 0.0373, Lge7 0.2205, Lge11 0.7540, TimeStep 032
# # 98500, T 2094.8, Ltr 0.0115, Lge4 0.0339, Lge7 0.0768, Lge11 0.7081, TimeStep 035
# # 98750, T 2100.1, Ltr 0.0069, Lge4 0.0320, Lge7 0.1636, Lge11 0.4967, TimeStep 042
# # 99000, T 2105.4, Ltr 0.0125, Lge4 0.0276, Lge7 0.1614, Lge11 1.2955, TimeStep 025
# # 99250, T 2110.7, Ltr 0.0090, Lge4 0.0330, Lge7 0.1239, Lge11 0.4378, TimeStep 032
# # 99500, T 2116.1, Ltr 0.0098, Lge4 0.0305, Lge7 0.0427, Lge11 0.0905, TimeStep 030
# # 99750, T 2121.4, Ltr 0.0081, Lge4 0.0128, Lge7 0.0111, Lge11 0.0329, TimeStep 001

# %%
var = [v for v in tf.trainable_variables() if v.name == 'MLPGraphNetwork/graph_network/edge_block/mlp/linear_0/w:0']
post_train_np = sess.run(var)
print(np.array(post_train_np)-np.array(pre_train_np))
# Out:
# [[[-0.06808893 -0.04346391 -0.02269235 ... -0.00508534 -0.0157256
#    -0.09697145]
#   [-0.00682849 -0.01216145 -0.01389384 ... -0.07665279  0.00464014
#     0.07394841]
#   [-0.07953324  0.0678984  -0.04925974 ...  0.016096    0.05720433
#    -0.12290478]
#   ...
#   [-0.04562606  0.08314455 -0.04527233 ...  0.01716291  0.08508138
#     0.11017892]
#   [-0.11809938 -0.06940524 -0.00462709 ... -0.01729921 -0.04772089
#     0.06006017]
#   [-0.0924091   0.07765627  0.03306558 ...  0.0194185   0.05294127
#    -0.02541873]]]

# %% [markdown]
# ## Save Model

# %%
if os.path.exists(os.path.join(path_saves, "model.ckpt")):
    print("The file: "+ "model.ckpt" + "already exists. Delete it before saving a new trajectory!")
else:
    save_path = saver.save(sess, os.path.join(path_saves)+"/model.ckpt")
    print("Model saved in path: %s" % save_path)
# Out:
# Model saved in path: /home/bence/git_workspace/Dyadic_Collaboration/Graph_Networks/Phases/Phase1/Two_ended_chain/damping/one_way/step_error/ntr=100000_btr=256_bge=100_date=021520_stepError_seed=4/Saves/model.ckpt

# %% [markdown]
# ## Load Model (Optional)

# %%
saver.restore(sess,os.path.join(path_saves)+"/model.ckpt")

var = [v for v in tf.trainable_variables() if v.name == 'MLPGraphNetwork/graph_network/edge_block/mlp/linear_0/w:0']
post_restore_np = sess.run(var)
print(np.array(post_restore_np))
# Out:
# INFO:tensorflow:Restoring parameters from /home/bence/git_workspace/Dyadic_Collaboration/Graph_Networks/Phases/Phase1/Two_ended_chain/Saves/ntr=3000_btr=256_bge=100date=020620/model.ckpt
# [[[-0.03615981  0.08480582  0.05031766 ...  0.00408229  0.15642138
#    -0.04161644]
#   [ 0.0719505  -0.01148265 -0.0835845  ...  0.10142673  0.12743555
#     0.00599778]
#   [-0.10257607  0.10264786  0.04341802 ...  0.06374927  0.1320276
#     0.04256159]
#   ...
#   [-0.00689922  0.05856967  0.15907852 ...  0.07085051  0.09101491
#    -0.14054282]
#   [ 0.06527713  0.02646459 -0.02397825 ... -0.0045441   0.01278247
#    -0.02234338]
#   [ 0.04215148 -0.15728731 -0.13071597 ... -0.15650336 -0.01082023
#     0.13159135]]]

# %% [markdown]
# ## Save Trajectories

# %%
#Describe the experiment


def get_node_trajectories(rollout_array, batch_size):
    return np.split(rollout_array[..., :2], batch_size, axis=1)

#Store the data
true_rollouts_4 = get_node_trajectories(test_values["true_rollout_4"],batch_size_ge)
true_trajectory_4_np = np.array(true_rollouts_4)

predicted_rollouts_4 = get_node_trajectories(test_values["predicted_rollout_4"],batch_size_ge)
predicted_trajectory_4_np=np.array(predicted_rollouts_4)

true_rollouts_7 = get_node_trajectories(test_values["true_rollout_7"],batch_size_ge)
true_trajectory_7_np = np.array(true_rollouts_7)

predicted_rollouts_7 = get_node_trajectories(test_values["predicted_rollout_7"],batch_size_ge)
predicted_trajectory_7_np=np.array(predicted_rollouts_7)

true_rollouts_11 = get_node_trajectories(test_values["true_rollout_11"],batch_size_ge)
true_trajectory_11_np = np.array(true_rollouts_11)

predicted_rollouts_11 = get_node_trajectories(test_values["predicted_rollout_11"],batch_size_ge)
predicted_trajectory_11_np=np.array(predicted_rollouts_11)


l_names = ["true_trajectory_4.npy",
           "predicted_trajectory_4.npy",
           "true_trajectory_7.npy",
           "predicted_trajectory_7.npy",
           "true_trajectory_11.npy",
           "predicted_trajectory_11.npy"]

l_data = [true_trajectory_4_np,
          predicted_trajectory_4_np,
          true_trajectory_7_np,
          predicted_trajectory_7_np,
          true_trajectory_11_np,
          predicted_trajectory_11_np]


for fname, fdata in zip(l_names,l_data):
    if os.path.exists(os.path.join(path_saves, fname)):
        print("The file: "+ fname + "already exists. Delete it before saving a new trajectory!")
    else:
        if not os.path.exists(os.path.join(path_saves)):
            os.mkdir(os.path.join(path_saves)) 
        np.save(os.path.join(path_saves, fname), fdata)

# %%
# Choose a simulated system
index_of_simulated_system = -1

spring_const = spring_constants_ge[index_of_simulated_system]
damping_ratio = damping_ratios_ge[index_of_simulated_system]

true_trajectory_4_np = true_trajectory_4_np[index_of_simulated_system]
predicted_trajectory_4_np = predicted_trajectory_4_np[index_of_simulated_system]
true_trajectory_7_np = true_trajectory_7_np[index_of_simulated_system]
predicted_trajectory_7_np = predicted_trajectory_7_np[index_of_simulated_system]
true_trajectory_11_np = true_trajectory_11_np[index_of_simulated_system]
predicted_trajectory_11_np = predicted_trajectory_11_np[index_of_simulated_system]

# %% [markdown]
# ## Plot and Save Convergence plot

# %%
fig = plt.figure(1, figsize=(16, 3))
fig.clf()
x = np.array(logged_iterations)



if os.path.exists(os.path.join(path_saves, "logged_iterations")):
    print("The file: "+ "logged_iterations" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "logged_iterations"), x)
    
if os.path.exists(os.path.join(path_saves, "logged_time_steps")):
    print("The file: "+ "logged_time_steps" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "logged_time_steps"), logged_timesteps)
        
# Next-step Loss.
y = losses_tr
ax = fig.add_subplot(1, 4, 1)
ax.plot(x, y, "k")
ax.set_title("Next step loss: Training")

if os.path.exists(os.path.join(path_saves, "losses_tr")):
    print("The file: "+ "losses_tr" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_tr"), losses_tr)


        
# Rollout 4 loss.
y = losses_4_step_ge
ax = fig.add_subplot(1, 4, 2)
ax.plot(x, y, "k")
ax.set_title("Rollout loss: 4-mass string")

if os.path.exists(os.path.join(path_saves, "losses_4_step_ge")):
    print("The file: "+ "losses_4_step_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_4_step_ge"), losses_4_step_ge)

if os.path.exists(os.path.join(path_saves, "losses_4_ge")):
    print("The file: "+ "losses_4_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_4_ge"), losses_4_ge)


# Rollout 7 loss.
y = losses_7_step_ge
ax = fig.add_subplot(1, 4, 3)
ax.plot(x, y, "k")
ax.set_title("Rollout loss: 7-mass string")

if os.path.exists(os.path.join(path_saves, "losses_7_step_ge")):
    print("The file: "+ "losses_7_step_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_7_step_ge"), losses_7_step_ge)

if os.path.exists(os.path.join(path_saves, "losses_7_ge")):
    print("The file: "+ "losses_7_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_7_ge"), losses_7_ge)

# Rollout 11 loss.
y = losses_11_step_ge
ax = fig.add_subplot(1, 4, 4)
ax.plot(x, y, "k")
ax.set_title("Rollout loss: 11-mass string")

if os.path.exists(os.path.join(path_saves, "losses_11_step_ge")):
    print("The file: "+ "losses_11_step_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_11_step_ge"), losses_11_step_ge)    
    
if os.path.exists(os.path.join(path_saves, "losses_11_ge")):
    print("The file: "+ "losses_11_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_11_ge"), losses_11_ge)   

plt.show()
#batch_size_tr = 256
#batch_size_ge = 100
        

#Save figure
if os.path.exists(os.path.join(path_plots,"ConvergencePlot.png")):
    print("The file: "+ "ConvergencePlot.png" + "already exists. Delete it before saving a new plot!")
else:
    if not os.path.exists(os.path.join(path_plots)):
        os.mkdir(os.path.join(path_plots))
                  
    fig.savefig(os.path.join(path_plots,"ConvergencePlot.png"))
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %% [markdown]
# ## Plot and Save Trajectories Error plot

# %% [markdown]
# ### Plot generated groundtruth for 4 mass system

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 4
edges = []
time_text = ax3.text(-5, 5, "Frame: "+str(0),fontsize=12)
num_nodes = true_trajectory_4_np.shape[1]
    
def init():
    for i in range(num_nodes-1):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
                     
    return edges,time_text
    
ax3.set_xlim(-6, 6)
ax3.set_ylim(-6, 6)


def animate(z):
    true_tr = true_trajectory_4_np[z]                               
    time_text.set_text("Frame: "+str(z))
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],[true_tr[left,1],true_tr[right,1]])
    legend = ax3.legend()
    return edges, legend,time_text

ax3.set_title("Trajectory: n = 4, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_4_masses.gif")):
    print("The file: "+ "ground_truth_trajectory_4_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations, "GroundTruth")):
        os.makedirs(os.path.join(path_animations, "GroundTruth"))
                  
    anim.save(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_4_masses.gif"), writer='imagemagick', fps=20)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### Plot generated groundtruth for 7 mass system

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 7
edges = []

time_text = ax3.text(-5, 5, "Frame: "+str(0),fontsize=12)
num_nodes = true_trajectory_7_np.shape[1]

def init():
    for i in range(num_nodes-1):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
                     
    return edges,time_text
    
ax3.set_xlim(-6, 6)
ax3.set_ylim(-6, 6)


def animate(z):
    true_tr = true_trajectory_7_np[z]                                
    time_text.set_text("Frame: "+str(z))        
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],
                                           [true_tr[left,1],true_tr[right,1]])
        
                     
    legend = ax3.legend()
    return legend, edges,time_text

ax3.set_title("Trajectory: n = 7, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_7_masses.gif")):
    print("The file: "+ "ground_truth_trajectory_7_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"GroundTruth")):
        os.makedirs(os.path.join(path_animations,"GroundTruth"))
                  
    anim.save(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_7_masses.gif"), writer='imagemagick', fps=20)

                     

plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### Plot generated groundtruth for 11 mass system

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 11
edges = []

time_text = ax3.text(-8, 8, "Frame: "+str(0),fontsize=12)
num_nodes = true_trajectory_11_np.shape[1]

def init():
    for i in range(num_nodes-1):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
                     
    return edges,time_text
    
ax3.set_xlim(-9, 9)
ax3.set_ylim(-9, 9)


def animate(z):
    true_tr = true_trajectory_11_np[z]                                
    time_text.set_text("Frame: "+str(z))        
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],
                                           [true_tr[left,1],true_tr[right,1]])
        
                     
    legend = ax3.legend()
    return legend, edges,time_text

ax3.set_title("Trajectory: n = 11, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_11_masses.gif")):
    print("The file: "+ "ground_truth_trajectory_11_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"GroundTruth")):
        os.makedirs(os.path.join(path_animations,"GroundTruth"))
                  
    anim.save(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_11_masses.gif"), writer='imagemagick', fps=20)

                     

plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### 4 masses

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 4

edges = []
edges1 = []

time_text = ax3.text(-5, 5, "Frame: "+str(0),fontsize=12)
num_nodes = true_trajectory_4_np.shape[1]
    
def init():
    for i in range(num_nodes-1):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k",label="Prediction"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k"))
    return edges,edges1,time_text
    
ax3.set_xlim(-6, 6)
ax3.set_ylim(-6, 6)


def animate(z):
    
    true_tr = true_trajectory_4_np[z]
    pred_tr = predicted_trajectory_4_np[z]                              
    time_text.set_text("Frame: "+str(z))
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],[true_tr[left,1],true_tr[right,1]])
        edges1[i][0].set_data([pred_tr[left,0],pred_tr[right,0]],[pred_tr[left,1],pred_tr[right,1]])
        
    legend = ax3.legend()
    return legend,edges,edges1,time_text


ax3.set_title("Rollout Trajectory: n = 4, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"FullRollout","trajectory_4_masses.gif")):
    print("The file: "+ "trajectory_4_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"FullRollout")):
        os.mkdir(os.path.join(path_animations,"FullRollout"))
                  
    anim.save(os.path.join(path_animations,"FullRollout","trajectory_4_masses.gif"), writer='imagemagick', fps=20)

               
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### 7 masses

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 7
edges = []
edges1 = []

num_nodes = true_trajectory_7_np.shape[1]
time_text = ax3.text(-5, 5, "Frame: "+str(0),fontsize=12)
    
def init():
    for i in range(num_nodes):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k",label="Prediction"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k"))
    return edges,edges1,time_text
    
ax3.set_xlim(-6, 6)
ax3.set_ylim(-6, 6)


def animate(z):
    true_tr = true_trajectory_7_np[z]
    pred_tr = predicted_trajectory_7_np[z]                              
    time_text.set_text("Frame: "+str(z))
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],[true_tr[left,1],true_tr[right,1]])
        edges1[i][0].set_data([pred_tr[left,0],pred_tr[right,0]],[pred_tr[left,1],pred_tr[right,1]])
    legend = ax3.legend()
    return edges,edges1,legend,time_text




ax3.set_title("Rollout Trajectory: n = 7, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"FullRollout","trajectory_7_msses.gif")):
    print("The file: "+ "trajectory_7_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"FullRollout")):
        os.mkdir(os.path.join(path_animations,"FullRollout"))
                  
    anim.save(os.path.join(path_animations,"FullRollout","trajectory_7_masses.gif"), writer='imagemagick', fps=20)

    
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### 11 masses

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 11
edges = []
edges1 = []

num_nodes = true_trajectory_11_np.shape[1]
time_text = ax3.text(-8, 8, "Frame: "+str(0),fontsize=12)
    
def init():
    for i in range(num_nodes):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k",label="Prediction"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k"))
    return edges,edges1,time_text
    
ax3.set_xlim(-9, 9)
ax3.set_ylim(-9, 9)


def animate(z):
    true_tr = true_trajectory_11_np[z]
    pred_tr = predicted_trajectory_11_np[z]                              
    time_text.set_text("Frame: "+str(z))
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],[true_tr[left,1],true_tr[right,1]])
        edges1[i][0].set_data([pred_tr[left,0],pred_tr[right,0]],[pred_tr[left,1],pred_tr[right,1]])
    legend = ax3.legend()
    return edges,edges1,legend,time_text




ax3.set_title("Rollout Trajectory: n = 11, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"FullRollout","trajectory_11_msses.gif")):
    print("The file: "+ "trajectory_11_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"FullRollout")):
        os.mkdir(os.path.join(path_animations,"FullRollout"))
                  
    anim.save(os.path.join(path_animations,"FullRollout","trajectory_11_masses.gif"), writer='imagemagick', fps=20)

    
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">
