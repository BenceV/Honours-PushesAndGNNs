# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
# %matplotlib notebook
import time
import datetime

#Save experiment begin date
current_time = datetime.datetime.now()
print("Current_date: "+str(current_time))
current_time = "".join(current_time.strftime("%x").split('/'))

#Import usual things required for graph nets
import numpy as np
import pandas as pd
import networkx as nx
import sonnet as snt
import tensorflow as tf
import os
import sys
from matplotlib import pyplot as plt
from matplotlib import animation
import seaborn as sns

#Import graph nets
from graph_nets import blocks
from graph_nets import utils_tf
from graph_nets import utils_np
from graph_nets.demos import models

#Change here
num_training_iterations = 100000
batch_size_tr = 256
batch_size_ge = 100
num_time_steps = 50

desc = "ntr="+str(num_training_iterations)
desc = desc +"_btr="+str(batch_size_tr)
desc = desc +"_bge="+str(batch_size_ge)
desc = desc +"_date="+str(current_time)
desc = desc +"_stepError_"

#Set seed
SEED = 5
desc = desc +"seed="+str(SEED)

#Path to the scripts shared troughout phases
parent_path=os.path.abspath('..')
path_common =  '/'.join(parent_path.split('/')[:-1])
path_common = os.path.join(path_common,'Common','Scripts')
#Check if path exists
if(not os.path.exists(path_common)):
    print('The path: '+ os.path.exists(path_common)+' is not found!')
#Add shared scripts to our current paths for importing
sys.path.insert(0, path_common)

base = os.path.join(parent_path,'One_ended_chain','damping')
if(not os.path.exists(base)):
    os.makedirs(base)
#Path to saved models and trajectories
path_saves = os.path.join(base,desc,'Saves')
if(not os.path.exists(path_saves)):
    os.makedirs(path_saves)
#Path to plots
path_plots = os.path.join(base,desc,'Plots')
if(not os.path.exists(path_plots)):
    os.makedirs(path_plots)
#Path to animations
path_animations = os.path.join(base,desc,'Animations')
if(not os.path.exists(path_animations)):
    os.makedirs(path_animations)



np.random.seed(SEED)
tf.set_random_seed(SEED)
# Out:
# Current_date: 2020-02-22 21:05:16.380733
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## Import functions

# %%
#Import functions for simulating
from Simulation_Functions_extended import SpringMassSimulator, generate_trajectory, roll_out_physics
#Import functions for creating graph
from Graph_creator_functions import chain_graph_one_ended_extended_one_way
#Import visualisation functions

# %% [markdown]
# ## Define loss functions

# %%
def create_loss_ops(target_op, output_ops):
    """Create supervised loss operations from targets and outputs.

    Args:
        target_op: The target velocity tf.Tensor.
        output_ops: The list of output graphs from the model.

    Returns:
        A list of loss values (tf.Tensor), one per output op.""" 
    loss_ops = [
            tf.reduce_mean(
            tf.reduce_sum((tf.cast(output_op.nodes,tf.float64) - tf.cast(target_op[..., 2:4],tf.float64))**2, axis=-1))
            for output_op in output_ops
    ]
    return loss_ops


def make_all_runnable_in_session(*args):
    """Apply make_runnable_in_session to an iterable of graphs."""
    return [utils_tf.make_runnable_in_session(a) for a in args]

# %% [markdown]
# # Define the Model

# %%
tf.reset_default_graph()
# Create the model.
model = models.EncodeProcessDecode(node_output_size=2)
# Out:
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/base.py:177: The name tf.make_template is deprecated. Please use tf.compat.v1.make_template instead.
#
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/base.py:278: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/base.py:579: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.

# %% [markdown]
# # Training the Network: Chain
# ## Generate:
# - Model
# - Training trajectory 5 to 9 masses
# - Generalization trajectories: 4 mass, 7 mass and 11 mass

# %%
#@title Set up model training and evaluation  { form-width: "30%" }

# The model we explore includes three components:
# - An "Encoder" graph net, which independently encodes the edge, node, and
#   global attributes (does not compute relations etc.).
# - A "Core" graph net, which performs N rounds of processing (message-passing)
#   steps. The input to the Core is the concatenation of the Encoder's output
#   and the previous output of the Core (labeled "Hidden(t)" below, where "t" is
#   the processing step).
# - A "Decoder" graph net, which independently decodes the edge, node, and
#   global attributes (does not compute relations etc.), on each
#   message-passing step.
#
#                     Hidden(t)   Hidden(t+1)
#                        |            ^
#           *---------*  |  *------*  |  *---------*
#           |         |  |  |      |  |  |         |
# Input --->| Encoder |  *->| Core |--*->| Decoder |---> Output(t)
#           |         |---->|      |     |         |
#           *---------*     *------*     *---------*
#
# The model is trained by supervised learning. Input mass-spring systems are
# procedurally generated, where the nodes represent the positions, velocities,
# and indicators of whether the mass is fixed in space or free to move, the
# edges represent the spring constant and spring rest length, and the global
# attribute represents the variable coefficient of gravitational acceleration.
# The outputs/targets have the same structure, with the nodes representing the
# masses' next-step states.
#
# The training loss is computed on the output of each processing step. The
# reason for this is to encourage the model to try to solve the problem in as
# few steps as possible. It also helps make the output of intermediate steps
# more interpretable.
#
# There's no need for a separate evaluate dataset because the inputs are
# never repeated, so the training loss is the measure of performance on graphs
# from the input distribution.
#
# We also evaluate how well the models generalize to systems which are one mass
# larger, and smaller, than those from the training distribution. The loss is
# computed as the mean over a 50-step rollout, where each step's input is the
# the previous step's output.
#
# Variables with the suffix _tr are training parameters, and variables with the
# suffix _ge are test/generalization parameters.
#
# After around 10000-20000 training iterations the model reaches good
# performance on mass-spring systems with 5-8 masses.


rand = np.random.RandomState(SEED)

# Model parameters.
num_processing_steps_tr = 1
num_processing_steps_ge = 1

step_size = 0.1
num_masses_min_max_tr = (5, 9)
dist_between_masses_min_max_tr = (0.2, 1.0)
spring_constant_min_max_tr = (40,60)
damping_ratio_min_max_tr = (0.3,0.6)

# Data.
# Base graphs for training.
num_masses_tr = rand.randint(*num_masses_min_max_tr, size=batch_size_tr)
dist_between_masses_tr = rand.uniform(*dist_between_masses_min_max_tr, size=batch_size_tr)
spring_constants_tr = rand.randint(*spring_constant_min_max_tr, size=batch_size_tr)
damping_ratios_tr = rand.uniform(*damping_ratio_min_max_tr, size=batch_size_tr)

dict_rands = {"num_masses":num_masses_tr,
              "distances":dist_between_masses_tr,
              "spring_constants":spring_constants_tr,
              "damping_ratios":damping_ratios_tr}


if os.path.exists(os.path.join(path_saves, "training_examples")):
    print("The file: "+ "training_examples" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "training_examples"), dict_rands)
    


static_graph_tr = [chain_graph_one_ended_extended_one_way(n,k,d,r) for n, d, k, r in zip(num_masses_tr,
                                                                               dist_between_masses_tr,
                                                                               spring_constants_tr,
                                                                               damping_ratios_tr)]
base_graph_tr = utils_tf.data_dicts_to_graphs_tuple(static_graph_tr)

# Base graphs for testing.
spring_constant_min_max_ge = (25,75)
damping_ratio_min_max_ge = (0.0,0.3)

spring_constants_ge = rand.randint(*spring_constant_min_max_ge, size=batch_size_ge)
damping_ratios_ge = rand.uniform(*damping_ratio_min_max_ge, size=batch_size_ge)


# 4 masses 1m apart in a chain like structure.
static_graph_4_ge = [chain_graph_one_ended_extended_one_way(4, k ,0.5,r) for k, r in zip(spring_constants_ge,
                                                                               damping_ratios_ge)]
base_graph_4_ge = utils_tf.data_dicts_to_graphs_tuple(static_graph_4_ge)
    
# 7 masses 0.5m apart in a chain like structure.
static_graph_7_ge = [chain_graph_one_ended_extended_one_way(7, k ,0.5,r) for k, r in zip(spring_constants_ge,
                                                                               damping_ratios_ge)]
base_graph_7_ge = utils_tf.data_dicts_to_graphs_tuple(static_graph_7_ge)

# 11 masses 0.5m apart in a chain like structure.
static_graph_11_ge = [chain_graph_one_ended_extended_one_way(11, k ,0.5,r) for k, r in zip(spring_constants_ge,
                                                                               damping_ratios_ge)]
base_graph_11_ge = utils_tf.data_dicts_to_graphs_tuple(static_graph_11_ge)



# True physics simulator for data generation.
simulator = SpringMassSimulator(step_size=step_size)
# Training.
# Generate a training trajectory by adding noise to initial
# position, spring constants and gravity
initial_conditions_tr, true_trajectory_tr = generate_trajectory(
    simulator,
    base_graph_tr,
    num_time_steps,
    step_size,
    node_noise_level=0.04,
    edge_noise_level=5.0,
    global_noise_level=1.0,
    do_set_rest=True,
    do_apply_gravity=True)
# Random start step.
t = tf.random_uniform([], minval=0, maxval=num_time_steps - 1, dtype=tf.int32)
input_graph_tr = initial_conditions_tr.replace(nodes=true_trajectory_tr[t])
target_nodes_tr = true_trajectory_tr[t + 1]

output_ops_tr = model(input_graph_tr, num_processing_steps_tr)

# Test data: 4-mass string.
initial_conditions_4_ge, true_trajectory_4_ge = generate_trajectory(
    simulator,
    base_graph_4_ge,
    num_time_steps,
    step_size,
    node_noise_level=0.04,
    edge_noise_level=5.0,
    global_noise_level=1.0,
    do_set_rest=True,
    do_apply_gravity=True)

input_graph_4_ge = initial_conditions_4_ge.replace(nodes=true_trajectory_4_ge[t])
target_nodes_4_ge = true_trajectory_4_ge[t + 1]

output_ops_4_ge = model(input_graph_4_ge, num_processing_steps_ge)

_, true_nodes_rollout_4_ge = roll_out_physics(
    simulator, initial_conditions_4_ge, num_time_steps, step_size)
_, predicted_nodes_rollout_4_ge = roll_out_physics(
    lambda x: model(x, num_processing_steps_ge), initial_conditions_4_ge,
    num_time_steps, step_size)



# Test data: 7-mass string.
initial_conditions_7_ge, true_trajectory_7_ge = generate_trajectory(
    simulator,
    base_graph_7_ge,
    num_time_steps,
    step_size,
    node_noise_level=0.04,
    edge_noise_level=5.0,
    global_noise_level=1.0,
    do_set_rest=True,
    do_apply_gravity=True)

input_graph_7_ge = initial_conditions_7_ge.replace(nodes=true_trajectory_7_ge[t])
target_nodes_7_ge = true_trajectory_7_ge[t + 1]

output_ops_7_ge = model(input_graph_7_ge, num_processing_steps_ge)

_, true_nodes_rollout_7_ge = roll_out_physics(
    simulator, initial_conditions_7_ge, num_time_steps, step_size)
_, predicted_nodes_rollout_7_ge = roll_out_physics(
    lambda x: model(x, num_processing_steps_ge), initial_conditions_7_ge,
    num_time_steps, step_size)



# Test data: 11-mass string.
initial_conditions_11_ge, true_trajectory_11_ge = generate_trajectory(
    simulator,
    base_graph_11_ge,
    num_time_steps,
    step_size,
    node_noise_level=0.04,
    edge_noise_level=5.0,
    global_noise_level=1.0,
    do_set_rest=True,
    do_apply_gravity=True)
    
input_graph_11_ge = initial_conditions_11_ge.replace(nodes=true_trajectory_11_ge[t])
target_nodes_11_ge = true_trajectory_11_ge[t + 1]

output_ops_11_ge = model(input_graph_11_ge, num_processing_steps_ge)


_, true_nodes_rollout_11_ge = roll_out_physics(
    simulator, initial_conditions_11_ge, num_time_steps, step_size)
_, predicted_nodes_rollout_11_ge = roll_out_physics(
    lambda x: model(x, num_processing_steps_ge), initial_conditions_11_ge,
    num_time_steps, step_size)






# Training loss.
loss_ops_tr = create_loss_ops(target_nodes_tr, output_ops_tr)
# Training loss across processing steps.
loss_op_tr = sum(loss_ops_tr) / num_processing_steps_tr

# Test/generalization loss: 4-mass.
loss_ops_4_ge = create_loss_ops(target_nodes_4_ge,output_ops_4_ge)
loss_op_step_4_ge = sum(loss_ops_4_ge) / num_processing_steps_tr
loss_op_4_ge = tf.reduce_mean(
    tf.reduce_sum(
        (predicted_nodes_rollout_4_ge[..., 2:4] -
         true_nodes_rollout_4_ge[..., 2:4])**2,
        axis=-1))

#Test/generalization loss: 7-mass string.
loss_ops_7_ge = create_loss_ops(target_nodes_7_ge,output_ops_7_ge)
loss_op_step_7_ge = sum(loss_ops_7_ge) / num_processing_steps_ge
loss_op_7_ge = tf.reduce_mean(
    tf.reduce_sum(
        (predicted_nodes_rollout_7_ge[..., 2:4] -
         true_nodes_rollout_7_ge[..., 2:4])**2,
        axis=-1))

# Test/generalization loss: 11-mass string.
loss_ops_11_ge = create_loss_ops(target_nodes_11_ge,output_ops_11_ge)
loss_op_step_11_ge = sum(loss_ops_11_ge) / num_processing_steps_ge
loss_op_11_ge = tf.reduce_mean(
    tf.reduce_sum(
        (predicted_nodes_rollout_11_ge[..., 2:4] -
         true_nodes_rollout_11_ge[..., 2:4])**2,
        axis=-1))




# Optimizer.
learning_rate = 1e-3
optimizer = tf.train.AdamOptimizer(learning_rate)
step_op = optimizer.minimize(loss_op_tr)

input_graph_tr = make_all_runnable_in_session(input_graph_tr)
initial_conditions_4_ge = make_all_runnable_in_session(initial_conditions_4_ge)
initial_conditions_7_ge = make_all_runnable_in_session(initial_conditions_7_ge)
initial_conditions_11_ge = make_all_runnable_in_session(initial_conditions_11_ge)
# Out:
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/bence/git_workspace/Dyadic_Collaboration/Graph_Networks/Phases/Common/Scripts/Simulation_Functions_extended.py:75: The name tf.unsorted_segment_sum is deprecated. Please use tf.math.unsorted_segment_sum instead.
#
# WARNING:tensorflow:From /home/bence/git_workspace/Dyadic_Collaboration/Graph_Networks/Phases/Common/Scripts/Simulation_Functions_extended.py:185: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/basic.py:126: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/basic.py:131: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/sonnet/python/modules/basic.py:247: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.

# %%
print(spring_constants_ge)
print(damping_ratios_ge)
# Out:
# [62 57 54 61 32 62 40 39 45 39 63 50 67 62 56 55 48 62 28 45 65 63 63 36
#  45 36 51 67 73 73 62 46 72 37 50 41 39 37 35 29 33 74 59 53 31 60 60 67
#  56 44 41 53 71 58 34 50 71 45 28 71 51 33 44 58 28 28 35 47 31 42 58 56
#  53 30 66 68 60 58 30 68 52 55 36 54 74 25 37 46 39 54 50 74 32 48 42 43
#  63 33 56 71]
# [0.01513149 0.21635886 0.19643398 0.02521004 0.15935954 0.0013339
#  0.23324131 0.12744037 0.21050204 0.11580501 0.23364909 0.2611567
#  0.02214443 0.26859075 0.08332964 0.16101312 0.01874859 0.10233488
#  0.15594468 0.17711551 0.10346779 0.21256374 0.20115291 0.20800519
#  0.04167805 0.21020537 0.13323717 0.17321255 0.10647864 0.17603076
#  0.00099313 0.01898057 0.02446337 0.15012669 0.16451686 0.20963401
#  0.13650137 0.16577331 0.08541757 0.2838721  0.25078142 0.11779819
#  0.28000174 0.00151905 0.14773608 0.11339901 0.24019261 0.12228423
#  0.08669139 0.27984923 0.00239605 0.05987985 0.2502468  0.2910727
#  0.17401056 0.29681223 0.24613455 0.11342721 0.22117765 0.03337162
#  0.13211893 0.00205483 0.25418182 0.20052388 0.01752296 0.19716827
#  0.0483573  0.08510864 0.07483904 0.22445188 0.23398405 0.01681041
#  0.29793549 0.19246773 0.04883923 0.23503154 0.25326128 0.24312072
#  0.17627934 0.18054283 0.13289912 0.14736737 0.06586373 0.16186799
#  0.05594187 0.23483453 0.0896158  0.02868849 0.04263508 0.28066677
#  0.2417066  0.04268474 0.22139875 0.05474416 0.10830533 0.17285459
#  0.1262887  0.12674673 0.19581583 0.16472744]

# %% [markdown]
# ### Reset Tensorflow session, but keep the same computational graph.

# %%
#@title Reset session  { form-width: "30%" }


saver = tf.train.Saver()
# This cell resets the 
try:
    sess.close()
except NameError:
    pass
sess = tf.Session()
sess.run(tf.global_variables_initializer())

var = [v for v in tf.trainable_variables() if v.name == 'MLPGraphNetwork/graph_network/edge_block/mlp/linear_0/w:0']
pre_train_np = sess.run(var)
print(pre_train_np)


last_iteration = 0
logged_iterations = []
logged_timesteps = []
losses_tr = []
losses_4_ge = []
losses_4_step_ge = []
losses_7_ge = []
losses_7_step_ge = []
losses_11_ge = []
losses_11_step_ge = []
# Out:
# [array([[ 0.1069105 ,  0.01536363,  0.06982477, ...,  0.05637925,
#          0.06999607, -0.02865723],
#        [ 0.09225084,  0.09277643, -0.05105245, ...,  0.15433246,
#         -0.08997808,  0.13243389],
#        [ 0.0372132 , -0.1316775 ,  0.01467187, ..., -0.07742055,
#          0.00476397, -0.11803041],
#        ...,
#        [ 0.07880688, -0.07510471,  0.10115135, ..., -0.0154298 ,
#          0.0527211 ,  0.07230595],
#        [ 0.07572528,  0.08059545, -0.02252672, ...,  0.08057552,
#          0.07065666,  0.10114778],
#        [-0.0344804 , -0.02776819,  0.07846209, ...,  0.15652628,
#         -0.06683365,  0.03497807]], dtype=float32)]

# %% [markdown]
# ### Train Network

# %%
#@title Run training  { form-width: "30%" }

# You can interrupt this cell's training loop at any time, and visualize the
# intermediate results by running the next cell (below). You can then resume
# training by simply executing this cell again.

# How much time between logging and printing the current results.
log_every_iteration = 250

print("# (iteration number), T (elapsed seconds), "
      "Ltr (training 1-step loss), "
      "Lge4 (test/generalization rollout loss for 4-mass strings), "
      "Lge9 (test/generalization rollout loss for 7-mass strings), "
      "Lge11 (test/generalization rollout loss for 11-mass strings)")

start_time = time.time()
last_log_time = start_time
for iteration in range(last_iteration, num_training_iterations):
    last_iteration = iteration
    train_values = sess.run({
        "step": step_op,
        "loss": loss_op_tr,
        "input_graph": input_graph_tr,
        "target_nodes": target_nodes_tr,
        "outputs": output_ops_tr,
        "time_step":t
    })
    if last_iteration % log_every_iteration == 0:
        
        the_time = time.time()
        elapsed_since_last_log = the_time - last_log_time
        last_log_time = the_time
        test_values = sess.run({
            "step_loss_4":loss_op_step_4_ge,
            "loss_4": loss_op_4_ge,
            "true_rollout_4": true_nodes_rollout_4_ge,
            "predicted_rollout_4": predicted_nodes_rollout_4_ge,
            "step_loss_7":loss_op_step_7_ge,
            "loss_7": loss_op_7_ge,
            "true_rollout_7": true_nodes_rollout_7_ge,
            "predicted_rollout_7": predicted_nodes_rollout_7_ge,
            "step_loss_11":loss_op_step_11_ge,
            "loss_11": loss_op_11_ge,
            "true_rollout_11": true_nodes_rollout_11_ge,
            "predicted_rollout_11": predicted_nodes_rollout_11_ge
        })
        elapsed = time.time() - start_time
        losses_tr.append(train_values["loss"])
        losses_4_ge.append(test_values["loss_4"])
        losses_4_step_ge.append(test_values["step_loss_4"])
        losses_7_ge.append(test_values["loss_7"])
        losses_7_step_ge.append(test_values["step_loss_7"])
        losses_11_ge.append(test_values["loss_11"])
        losses_11_step_ge.append(test_values["step_loss_11"])
        logged_iterations.append(iteration)
        logged_timesteps.append(train_values["time_step"])
        print("# {:05d}, T {:.1f}, Ltr {:.4f}, Lge4 {:.4f}, Lge7 {:.4f}, Lge11 {:.4f}, TimeStep {:03d}".format(
            iteration, elapsed, train_values["loss"], test_values["step_loss_4"],
            test_values["step_loss_7"],test_values["step_loss_11"],train_values["time_step"]))
# Out:
# # (iteration number), T (elapsed seconds), Ltr (training 1-step loss), Lge4 (test/generalization rollout loss for 4-mass strings), Lge9 (test/generalization rollout loss for 7-mass strings), Lge11 (test/generalization rollout loss for 11-mass strings)
# # 00000, T 2.0, Ltr 28.2688, Lge4 7.0045, Lge7 11.1011, Lge11 18.8185, TimeStep 008
# # 00250, T 7.4, Ltr 0.7344, Lge4 3.8449, Lge7 9.9169, Lge11 8.8788, TimeStep 040
# # 00500, T 12.7, Ltr 0.6813, Lge4 0.2453, Lge7 0.2500, Lge11 0.4766, TimeStep 025
# # 00750, T 18.1, Ltr 0.4314, Lge4 3.1443, Lge7 6.3724, Lge11 8.2460, TimeStep 041
# # 01000, T 23.4, Ltr 0.5263, Lge4 1.4062, Lge7 1.3987, Lge11 16.9176, TimeStep 021
# # 01250, T 28.8, Ltr 0.7297, Lge4 2.3069, Lge7 2.4931, Lge11 12.4423, TimeStep 011
# # 01500, T 34.1, Ltr 0.3949, Lge4 0.4556, Lge7 0.3368, Lge11 0.5855, TimeStep 032
# # 01750, T 39.5, Ltr 0.2537, Lge4 1.4742, Lge7 2.4569, Lge11 8.9384, TimeStep 042
# # 02000, T 44.8, Ltr 0.3473, Lge4 0.3726, Lge7 0.3837, Lge11 0.6154, TimeStep 037
# # 02250, T 50.1, Ltr 0.3013, Lge4 0.3867, Lge7 0.8177, Lge11 1.4282, TimeStep 024
# # 02500, T 55.4, Ltr 0.2522, Lge4 0.1386, Lge7 0.1687, Lge11 0.2054, TimeStep 037
# # 02750, T 60.8, Ltr 0.2261, Lge4 1.9717, Lge7 2.7075, Lge11 7.5818, TimeStep 038
# # 03000, T 66.1, Ltr 0.3315, Lge4 2.7025, Lge7 3.9390, Lge11 3.7159, TimeStep 021
# # 03250, T 71.4, Ltr 0.4182, Lge4 0.9778, Lge7 1.4816, Lge11 10.4584, TimeStep 029
# # 03500, T 76.7, Ltr 0.2691, Lge4 1.7716, Lge7 2.0894, Lge11 7.6950, TimeStep 023
# # 03750, T 82.0, Ltr 0.4426, Lge4 1.9813, Lge7 3.3125, Lge11 3.5690, TimeStep 014
# # 04000, T 87.3, Ltr 0.1999, Lge4 0.0405, Lge7 0.0306, Lge11 0.0306, TimeStep 041
# # 04250, T 92.7, Ltr 0.0256, Lge4 0.5747, Lge7 1.3682, Lge11 6.1278, TimeStep 002
# # 04500, T 98.1, Ltr 0.1857, Lge4 2.2335, Lge7 3.0075, Lge11 3.8865, TimeStep 009
# # 04750, T 103.4, Ltr 0.2494, Lge4 1.6457, Lge7 1.7325, Lge11 8.9808, TimeStep 021
# # 05000, T 108.8, Ltr 0.1224, Lge4 0.0856, Lge7 0.0634, Lge11 0.0884, TimeStep 048
# # 05250, T 114.1, Ltr 0.2463, Lge4 0.7908, Lge7 1.7403, Lge11 5.4813, TimeStep 027
# # 05500, T 119.4, Ltr 0.2170, Lge4 1.8661, Lge7 1.6623, Lge11 7.7335, TimeStep 030
# # 05750, T 124.8, Ltr 0.2872, Lge4 0.2149, Lge7 0.1711, Lge11 0.1275, TimeStep 043
# # 06000, T 130.1, Ltr 0.7282, Lge4 1.7790, Lge7 1.9077, Lge11 8.7214, TimeStep 016
# # 06250, T 135.5, Ltr 0.0613, Lge4 1.6381, Lge7 2.8940, Lge11 4.0702, TimeStep 006
# # 06500, T 140.8, Ltr 0.1472, Lge4 1.0945, Lge7 1.7969, Lge11 5.6724, TimeStep 040
# # 06750, T 146.2, Ltr 0.1219, Lge4 0.5509, Lge7 1.1777, Lge11 3.3089, TimeStep 046
# # 07000, T 151.5, Ltr 0.3735, Lge4 1.1000, Lge7 1.0222, Lge11 9.5833, TimeStep 018
# # 07250, T 156.9, Ltr 0.1290, Lge4 1.6068, Lge7 1.8663, Lge11 6.8053, TimeStep 009
# # 07500, T 162.3, Ltr 0.1690, Lge4 0.8406, Lge7 1.3324, Lge11 5.3935, TimeStep 033
# # 07750, T 167.6, Ltr 0.3056, Lge4 1.9929, Lge7 2.9045, Lge11 3.9514, TimeStep 031
# # 08000, T 173.0, Ltr 0.2339, Lge4 1.7804, Lge7 1.7092, Lge11 6.9924, TimeStep 013
# # 08250, T 178.3, Ltr 0.2546, Lge4 2.0142, Lge7 2.5563, Lge11 4.0756, TimeStep 023
# # 08500, T 183.6, Ltr 0.3028, Lge4 0.1636, Lge7 0.1517, Lge11 0.1979, TimeStep 025
# # 08750, T 188.9, Ltr 0.3380, Lge4 1.8084, Lge7 1.8716, Lge11 8.1150, TimeStep 013
# # 09000, T 194.2, Ltr 0.1275, Lge4 0.4939, Lge7 0.2384, Lge11 0.2898, TimeStep 010
# # 09250, T 199.5, Ltr 0.2042, Lge4 0.0217, Lge7 0.0126, Lge11 0.0156, TimeStep 012
# # 09500, T 204.9, Ltr 0.1577, Lge4 2.2883, Lge7 3.0854, Lge11 3.3467, TimeStep 033
# # 09750, T 210.2, Ltr 0.0237, Lge4 1.7149, Lge7 1.5361, Lge11 8.0537, TimeStep 004
# # 10000, T 215.6, Ltr 0.1924, Lge4 2.2427, Lge7 3.0243, Lge11 2.7797, TimeStep 026
# # 10250, T 220.9, Ltr 0.2400, Lge4 0.9399, Lge7 1.1844, Lge11 4.1963, TimeStep 021
# # 10500, T 226.2, Ltr 0.1566, Lge4 0.4073, Lge7 0.3316, Lge11 0.4963, TimeStep 012
# # 10750, T 231.6, Ltr 0.1139, Lge4 0.8362, Lge7 0.9347, Lge11 5.4696, TimeStep 046
# # 11000, T 236.9, Ltr 0.1047, Lge4 0.0993, Lge7 0.0864, Lge11 0.0982, TimeStep 046
# # 11250, T 242.2, Ltr 0.2397, Lge4 0.0538, Lge7 0.0516, Lge11 0.0703, TimeStep 017
# # 11500, T 247.6, Ltr 0.1471, Lge4 1.7084, Lge7 1.8058, Lge11 6.3044, TimeStep 042
# # 11750, T 252.9, Ltr 0.1971, Lge4 0.0776, Lge7 0.0713, Lge11 0.0835, TimeStep 019
# # 12000, T 258.2, Ltr 0.1389, Lge4 0.3574, Lge7 0.3724, Lge11 0.7338, TimeStep 042
# # 12250, T 263.6, Ltr 0.0377, Lge4 0.4222, Lge7 0.3294, Lge11 0.5915, TimeStep 006
# # 12500, T 269.0, Ltr 0.1667, Lge4 0.7304, Lge7 0.9499, Lge11 6.5242, TimeStep 030
# # 12750, T 274.3, Ltr 0.1948, Lge4 1.6413, Lge7 2.3954, Lge11 3.5549, TimeStep 019
# # 13000, T 279.6, Ltr 0.0754, Lge4 1.2538, Lge7 1.7552, Lge11 4.1366, TimeStep 008
# # 13250, T 285.0, Ltr 0.1445, Lge4 1.3042, Lge7 1.6819, Lge11 3.6184, TimeStep 036
# # 13500, T 290.4, Ltr 0.0333, Lge4 1.9066, Lge7 2.1236, Lge11 4.0147, TimeStep 005
# # 13750, T 295.7, Ltr 0.1749, Lge4 0.1527, Lge7 0.1530, Lge11 0.1915, TimeStep 033
# # 14000, T 301.0, Ltr 0.1010, Lge4 1.5095, Lge7 2.4040, Lge11 3.3917, TimeStep 047
# # 14250, T 306.4, Ltr 0.0203, Lge4 0.0609, Lge7 0.0376, Lge11 0.0599, TimeStep 002
# # 14500, T 311.8, Ltr 0.1490, Lge4 1.3507, Lge7 1.9065, Lge11 3.4316, TimeStep 038
# # 14750, T 317.2, Ltr 0.1420, Lge4 2.4452, Lge7 2.6341, Lge11 2.6404, TimeStep 034
# # 15000, T 322.5, Ltr 0.1224, Lge4 1.8837, Lge7 2.0832, Lge11 3.6383, TimeStep 044
# # 15250, T 327.8, Ltr 0.0914, Lge4 1.5249, Lge7 1.5289, Lge11 7.8944, TimeStep 009
# # 15500, T 333.3, Ltr 0.3042, Lge4 0.0283, Lge7 0.0173, Lge11 0.0401, TimeStep 023
# # 15750, T 338.6, Ltr 0.1485, Lge4 1.6611, Lge7 1.9342, Lge11 5.2078, TimeStep 034
# # 16000, T 344.0, Ltr 0.2137, Lge4 1.6245, Lge7 1.7365, Lge11 5.7969, TimeStep 016
# # 16250, T 349.3, Ltr 0.1696, Lge4 2.3597, Lge7 2.4757, Lge11 2.1975, TimeStep 015
# # 16500, T 354.7, Ltr 0.1876, Lge4 1.6677, Lge7 1.5424, Lge11 7.3511, TimeStep 018
# # 16750, T 360.0, Ltr 0.1087, Lge4 0.9121, Lge7 1.1170, Lge11 4.7816, TimeStep 011
# # 17000, T 365.4, Ltr 0.2383, Lge4 0.4440, Lge7 0.6478, Lge11 1.2606, TimeStep 014
# # 17250, T 370.7, Ltr 0.1356, Lge4 0.8753, Lge7 0.7305, Lge11 6.0268, TimeStep 037
# # 17500, T 376.1, Ltr 0.1333, Lge4 1.7815, Lge7 1.6299, Lge11 6.6118, TimeStep 034
# # 17750, T 381.4, Ltr 0.1465, Lge4 0.1205, Lge7 0.0889, Lge11 0.1179, TimeStep 033
# # 18000, T 386.8, Ltr 0.1918, Lge4 2.2950, Lge7 2.6099, Lge11 3.3319, TimeStep 036
# # 18250, T 392.1, Ltr 0.1524, Lge4 1.4881, Lge7 1.6643, Lge11 8.6131, TimeStep 036
# # 18500, T 397.5, Ltr 0.1871, Lge4 0.0080, Lge7 0.0071, Lge11 0.0174, TimeStep 018
# # 18750, T 402.8, Ltr 0.0680, Lge4 1.7646, Lge7 1.9539, Lge11 3.6976, TimeStep 009
# # 19000, T 408.2, Ltr 0.2009, Lge4 0.3243, Lge7 0.2507, Lge11 0.2863, TimeStep 013
# # 19250, T 413.5, Ltr 0.1744, Lge4 0.5210, Lge7 0.7868, Lge11 3.4228, TimeStep 016
# # 19500, T 418.8, Ltr 0.1024, Lge4 0.8187, Lge7 1.0117, Lge11 5.1156, TimeStep 046
# # 19750, T 424.2, Ltr 0.0200, Lge4 1.2812, Lge7 1.7892, Lge11 4.3283, TimeStep 004
# # 20000, T 429.5, Ltr 0.2005, Lge4 0.8494, Lge7 1.1822, Lge11 5.0791, TimeStep 020
# # 20250, T 434.8, Ltr 0.1480, Lge4 0.0312, Lge7 0.0148, Lge11 0.0192, TimeStep 033
# # 20500, T 440.2, Ltr 0.1595, Lge4 1.4332, Lge7 1.5482, Lge11 7.0680, TimeStep 033
# # 20750, T 445.5, Ltr 0.1008, Lge4 0.5104, Lge7 0.5396, Lge11 2.0390, TimeStep 047
# # 21000, T 450.9, Ltr 0.1618, Lge4 0.7171, Lge7 0.6573, Lge11 5.8473, TimeStep 027
# # 21250, T 456.2, Ltr 0.2897, Lge4 1.8027, Lge7 1.6068, Lge11 7.5513, TimeStep 029
# # 21500, T 461.5, Ltr 0.1829, Lge4 0.8120, Lge7 0.7033, Lge11 6.3761, TimeStep 028
# # 21750, T 466.9, Ltr 0.1427, Lge4 0.0245, Lge7 0.0099, Lge11 0.0183, TimeStep 035
# # 22000, T 472.3, Ltr 0.1506, Lge4 0.0717, Lge7 0.0633, Lge11 0.0721, TimeStep 019
# # 22250, T 477.6, Ltr 0.1522, Lge4 2.1083, Lge7 2.4420, Lge11 2.3577, TimeStep 025
# # 22500, T 483.0, Ltr 0.0198, Lge4 1.1247, Lge7 1.3304, Lge11 3.9880, TimeStep 003
# # 22750, T 488.4, Ltr 0.2227, Lge4 1.6616, Lge7 1.8489, Lge11 6.3396, TimeStep 036
# # 23000, T 493.7, Ltr 0.0358, Lge4 1.6946, Lge7 2.1263, Lge11 4.0700, TimeStep 003
# # 23250, T 499.1, Ltr 0.1815, Lge4 1.7616, Lge7 1.7730, Lge11 6.7947, TimeStep 022
# # 23500, T 504.4, Ltr 0.1454, Lge4 1.7747, Lge7 2.5654, Lge11 2.6437, TimeStep 033
# # 23750, T 509.7, Ltr 0.1100, Lge4 0.7328, Lge7 0.8800, Lge11 5.3083, TimeStep 046
# # 24000, T 515.1, Ltr 0.0954, Lge4 1.9681, Lge7 2.6883, Lge11 2.5638, TimeStep 008
# # 24250, T 520.5, Ltr 0.1565, Lge4 0.9943, Lge7 1.2355, Lge11 4.4888, TimeStep 027
# # 24500, T 525.9, Ltr 0.1618, Lge4 1.9004, Lge7 2.4363, Lge11 3.1854, TimeStep 016
# # 24750, T 531.2, Ltr 0.1204, Lge4 0.0489, Lge7 0.0356, Lge11 0.0513, TimeStep 011
# # 25000, T 536.5, Ltr 0.1386, Lge4 0.7470, Lge7 0.7756, Lge11 5.0618, TimeStep 036
# # 25250, T 541.9, Ltr 0.1298, Lge4 1.2311, Lge7 1.6609, Lge11 3.1801, TimeStep 038
# # 25500, T 547.2, Ltr 0.1319, Lge4 0.7519, Lge7 0.7967, Lge11 5.4286, TimeStep 035
# # 25750, T 552.5, Ltr 0.1682, Lge4 0.2899, Lge7 0.2505, Lge11 0.3796, TimeStep 029
# # 26000, T 557.9, Ltr 0.0911, Lge4 0.6371, Lge7 0.7849, Lge11 6.0982, TimeStep 048
# # 26250, T 563.2, Ltr 0.1698, Lge4 0.4737, Lge7 0.6906, Lge11 3.5091, TimeStep 016
# # 26500, T 568.6, Ltr 0.1804, Lge4 1.9542, Lge7 2.5755, Lge11 2.1943, TimeStep 026
# # 26750, T 573.9, Ltr 0.1776, Lge4 0.3453, Lge7 0.2110, Lge11 0.2610, TimeStep 027
# # 27000, T 579.2, Ltr 0.1419, Lge4 1.0051, Lge7 1.1392, Lge11 3.7642, TimeStep 027
# # 27250, T 584.6, Ltr 0.1209, Lge4 0.8556, Lge7 0.7760, Lge11 4.7030, TimeStep 041
# # 27500, T 590.0, Ltr 0.1311, Lge4 1.6498, Lge7 2.1365, Lge11 3.7308, TimeStep 034
# # 27750, T 595.3, Ltr 0.2543, Lge4 0.5412, Lge7 0.8241, Lge11 3.8013, TimeStep 009
# # 28000, T 600.7, Ltr 0.0121, Lge4 0.7783, Lge7 0.6712, Lge11 6.5962, TimeStep 004
# # 28250, T 606.0, Ltr 0.1099, Lge4 1.8451, Lge7 1.6111, Lge11 5.5402, TimeStep 044
# # 28500, T 611.4, Ltr 0.0230, Lge4 0.4584, Lge7 0.7498, Lge11 2.3188, TimeStep 003
# # 28750, T 616.8, Ltr 0.1322, Lge4 0.0451, Lge7 0.0300, Lge11 0.0423, TimeStep 036
# # 29000, T 622.1, Ltr 0.1188, Lge4 0.7062, Lge7 0.6542, Lge11 5.8390, TimeStep 037
# # 29250, T 627.5, Ltr 0.1892, Lge4 0.9260, Lge7 0.8892, Lge11 4.9155, TimeStep 036
# # 29500, T 632.8, Ltr 0.0340, Lge4 0.9856, Lge7 1.2422, Lge11 3.5760, TimeStep 007
# # 29750, T 638.1, Ltr 0.1667, Lge4 0.5839, Lge7 0.6707, Lge11 2.4626, TimeStep 023
# # 30000, T 643.5, Ltr 0.1382, Lge4 1.7359, Lge7 1.7303, Lge11 5.3856, TimeStep 026
# # 30250, T 648.9, Ltr 0.1295, Lge4 0.4374, Lge7 0.4800, Lge11 1.7645, TimeStep 031
# # 30500, T 654.2, Ltr 0.2577, Lge4 0.4714, Lge7 0.9827, Lge11 3.3021, TimeStep 031
# # 30750, T 659.5, Ltr 0.1335, Lge4 2.3601, Lge7 2.5323, Lge11 2.2569, TimeStep 048
# # 31000, T 664.9, Ltr 0.1086, Lge4 2.3749, Lge7 2.4760, Lge11 1.9821, TimeStep 047
# # 31250, T 670.2, Ltr 0.1316, Lge4 2.0598, Lge7 1.7543, Lge11 6.4956, TimeStep 018
# # 31500, T 675.6, Ltr 0.1420, Lge4 1.8536, Lge7 1.4743, Lge11 7.2008, TimeStep 019
# # 31750, T 680.9, Ltr 0.1573, Lge4 1.6934, Lge7 2.0277, Lge11 3.7593, TimeStep 025
# # 32000, T 686.2, Ltr 0.1089, Lge4 2.0266, Lge7 2.3295, Lge11 1.7669, TimeStep 009
# # 32250, T 691.6, Ltr 0.1631, Lge4 0.7774, Lge7 0.6549, Lge11 8.5154, TimeStep 011
# # 32500, T 697.0, Ltr 0.0761, Lge4 1.7746, Lge7 2.2052, Lge11 3.4285, TimeStep 010
# # 32750, T 702.3, Ltr 0.1325, Lge4 0.0330, Lge7 0.0132, Lge11 0.0097, TimeStep 027
# # 33000, T 707.7, Ltr 0.1332, Lge4 0.0414, Lge7 0.0327, Lge11 0.0469, TimeStep 032
# # 33250, T 713.0, Ltr 0.1357, Lge4 1.7052, Lge7 1.5808, Lge11 7.1078, TimeStep 022
# # 33500, T 718.4, Ltr 0.0333, Lge4 1.8620, Lge7 1.4201, Lge11 8.0250, TimeStep 006
# # 33750, T 723.7, Ltr 0.0975, Lge4 1.6701, Lge7 1.8796, Lge11 4.4925, TimeStep 010
# # 34000, T 729.0, Ltr 0.0258, Lge4 1.6637, Lge7 1.6765, Lge11 7.7292, TimeStep 007
# # 34250, T 734.4, Ltr 0.0122, Lge4 0.7763, Lge7 0.8906, Lge11 4.5544, TimeStep 004
# # 34500, T 739.7, Ltr 0.0984, Lge4 0.7431, Lge7 0.7216, Lge11 6.8336, TimeStep 045
# # 34750, T 745.1, Ltr 0.1208, Lge4 0.0409, Lge7 0.0372, Lge11 0.0596, TimeStep 034
# # 35000, T 750.4, Ltr 0.0798, Lge4 1.2324, Lge7 1.6685, Lge11 3.9489, TimeStep 046
# # 35250, T 755.7, Ltr 0.1344, Lge4 0.3319, Lge7 0.3505, Lge11 1.0657, TimeStep 032
# # 35500, T 761.1, Ltr 0.1243, Lge4 1.9490, Lge7 2.4354, Lge11 2.5868, TimeStep 036
# # 35750, T 766.5, Ltr 0.0978, Lge4 2.1808, Lge7 2.2260, Lge11 2.1071, TimeStep 043
# # 36000, T 771.8, Ltr 0.0160, Lge4 1.9076, Lge7 1.9443, Lge11 5.0545, TimeStep 003
# # 36250, T 777.2, Ltr 0.1034, Lge4 0.7263, Lge7 0.7248, Lge11 4.8072, TimeStep 011
# # 36500, T 782.5, Ltr 0.1334, Lge4 1.0966, Lge7 1.1784, Lge11 4.0227, TimeStep 030
# # 36750, T 787.8, Ltr 0.1446, Lge4 0.0284, Lge7 0.0098, Lge11 0.0142, TimeStep 030
# # 37000, T 793.2, Ltr 0.1179, Lge4 1.6750, Lge7 1.6691, Lge11 7.3649, TimeStep 038
# # 37250, T 798.5, Ltr 0.1026, Lge4 0.5367, Lge7 0.4765, Lge11 2.1442, TimeStep 042
# # 37500, T 803.9, Ltr 0.1289, Lge4 0.1837, Lge7 0.1164, Lge11 0.1051, TimeStep 013
# # 37750, T 809.2, Ltr 0.1243, Lge4 0.4273, Lge7 0.4799, Lge11 1.9691, TimeStep 023
# # 38000, T 814.6, Ltr 0.1287, Lge4 0.0376, Lge7 0.0160, Lge11 0.0195, TimeStep 036
# # 38250, T 819.9, Ltr 0.1014, Lge4 0.3981, Lge7 0.3387, Lge11 0.6847, TimeStep 039
# # 38500, T 825.3, Ltr 0.0865, Lge4 1.7549, Lge7 2.1134, Lge11 4.1592, TimeStep 047
# # 38750, T 830.6, Ltr 0.0981, Lge4 1.6725, Lge7 1.9005, Lge11 4.9910, TimeStep 010
# # 39000, T 836.0, Ltr 0.1311, Lge4 2.3490, Lge7 2.8626, Lge11 2.1965, TimeStep 013
# # 39250, T 841.3, Ltr 0.1188, Lge4 1.3334, Lge7 1.7885, Lge11 3.2783, TimeStep 014
# # 39500, T 846.7, Ltr 0.0132, Lge4 1.6412, Lge7 1.5217, Lge11 7.5194, TimeStep 002
# # 39750, T 852.1, Ltr 0.0933, Lge4 1.8524, Lge7 2.6452, Lge11 2.8013, TimeStep 041
# # 40000, T 857.4, Ltr 0.2136, Lge4 1.2811, Lge7 1.5046, Lge11 3.3003, TimeStep 029
# # 40250, T 862.8, Ltr 0.0983, Lge4 0.6695, Lge7 0.7533, Lge11 4.8153, TimeStep 045
# # 40500, T 868.2, Ltr 0.1417, Lge4 0.7890, Lge7 0.9105, Lge11 4.8179, TimeStep 027
# # 40750, T 873.5, Ltr 0.0892, Lge4 1.6476, Lge7 1.4969, Lge11 7.8236, TimeStep 011
# # 41000, T 878.9, Ltr 0.1332, Lge4 1.8982, Lge7 2.3632, Lge11 3.4809, TimeStep 037
# # 41250, T 884.3, Ltr 0.0884, Lge4 1.7840, Lge7 1.8908, Lge11 7.2208, TimeStep 043
# # 41500, T 889.6, Ltr 0.1727, Lge4 0.7488, Lge7 0.6364, Lge11 5.0580, TimeStep 023
# # 41750, T 894.9, Ltr 0.1339, Lge4 0.6805, Lge7 0.6700, Lge11 5.5712, TimeStep 014
# # 42000, T 900.2, Ltr 0.1276, Lge4 0.0215, Lge7 0.0112, Lge11 0.0100, TimeStep 028
# # 42250, T 905.6, Ltr 0.1369, Lge4 2.0369, Lge7 2.3191, Lge11 2.4058, TimeStep 013
# # 42500, T 911.0, Ltr 0.1335, Lge4 0.6098, Lge7 0.7152, Lge11 4.9709, TimeStep 020
# # 42750, T 916.3, Ltr 0.1348, Lge4 0.5454, Lge7 0.5924, Lge11 3.0471, TimeStep 022
# # 43000, T 921.7, Ltr 0.0975, Lge4 0.0407, Lge7 0.0393, Lge11 0.0519, TimeStep 044
# # 43250, T 927.0, Ltr 0.1152, Lge4 0.2467, Lge7 0.1707, Lge11 0.3353, TimeStep 013
# # 43500, T 932.4, Ltr 0.0800, Lge4 2.0274, Lge7 2.5724, Lge11 2.2950, TimeStep 048
# # 43750, T 937.7, Ltr 0.0935, Lge4 1.8064, Lge7 1.4518, Lge11 8.5163, TimeStep 040
# # 44000, T 943.0, Ltr 0.1134, Lge4 0.0379, Lge7 0.0354, Lge11 0.0522, TimeStep 036
# # 44250, T 948.4, Ltr 0.1103, Lge4 1.9899, Lge7 2.4163, Lge11 2.8329, TimeStep 036
# # 44500, T 953.7, Ltr 0.1114, Lge4 1.8110, Lge7 1.8168, Lge11 6.6956, TimeStep 034
# # 44750, T 959.1, Ltr 0.1220, Lge4 0.0123, Lge7 0.0180, Lge11 0.0284, TimeStep 022
# # 45000, T 964.4, Ltr 0.1088, Lge4 0.3756, Lge7 0.5457, Lge11 1.6119, TimeStep 038
# # 45250, T 969.8, Ltr 0.1229, Lge4 1.4671, Lge7 2.0264, Lge11 3.6444, TimeStep 018
# # 45500, T 975.1, Ltr 0.0416, Lge4 0.4848, Lge7 0.5598, Lge11 4.8961, TimeStep 001
# # 45750, T 980.5, Ltr 0.1120, Lge4 0.0249, Lge7 0.0102, Lge11 0.0159, TimeStep 033
# # 46000, T 985.8, Ltr 0.1121, Lge4 2.1132, Lge7 2.3760, Lge11 1.8184, TimeStep 014
# # 46250, T 991.1, Ltr 0.1258, Lge4 0.0894, Lge7 0.1429, Lge11 0.2060, TimeStep 031
# # 46500, T 996.5, Ltr 0.0244, Lge4 0.9785, Lge7 1.1931, Lge11 4.3179, TimeStep 000
# # 46750, T 1001.9, Ltr 0.0246, Lge4 0.6427, Lge7 0.7255, Lge11 4.8354, TimeStep 006
# # 47000, T 1007.2, Ltr 0.0419, Lge4 0.1376, Lge7 0.1185, Lge11 0.1723, TimeStep 004
# # 47250, T 1012.6, Ltr 0.1192, Lge4 1.7088, Lge7 2.2629, Lge11 4.7264, TimeStep 008
# # 47500, T 1017.9, Ltr 0.0837, Lge4 0.7939, Lge7 1.0166, Lge11 5.0793, TimeStep 045
# # 47750, T 1023.3, Ltr 0.0926, Lge4 1.5690, Lge7 1.6361, Lge11 5.8100, TimeStep 011
# # 48000, T 1028.6, Ltr 0.0147, Lge4 0.6289, Lge7 0.5767, Lge11 4.7025, TimeStep 004
# # 48250, T 1034.0, Ltr 0.1197, Lge4 0.6281, Lge7 0.4837, Lge11 2.4273, TimeStep 027
# # 48500, T 1039.4, Ltr 0.1067, Lge4 1.1517, Lge7 1.6549, Lge11 3.4118, TimeStep 042
# # 48750, T 1044.7, Ltr 0.1178, Lge4 2.2507, Lge7 2.8243, Lge11 2.1276, TimeStep 021
# # 49000, T 1050.1, Ltr 0.1330, Lge4 0.9140, Lge7 1.1565, Lge11 4.0314, TimeStep 026
# # 49250, T 1055.4, Ltr 0.0299, Lge4 0.5414, Lge7 0.4030, Lge11 1.4141, TimeStep 008
# # 49500, T 1060.8, Ltr 0.0477, Lge4 0.0746, Lge7 0.0597, Lge11 0.0792, TimeStep 002
# # 49750, T 1066.1, Ltr 0.0842, Lge4 1.7076, Lge7 1.4179, Lge11 7.4099, TimeStep 011
# # 50000, T 1071.5, Ltr 0.1109, Lge4 1.9888, Lge7 2.3387, Lge11 2.8780, TimeStep 018
# # 50250, T 1076.8, Ltr 0.0140, Lge4 0.6789, Lge7 0.5523, Lge11 5.1543, TimeStep 004
# # 50500, T 1082.2, Ltr 0.0818, Lge4 0.5330, Lge7 0.4884, Lge11 3.1426, TimeStep 047
# # 50750, T 1087.6, Ltr 0.0723, Lge4 1.7936, Lge7 1.6304, Lge11 7.3396, TimeStep 009
# # 51000, T 1092.9, Ltr 0.0458, Lge4 0.0604, Lge7 0.0476, Lge11 0.0518, TimeStep 009
# # 51250, T 1098.3, Ltr 0.0907, Lge4 0.5971, Lge7 0.6594, Lge11 4.5429, TimeStep 040
# # 51500, T 1103.6, Ltr 0.0888, Lge4 2.1279, Lge7 2.6026, Lge11 2.0103, TimeStep 042
# # 51750, T 1109.0, Ltr 0.1003, Lge4 0.5482, Lge7 0.5888, Lge11 4.5855, TimeStep 017
# # 52000, T 1114.3, Ltr 0.0275, Lge4 0.1857, Lge7 0.1018, Lge11 0.1358, TimeStep 005
# # 52250, T 1119.7, Ltr 0.1429, Lge4 1.7811, Lge7 2.1090, Lge11 3.0580, TimeStep 032
# # 52500, T 1125.0, Ltr 0.0904, Lge4 0.0459, Lge7 0.0273, Lge11 0.0356, TimeStep 012
# # 52750, T 1130.3, Ltr 0.0889, Lge4 1.8110, Lge7 1.6396, Lge11 4.9976, TimeStep 040
# # 53000, T 1135.7, Ltr 0.1060, Lge4 1.5168, Lge7 1.5233, Lge11 4.2134, TimeStep 031
# # 53250, T 1141.0, Ltr 0.0547, Lge4 1.6337, Lge7 1.5687, Lge11 7.5030, TimeStep 009
# # 53500, T 1146.3, Ltr 0.1034, Lge4 1.7166, Lge7 2.6589, Lge11 2.0004, TimeStep 034
# # 53750, T 1151.7, Ltr 0.0838, Lge4 1.6789, Lge7 1.4164, Lge11 7.3833, TimeStep 041
# # 54000, T 1157.0, Ltr 0.1389, Lge4 0.7818, Lge7 0.7872, Lge11 3.8848, TimeStep 014
# # 54250, T 1162.3, Ltr 0.1024, Lge4 1.7220, Lge7 1.4171, Lge11 8.1152, TimeStep 048
# # 54500, T 1167.7, Ltr 0.1186, Lge4 1.5191, Lge7 2.3288, Lge11 2.9009, TimeStep 026
# # 54750, T 1173.0, Ltr 0.1182, Lge4 1.5268, Lge7 1.5144, Lge11 6.8379, TimeStep 029
# # 55000, T 1178.4, Ltr 0.1188, Lge4 0.0671, Lge7 0.0980, Lge11 0.1554, TimeStep 037
# # 55250, T 1183.8, Ltr 0.1270, Lge4 0.5734, Lge7 0.3993, Lge11 2.5293, TimeStep 024
# # 55500, T 1189.2, Ltr 0.0707, Lge4 1.6667, Lge7 2.3842, Lge11 2.5898, TimeStep 048
# # 55750, T 1194.5, Ltr 0.1014, Lge4 0.3042, Lge7 0.2874, Lge11 0.6094, TimeStep 036
# # 56000, T 1199.9, Ltr 0.1056, Lge4 1.6739, Lge7 1.5036, Lge11 7.6259, TimeStep 014
# # 56250, T 1205.2, Ltr 0.1455, Lge4 1.8020, Lge7 1.7423, Lge11 5.0903, TimeStep 016
# # 56500, T 1210.6, Ltr 0.0629, Lge4 1.5162, Lge7 1.5803, Lge11 5.1378, TimeStep 010
# # 56750, T 1215.9, Ltr 0.0827, Lge4 0.6062, Lge7 0.4265, Lge11 2.3286, TimeStep 042
# # 57000, T 1221.3, Ltr 0.1186, Lge4 1.5914, Lge7 1.7841, Lge11 6.0046, TimeStep 025
# # 57250, T 1226.6, Ltr 0.0647, Lge4 1.6487, Lge7 2.4906, Lge11 3.2370, TimeStep 009
# # 57500, T 1232.0, Ltr 0.0185, Lge4 0.5870, Lge7 0.5820, Lge11 3.7632, TimeStep 006
# # 57750, T 1237.3, Ltr 0.0110, Lge4 0.9048, Lge7 1.1225, Lge11 3.6379, TimeStep 003
# # 58000, T 1242.7, Ltr 0.0867, Lge4 1.8068, Lge7 1.4477, Lge11 5.7229, TimeStep 043
# # 58250, T 1248.0, Ltr 0.1077, Lge4 1.7435, Lge7 2.3364, Lge11 1.8341, TimeStep 033
# # 58500, T 1253.3, Ltr 0.0886, Lge4 0.0361, Lge7 0.0209, Lge11 0.0298, TimeStep 039
# # 58750, T 1258.7, Ltr 0.1182, Lge4 0.6159, Lge7 0.5420, Lge11 3.3761, TimeStep 029
# # 59000, T 1264.0, Ltr 0.0186, Lge4 1.7436, Lge7 2.4004, Lge11 2.6565, TimeStep 000
# # 59250, T 1269.3, Ltr 0.0212, Lge4 0.5244, Lge7 0.5529, Lge11 5.4867, TimeStep 007
# # 59500, T 1274.7, Ltr 0.1053, Lge4 0.5604, Lge7 0.5438, Lge11 3.8084, TimeStep 022
# # 59750, T 1280.0, Ltr 0.1121, Lge4 0.2225, Lge7 0.1866, Lge11 0.3225, TimeStep 023
# # 60000, T 1285.4, Ltr 0.1511, Lge4 1.8523, Lge7 1.2917, Lge11 7.7876, TimeStep 025
# # 60250, T 1290.7, Ltr 0.1001, Lge4 0.2458, Lge7 0.2084, Lge11 0.3527, TimeStep 036
# # 60500, T 1296.1, Ltr 0.0159, Lge4 0.2710, Lge7 0.2156, Lge11 0.3435, TimeStep 004
# # 60750, T 1301.5, Ltr 0.2061, Lge4 1.5832, Lge7 1.8295, Lge11 5.2210, TimeStep 024
# # 61000, T 1306.9, Ltr 0.0878, Lge4 1.5432, Lge7 2.2733, Lge11 4.0899, TimeStep 037
# # 61250, T 1312.2, Ltr 0.0373, Lge4 0.1025, Lge7 0.3032, Lge11 0.4323, TimeStep 000
# # 61500, T 1317.6, Ltr 0.1283, Lge4 1.5770, Lge7 1.7585, Lge11 6.4416, TimeStep 023
# # 61750, T 1323.0, Ltr 0.1167, Lge4 0.0964, Lge7 0.0954, Lge11 0.1117, TimeStep 024
# # 62000, T 1328.3, Ltr 0.0755, Lge4 0.5130, Lge7 0.5339, Lge11 5.1579, TimeStep 044
# # 62250, T 1333.6, Ltr 0.1179, Lge4 0.7950, Lge7 1.2260, Lge11 3.8966, TimeStep 020
# # 62500, T 1339.0, Ltr 0.1161, Lge4 1.8845, Lge7 2.4360, Lge11 2.4672, TimeStep 030
# # 62750, T 1344.4, Ltr 0.1003, Lge4 1.5077, Lge7 1.6026, Lge11 7.0585, TimeStep 033
# # 63000, T 1349.8, Ltr 0.0237, Lge4 0.4806, Lge7 0.5373, Lge11 4.7665, TimeStep 005
# # 63250, T 1355.1, Ltr 0.1038, Lge4 0.4749, Lge7 0.5064, Lge11 5.0988, TimeStep 023
# # 63500, T 1360.4, Ltr 0.0802, Lge4 1.0830, Lge7 1.8399, Lge11 2.9905, TimeStep 040
# # 63750, T 1365.8, Ltr 0.0897, Lge4 1.9329, Lge7 2.6767, Lge11 2.9726, TimeStep 013
# # 64000, T 1371.2, Ltr 0.1443, Lge4 1.6019, Lge7 1.3485, Lge11 7.3124, TimeStep 030
# # 64250, T 1376.5, Ltr 0.1169, Lge4 0.8881, Lge7 0.3933, Lge11 2.4858, TimeStep 015
# # 64500, T 1381.8, Ltr 0.1062, Lge4 0.6888, Lge7 0.5285, Lge11 2.6158, TimeStep 019
# # 64750, T 1387.2, Ltr 0.1108, Lge4 2.0146, Lge7 2.3979, Lge11 1.7283, TimeStep 028
# # 65000, T 1392.5, Ltr 0.0957, Lge4 0.0276, Lge7 0.0162, Lge11 0.0227, TimeStep 017
# # 65250, T 1397.9, Ltr 0.0689, Lge4 0.5612, Lge7 0.5702, Lge11 3.7351, TimeStep 007
# # 65500, T 1403.2, Ltr 0.0254, Lge4 0.4240, Lge7 0.3917, Lge11 1.1729, TimeStep 005
# # 65750, T 1408.6, Ltr 0.0949, Lge4 0.4798, Lge7 0.6201, Lge11 4.2242, TimeStep 020
# # 66000, T 1414.0, Ltr 0.1465, Lge4 1.7210, Lge7 3.1525, Lge11 2.2651, TimeStep 030
# # 66250, T 1419.3, Ltr 0.1009, Lge4 1.5004, Lge7 1.3745, Lge11 7.2386, TimeStep 016
# # 66500, T 1424.7, Ltr 0.0770, Lge4 0.0277, Lge7 0.0123, Lge11 0.0218, TimeStep 012
# # 66750, T 1430.0, Ltr 0.0445, Lge4 1.6762, Lge7 2.3974, Lge11 2.3400, TimeStep 008
# # 67000, T 1435.4, Ltr 0.1016, Lge4 0.4714, Lge7 0.5219, Lge11 4.5555, TimeStep 020
# # 67250, T 1440.7, Ltr 0.0302, Lge4 1.5731, Lge7 1.2122, Lge11 7.3427, TimeStep 004
# # 67500, T 1446.1, Ltr 0.1080, Lge4 1.6978, Lge7 1.4385, Lge11 7.6998, TimeStep 025
# # 67750, T 1451.5, Ltr 0.1097, Lge4 1.8830, Lge7 1.3619, Lge11 8.2591, TimeStep 030
# # 68000, T 1456.8, Ltr 0.0441, Lge4 0.5201, Lge7 0.3960, Lge11 1.8894, TimeStep 009
# # 68250, T 1462.2, Ltr 0.1013, Lge4 0.5816, Lge7 0.6806, Lge11 4.3704, TimeStep 024
# # 68500, T 1467.5, Ltr 0.0804, Lge4 1.5679, Lge7 1.3127, Lge11 6.2655, TimeStep 046
# # 68750, T 1472.8, Ltr 0.1111, Lge4 0.6788, Lge7 0.4635, Lge11 3.2887, TimeStep 016
# # 69000, T 1478.2, Ltr 0.0928, Lge4 2.2109, Lge7 2.7544, Lge11 1.7998, TimeStep 042
# # 69250, T 1483.6, Ltr 0.0956, Lge4 1.6987, Lge7 2.5155, Lge11 1.8711, TimeStep 033
# # 69500, T 1488.9, Ltr 0.0136, Lge4 1.9201, Lge7 2.2601, Lge11 1.8956, TimeStep 001
# # 69750, T 1494.3, Ltr 0.0550, Lge4 0.0175, Lge7 0.0173, Lge11 0.0314, TimeStep 010
# # 70000, T 1499.6, Ltr 0.1065, Lge4 0.6282, Lge7 0.7508, Lge11 5.5472, TimeStep 028
# # 70250, T 1505.0, Ltr 0.1073, Lge4 0.5222, Lge7 0.5580, Lge11 4.8172, TimeStep 028
# # 70500, T 1510.3, Ltr 0.1310, Lge4 1.5601, Lge7 1.5875, Lge11 7.3740, TimeStep 015
# # 70750, T 1515.7, Ltr 0.0571, Lge4 0.0200, Lge7 0.0221, Lge11 0.0300, TimeStep 010
# # 71000, T 1521.1, Ltr 0.1156, Lge4 0.2990, Lge7 0.3237, Lge11 0.6034, TimeStep 010
# # 71250, T 1526.4, Ltr 0.0179, Lge4 1.8387, Lge7 2.0555, Lge11 2.1767, TimeStep 003
# # 71500, T 1531.7, Ltr 0.0937, Lge4 0.0852, Lge7 0.0516, Lge11 0.0664, TimeStep 026
# # 71750, T 1537.1, Ltr 0.1019, Lge4 2.1817, Lge7 2.5653, Lge11 1.9515, TimeStep 018
# # 72000, T 1542.5, Ltr 0.0729, Lge4 0.0673, Lge7 0.0458, Lge11 0.0731, TimeStep 045
# # 72250, T 1547.8, Ltr 0.1025, Lge4 0.9736, Lge7 1.3401, Lge11 3.9486, TimeStep 011
# # 72500, T 1553.2, Ltr 0.1115, Lge4 0.5222, Lge7 0.4617, Lge11 5.4228, TimeStep 030
# # 72750, T 1558.5, Ltr 0.1096, Lge4 1.5610, Lge7 1.4337, Lge11 7.0745, TimeStep 027
# # 73000, T 1563.9, Ltr 0.0181, Lge4 1.6774, Lge7 1.2928, Lge11 5.8735, TimeStep 002
# # 73250, T 1569.3, Ltr 0.0977, Lge4 0.0395, Lge7 0.0247, Lge11 0.0321, TimeStep 034
# # 73500, T 1574.6, Ltr 0.0176, Lge4 0.5028, Lge7 0.4914, Lge11 4.5989, TimeStep 006
# # 73750, T 1580.0, Ltr 0.0147, Lge4 1.5815, Lge7 1.3727, Lge11 7.4758, TimeStep 003
# # 74000, T 1585.4, Ltr 0.1098, Lge4 1.9430, Lge7 1.7688, Lge11 4.5035, TimeStep 016
# # 74250, T 1590.7, Ltr 0.1042, Lge4 1.4653, Lge7 1.4060, Lge11 7.6146, TimeStep 028
# # 74500, T 1596.1, Ltr 0.1409, Lge4 1.6000, Lge7 1.4741, Lge11 8.0129, TimeStep 029
# # 74750, T 1601.5, Ltr 0.1188, Lge4 0.0668, Lge7 0.0570, Lge11 0.0928, TimeStep 036
# # 75000, T 1606.9, Ltr 0.0978, Lge4 1.0939, Lge7 1.3872, Lge11 3.6506, TimeStep 023
# # 75250, T 1612.2, Ltr 0.0979, Lge4 1.5245, Lge7 1.7487, Lge11 4.0881, TimeStep 027
# # 75500, T 1617.6, Ltr 0.1002, Lge4 0.4832, Lge7 0.5227, Lge11 4.1030, TimeStep 023
# # 75750, T 1622.9, Ltr 0.0967, Lge4 1.2050, Lge7 1.9920, Lge11 3.0042, TimeStep 017
# # 76000, T 1628.2, Ltr 0.0934, Lge4 0.5543, Lge7 0.6767, Lge11 4.9408, TimeStep 011
# # 76250, T 1633.6, Ltr 0.0967, Lge4 1.7306, Lge7 1.2971, Lge11 6.9327, TimeStep 032
# # 76500, T 1639.0, Ltr 0.0796, Lge4 0.7697, Lge7 0.5287, Lge11 4.8433, TimeStep 010
# # 76750, T 1644.3, Ltr 0.0274, Lge4 1.8111, Lge7 2.4304, Lge11 1.7162, TimeStep 008
# # 77000, T 1649.6, Ltr 0.0804, Lge4 1.3499, Lge7 1.4873, Lge11 7.3958, TimeStep 039
# # 77250, T 1655.0, Ltr 0.0811, Lge4 1.7635, Lge7 2.7020, Lge11 2.1083, TimeStep 012
# # 77500, T 1660.4, Ltr 0.0213, Lge4 0.3665, Lge7 0.3035, Lge11 0.8709, TimeStep 007
# # 77750, T 1665.7, Ltr 0.0819, Lge4 0.2750, Lge7 0.2150, Lge11 0.4106, TimeStep 014
# # 78000, T 1671.1, Ltr 0.1025, Lge4 0.4851, Lge7 0.5034, Lge11 4.6496, TimeStep 036
# # 78250, T 1676.5, Ltr 0.0726, Lge4 1.4743, Lge7 1.2556, Lge11 7.6095, TimeStep 043
# # 78500, T 1681.9, Ltr 0.1167, Lge4 0.4431, Lge7 0.4592, Lge11 4.0890, TimeStep 032
# # 78750, T 1687.2, Ltr 0.0461, Lge4 0.2564, Lge7 0.2279, Lge11 0.5605, TimeStep 001
# # 79000, T 1692.6, Ltr 0.0939, Lge4 0.0423, Lge7 0.0253, Lge11 0.0312, TimeStep 023
# # 79250, T 1697.9, Ltr 0.0834, Lge4 1.1151, Lge7 1.6787, Lge11 3.1173, TimeStep 019
# # 79500, T 1703.2, Ltr 0.0157, Lge4 0.9280, Lge7 1.3193, Lge11 3.5092, TimeStep 006
# # 79750, T 1708.6, Ltr 0.0137, Lge4 1.6136, Lge7 1.3376, Lge11 7.0576, TimeStep 004
# # 80000, T 1713.9, Ltr 0.0822, Lge4 1.5026, Lge7 1.3249, Lge11 7.0246, TimeStep 016
# # 80250, T 1719.3, Ltr 0.1450, Lge4 0.5748, Lge7 0.7052, Lge11 5.0967, TimeStep 027
# # 80500, T 1724.6, Ltr 0.0921, Lge4 0.2845, Lge7 0.1721, Lge11 0.3861, TimeStep 015
# # 80750, T 1730.0, Ltr 0.1150, Lge4 1.5758, Lge7 1.9677, Lge11 3.6028, TimeStep 030
# # 81000, T 1735.3, Ltr 0.0863, Lge4 0.4758, Lge7 0.5534, Lge11 3.2410, TimeStep 036
# # 81250, T 1740.7, Ltr 0.0087, Lge4 0.4357, Lge7 0.4774, Lge11 3.2481, TimeStep 003
# # 81500, T 1746.0, Ltr 0.0781, Lge4 0.0140, Lge7 0.0144, Lge11 0.0198, TimeStep 041
# # 81750, T 1751.4, Ltr 0.1254, Lge4 0.6289, Lge7 0.5828, Lge11 4.7611, TimeStep 040
# # 82000, T 1756.8, Ltr 0.1067, Lge4 0.2091, Lge7 0.1138, Lge11 0.1453, TimeStep 024
# # 82250, T 1762.1, Ltr 0.0649, Lge4 0.4592, Lge7 0.3983, Lge11 2.6429, TimeStep 012
# # 82500, T 1767.5, Ltr 0.1772, Lge4 2.0084, Lge7 2.6356, Lge11 2.1668, TimeStep 036
# # 82750, T 1772.8, Ltr 0.1071, Lge4 1.8484, Lge7 1.9921, Lge11 2.5961, TimeStep 024
# # 83000, T 1778.1, Ltr 0.0915, Lge4 0.5069, Lge7 0.4842, Lge11 4.7959, TimeStep 021
# # 83250, T 1783.5, Ltr 0.0681, Lge4 0.5421, Lge7 0.6110, Lge11 4.1504, TimeStep 011
# # 83500, T 1788.9, Ltr 0.0958, Lge4 0.3389, Lge7 0.3098, Lge11 0.8376, TimeStep 022
# # 83750, T 1794.2, Ltr 0.0737, Lge4 2.0315, Lge7 2.2488, Lge11 2.3251, TimeStep 014
# # 84000, T 1799.6, Ltr 0.1092, Lge4 1.5154, Lge7 2.5867, Lge11 2.5077, TimeStep 028
# # 84250, T 1804.9, Ltr 0.0951, Lge4 1.6858, Lge7 1.2499, Lge11 7.1137, TimeStep 026
# # 84500, T 1810.3, Ltr 0.0755, Lge4 0.0129, Lge7 0.0095, Lge11 0.0117, TimeStep 042
# # 84750, T 1815.6, Ltr 0.0816, Lge4 0.9278, Lge7 1.3603, Lge11 3.3521, TimeStep 013
# # 85000, T 1821.0, Ltr 0.0958, Lge4 0.0151, Lge7 0.0104, Lge11 0.0138, TimeStep 025
# # 85250, T 1826.3, Ltr 0.1119, Lge4 0.6324, Lge7 0.4366, Lge11 2.4514, TimeStep 029
# # 85500, T 1831.7, Ltr 0.0318, Lge4 0.4926, Lge7 0.3702, Lge11 1.6538, TimeStep 008
# # 85750, T 1837.0, Ltr 0.0740, Lge4 0.4925, Lge7 0.4183, Lge11 1.9767, TimeStep 045
# # 86000, T 1842.4, Ltr 0.0196, Lge4 0.0551, Lge7 0.0374, Lge11 0.0578, TimeStep 004
# # 86250, T 1847.7, Ltr 0.1006, Lge4 1.6571, Lge7 2.3270, Lge11 1.7751, TimeStep 030
# # 86500, T 1853.1, Ltr 0.0131, Lge4 0.5717, Lge7 0.4080, Lge11 2.4748, TimeStep 000
# # 86750, T 1858.5, Ltr 0.0758, Lge4 0.4701, Lge7 0.3469, Lge11 1.7254, TimeStep 013
# # 87000, T 1863.8, Ltr 0.0962, Lge4 0.0141, Lge7 0.0153, Lge11 0.0176, TimeStep 021
# # 87250, T 1869.1, Ltr 0.0873, Lge4 1.6025, Lge7 1.2822, Lge11 4.9832, TimeStep 017
# # 87500, T 1874.4, Ltr 0.0974, Lge4 0.0707, Lge7 0.0356, Lge11 0.0572, TimeStep 030
# # 87750, T 1879.8, Ltr 0.0133, Lge4 0.0611, Lge7 0.0418, Lge11 0.0519, TimeStep 004
# # 88000, T 1885.1, Ltr 0.0739, Lge4 0.4738, Lge7 0.3750, Lge11 1.6110, TimeStep 040
# # 88250, T 1890.5, Ltr 0.1030, Lge4 0.0744, Lge7 0.0488, Lge11 0.0663, TimeStep 028
# # 88500, T 1895.8, Ltr 0.0702, Lge4 1.5506, Lge7 1.8182, Lge11 3.7142, TimeStep 013
# # 88750, T 1901.2, Ltr 0.0984, Lge4 0.0590, Lge7 0.0728, Lge11 0.0918, TimeStep 042
# # 89000, T 1906.5, Ltr 0.0691, Lge4 0.9554, Lge7 1.4984, Lge11 3.4505, TimeStep 001
# # 89250, T 1911.8, Ltr 0.0995, Lge4 1.3860, Lge7 2.2335, Lge11 2.9816, TimeStep 028
# # 89500, T 1917.2, Ltr 0.0094, Lge4 1.4614, Lge7 1.3015, Lge11 8.0817, TimeStep 003
# # 89750, T 1922.5, Ltr 0.0892, Lge4 1.4858, Lge7 1.3659, Lge11 7.0805, TimeStep 039
# # 90000, T 1927.9, Ltr 0.0149, Lge4 1.1348, Lge7 1.7564, Lge11 3.1784, TimeStep 004
# # 90250, T 1933.2, Ltr 0.0764, Lge4 0.5606, Lge7 0.5204, Lge11 4.7071, TimeStep 043
# # 90500, T 1938.6, Ltr 0.0808, Lge4 1.1309, Lge7 1.9864, Lge11 2.1646, TimeStep 011
# # 90750, T 1944.0, Ltr 0.0913, Lge4 0.4590, Lge7 0.4962, Lge11 3.5339, TimeStep 033
# # 91000, T 1949.4, Ltr 0.0740, Lge4 1.7593, Lge7 1.4629, Lge11 7.8260, TimeStep 046
# # 91250, T 1954.7, Ltr 0.0663, Lge4 0.4315, Lge7 0.3813, Lge11 2.5941, TimeStep 010
# # 91500, T 1960.1, Ltr 0.0948, Lge4 0.0277, Lge7 0.0140, Lge11 0.0177, TimeStep 031
# # 91750, T 1965.5, Ltr 0.1043, Lge4 1.7600, Lge7 2.5249, Lge11 1.7302, TimeStep 030
# # 92000, T 1970.8, Ltr 0.1115, Lge4 1.4237, Lge7 1.4025, Lge11 7.2059, TimeStep 025
# # 92250, T 1976.2, Ltr 0.0729, Lge4 0.6007, Lge7 0.6466, Lge11 3.7712, TimeStep 043
# # 92500, T 1981.6, Ltr 0.1240, Lge4 0.0641, Lge7 0.0413, Lge11 0.0627, TimeStep 013
# # 92750, T 1986.9, Ltr 0.1002, Lge4 0.0127, Lge7 0.0179, Lge11 0.0219, TimeStep 022
# # 93000, T 1992.3, Ltr 0.0865, Lge4 1.5764, Lge7 1.4496, Lge11 7.6565, TimeStep 026
# # 93250, T 1997.6, Ltr 0.0814, Lge4 0.4545, Lge7 0.4552, Lge11 3.6459, TimeStep 041
# # 93500, T 2003.0, Ltr 0.0109, Lge4 0.0723, Lge7 0.0337, Lge11 0.0531, TimeStep 004
# # 93750, T 2008.3, Ltr 0.0725, Lge4 1.5333, Lge7 1.2493, Lge11 7.5686, TimeStep 046
# # 94000, T 2013.7, Ltr 0.0843, Lge4 0.4907, Lge7 0.4948, Lge11 4.5442, TimeStep 038
# # 94250, T 2019.0, Ltr 0.0090, Lge4 0.5088, Lge7 0.6019, Lge11 4.6976, TimeStep 002
# # 94500, T 2024.4, Ltr 0.0975, Lge4 0.0607, Lge7 0.0341, Lge11 0.0401, TimeStep 028
# # 94750, T 2029.7, Ltr 0.1556, Lge4 0.1492, Lge7 0.1777, Lge11 0.2140, TimeStep 034
# # 95000, T 2035.1, Ltr 0.0710, Lge4 1.5199, Lge7 1.5440, Lge11 7.6730, TimeStep 014
# # 95250, T 2040.4, Ltr 0.0658, Lge4 0.0511, Lge7 0.0236, Lge11 0.0337, TimeStep 015
# # 95500, T 2045.8, Ltr 0.0701, Lge4 1.1266, Lge7 1.8773, Lge11 3.5754, TimeStep 044
# # 95750, T 2051.2, Ltr 0.0440, Lge4 1.6976, Lge7 2.1435, Lge11 1.9913, TimeStep 010
# # 96000, T 2056.5, Ltr 0.0937, Lge4 0.5379, Lge7 0.4956, Lge11 3.7035, TimeStep 035
# # 96250, T 2061.9, Ltr 0.0878, Lge4 1.4365, Lge7 1.4134, Lge11 6.6549, TimeStep 022
# # 96500, T 2067.2, Ltr 0.1248, Lge4 0.4842, Lge7 0.4496, Lge11 4.0278, TimeStep 034
# # 96750, T 2072.6, Ltr 0.0337, Lge4 0.4824, Lge7 0.5574, Lge11 4.4441, TimeStep 006
# # 97000, T 2078.0, Ltr 0.0926, Lge4 0.4090, Lge7 0.4942, Lge11 4.4810, TimeStep 028
# # 97250, T 2083.3, Ltr 0.1634, Lge4 0.5659, Lge7 0.6399, Lge11 4.2146, TimeStep 037
# # 97500, T 2088.7, Ltr 0.0959, Lge4 1.2763, Lge7 1.1662, Lge11 7.4915, TimeStep 035
# # 97750, T 2094.1, Ltr 0.0888, Lge4 1.5666, Lge7 1.2076, Lge11 7.3081, TimeStep 009
# # 98000, T 2099.4, Ltr 0.0952, Lge4 0.5848, Lge7 0.7340, Lge11 4.1248, TimeStep 030
# # 98250, T 2104.8, Ltr 0.0506, Lge4 2.0411, Lge7 2.1902, Lge11 2.0040, TimeStep 006
# # 98500, T 2110.1, Ltr 0.0114, Lge4 0.8731, Lge7 0.9368, Lge11 3.6265, TimeStep 004
# # 98750, T 2115.5, Ltr 0.0837, Lge4 1.9771, Lge7 2.1678, Lge11 1.9651, TimeStep 021
# # 99000, T 2120.9, Ltr 0.0742, Lge4 1.5370, Lge7 2.4024, Lge11 2.2694, TimeStep 016
# # 99250, T 2126.2, Ltr 0.0278, Lge4 0.4994, Lge7 0.5102, Lge11 4.3131, TimeStep 008
# # 99500, T 2131.6, Ltr 0.0786, Lge4 0.0399, Lge7 0.0298, Lge11 0.0424, TimeStep 018
# # 99750, T 2136.9, Ltr 0.1175, Lge4 0.6592, Lge7 0.9251, Lge11 4.2882, TimeStep 011

# %%
var = [v for v in tf.trainable_variables() if v.name == 'MLPGraphNetwork/graph_network/edge_block/mlp/linear_0/w:0']
post_train_np = sess.run(var)
print(np.array(post_train_np)-np.array(pre_train_np))
# Out:
# [[[-3.2060049e-02  4.8204444e-02  1.2157343e-02 ...  6.3494980e-02
#    -2.1122154e-02  5.2516237e-02]
#   [-1.2958027e-02  3.5169743e-02 -2.2541735e-02 ...  3.6084309e-02
#    -6.6945344e-02  2.6365668e-03]
#   [-4.8176102e-02  5.8084726e-05 -2.6163552e-02 ...  3.0164655e-02
#    -6.9408484e-02 -1.6605817e-02]
#   ...
#   [-1.2563477e-01  4.6002649e-02  4.7773868e-03 ...  7.4077822e-02
#     5.2761830e-02  5.3487077e-02]
#   [-4.3629419e-02  4.6825930e-02  1.1064841e-01 ...  7.3975854e-02
#     4.5554072e-02  5.3962298e-02]
#   [-7.9345927e-03  4.4581063e-02  1.0057620e-01 ...  7.5051963e-02
#     7.5489312e-02  5.2036945e-02]]]

# %% [markdown]
# ## Save Model

# %%
if os.path.exists(os.path.join(path_saves, "model.ckpt")):
    print("The file: "+ "model.ckpt" + "already exists. Delete it before saving a new trajectory!")
else:
    save_path = saver.save(sess, os.path.join(path_saves)+"/model.ckpt")
    print("Model saved in path: %s" % save_path)
# Out:
# Model saved in path: /home/bence/git_workspace/Dyadic_Collaboration/Graph_Networks/Phases/Phase1/One_ended_chain/damping/ntr=100000_btr=256_bge=100_date=022220_stepError_seed=5/Saves/model.ckpt

# %% [markdown]
# ## Load Model (Optional)

# %%
saver.restore(sess,os.path.join(path_saves)+"/model.ckpt")

var = [v for v in tf.trainable_variables() if v.name == 'MLPGraphNetwork/graph_network/edge_block/mlp/linear_0/w:0']
post_restore_np = sess.run(var)
print(np.array(post_restore_np))
# Out:
# INFO:tensorflow:Restoring parameters from /home/bence/git_workspace/Dyadic_Collaboration/Graph_Networks/Phases/Phase1/Two_ended_chain/Saves/ntr=3000_btr=256_bge=100date=020620/model.ckpt
# [[[-0.03615981  0.08480582  0.05031766 ...  0.00408229  0.15642138
#    -0.04161644]
#   [ 0.0719505  -0.01148265 -0.0835845  ...  0.10142673  0.12743555
#     0.00599778]
#   [-0.10257607  0.10264786  0.04341802 ...  0.06374927  0.1320276
#     0.04256159]
#   ...
#   [-0.00689922  0.05856967  0.15907852 ...  0.07085051  0.09101491
#    -0.14054282]
#   [ 0.06527713  0.02646459 -0.02397825 ... -0.0045441   0.01278247
#    -0.02234338]
#   [ 0.04215148 -0.15728731 -0.13071597 ... -0.15650336 -0.01082023
#     0.13159135]]]

# %% [markdown]
# ## Save Trajectories

# %%
#Describe the experiment


def get_node_trajectories(rollout_array, batch_size):
    return np.split(rollout_array[..., :2], batch_size, axis=1)

#Store the data
true_rollouts_4 = get_node_trajectories(test_values["true_rollout_4"],batch_size_ge)
true_trajectory_4_np = np.array(true_rollouts_4)

predicted_rollouts_4 = get_node_trajectories(test_values["predicted_rollout_4"],batch_size_ge)
predicted_trajectory_4_np=np.array(predicted_rollouts_4)

true_rollouts_7 = get_node_trajectories(test_values["true_rollout_7"],batch_size_ge)
true_trajectory_7_np = np.array(true_rollouts_7)

predicted_rollouts_7 = get_node_trajectories(test_values["predicted_rollout_7"],batch_size_ge)
predicted_trajectory_7_np=np.array(predicted_rollouts_7)

true_rollouts_11 = get_node_trajectories(test_values["true_rollout_11"],batch_size_ge)
true_trajectory_11_np = np.array(true_rollouts_11)

predicted_rollouts_11 = get_node_trajectories(test_values["predicted_rollout_11"],batch_size_ge)
predicted_trajectory_11_np=np.array(predicted_rollouts_11)


l_names = ["true_trajectory_4.npy",
           "predicted_trajectory_4.npy",
           "true_trajectory_7.npy",
           "predicted_trajectory_7.npy",
           "true_trajectory_11.npy",
           "predicted_trajectory_11.npy"]

l_data = [true_trajectory_4_np,
          predicted_trajectory_4_np,
          true_trajectory_7_np,
          predicted_trajectory_7_np,
          true_trajectory_11_np,
          predicted_trajectory_11_np]


for fname, fdata in zip(l_names,l_data):
    if os.path.exists(os.path.join(path_saves, fname)):
        print("The file: "+ fname + "already exists. Delete it before saving a new trajectory!")
    else:
        if not os.path.exists(os.path.join(path_saves)):
            os.mkdir(os.path.join(path_saves)) 
        np.save(os.path.join(path_saves, fname), fdata)

# %%
# Choose a simulated system
index_of_simulated_system = -1

spring_const = spring_constants_ge[index_of_simulated_system]
damping_ratio = damping_ratios_ge[index_of_simulated_system]

true_trajectory_4_np = true_trajectory_4_np[index_of_simulated_system]
predicted_trajectory_4_np = predicted_trajectory_4_np[index_of_simulated_system]
true_trajectory_7_np = true_trajectory_7_np[index_of_simulated_system]
predicted_trajectory_7_np = predicted_trajectory_7_np[index_of_simulated_system]
true_trajectory_11_np = true_trajectory_11_np[index_of_simulated_system]
predicted_trajectory_11_np = predicted_trajectory_11_np[index_of_simulated_system]

# %% [markdown]
# ## Plot and Save Convergence plot

# %%
fig = plt.figure(1, figsize=(16, 3))
fig.clf()
x = np.array(logged_iterations)



if os.path.exists(os.path.join(path_saves, "logged_iterations")):
    print("The file: "+ "logged_iterations" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "logged_iterations"), x)
    
if os.path.exists(os.path.join(path_saves, "logged_time_steps")):
    print("The file: "+ "logged_time_steps" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "logged_time_steps"), logged_timesteps)
        
# Next-step Loss.
y = losses_tr
ax = fig.add_subplot(1, 4, 1)
ax.plot(x, y, "k")
ax.set_title("Next step loss: Training")

if os.path.exists(os.path.join(path_saves, "losses_tr")):
    print("The file: "+ "losses_tr" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_tr"), losses_tr)


        
# Rollout 4 loss.
y = losses_4_step_ge
ax = fig.add_subplot(1, 4, 2)
ax.plot(x, y, "k")
ax.set_title("Step loss: 4-mass string")

if os.path.exists(os.path.join(path_saves, "losses_4_step_ge")):
    print("The file: "+ "losses_4_step_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_4_step_ge"), losses_4_step_ge)

if os.path.exists(os.path.join(path_saves, "losses_4_ge")):
    print("The file: "+ "losses_4_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_4_ge"), losses_4_ge)


# Rollout 7 loss.
y = losses_7_step_ge
ax = fig.add_subplot(1, 4, 3)
ax.plot(x, y, "k")
ax.set_title("Step loss: 7-mass string")

if os.path.exists(os.path.join(path_saves, "losses_7_step_ge")):
    print("The file: "+ "losses_7_step_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_7_step_ge"), losses_7_step_ge)

if os.path.exists(os.path.join(path_saves, "losses_7_ge")):
    print("The file: "+ "losses_7_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_7_ge"), losses_7_ge)

# Rollout 11 loss.
y = losses_11_step_ge
ax = fig.add_subplot(1, 4, 4)
ax.plot(x, y, "k")
ax.set_title("Step loss: 11-mass string")

if os.path.exists(os.path.join(path_saves, "losses_11_step_ge")):
    print("The file: "+ "losses_11_step_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_11_step_ge"), losses_11_step_ge)    
    
if os.path.exists(os.path.join(path_saves, "losses_11_ge")):
    print("The file: "+ "losses_11_ge" + "already exists. Delete it before saving a new trajectory!")
else:
    if not os.path.exists(os.path.join(path_saves)):
        os.makedirs(os.path.join(path_saves)) 
    np.save(os.path.join(path_saves, "losses_11_ge"), losses_11_ge)   

plt.show()
#batch_size_tr = 256
#batch_size_ge = 100
        

#Save figure
if os.path.exists(os.path.join(path_plots,"ConvergencePlot.png")):
    print("The file: "+ "ConvergencePlot.png" + "already exists. Delete it before saving a new plot!")
else:
    if not os.path.exists(os.path.join(path_plots)):
        os.mkdir(os.path.join(path_plots))
                  
    fig.savefig(os.path.join(path_plots,"ConvergencePlot.png"))
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %% [markdown]
# ## Plot and Save Trajectories Error plot

# %% [markdown]
# ### Plot generated groundtruth for 4 mass system

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 4
edges = []
time_text = ax3.text(-5, 5, "Frame: "+str(0),fontsize=12)
num_nodes = true_trajectory_4_np.shape[1]
    
def init():
    for i in range(num_nodes-1):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
                     
    return edges,time_text
    
ax3.set_xlim(-6, 6)
ax3.set_ylim(-6, 6)


def animate(z):
    true_tr = true_trajectory_4_np[z]                               
    time_text.set_text("Frame: "+str(z))
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],[true_tr[left,1],true_tr[right,1]])
    legend = ax3.legend()
    return edges, legend,time_text

ax3.set_title("Trajectory: n = 4, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_4_masses.gif")):
    print("The file: "+ "ground_truth_trajectory_4_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations, "GroundTruth")):
        os.makedirs(os.path.join(path_animations, "GroundTruth"))
                  
    anim.save(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_4_masses.gif"), writer='imagemagick', fps=20)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### Plot generated groundtruth for 7 mass system

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 7
edges = []

time_text = ax3.text(-5, 5, "Frame: "+str(0),fontsize=12)
num_nodes = true_trajectory_7_np.shape[1]

def init():
    for i in range(num_nodes-1):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
                     
    return edges,time_text
    
ax3.set_xlim(-6, 6)
ax3.set_ylim(-6, 6)


def animate(z):
    true_tr = true_trajectory_7_np[z]                                
    time_text.set_text("Frame: "+str(z))        
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],
                                           [true_tr[left,1],true_tr[right,1]])
        
                     
    legend = ax3.legend()
    return legend, edges,time_text

ax3.set_title("Trajectory: n = 7, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_7_masses.gif")):
    print("The file: "+ "ground_truth_trajectory_7_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"GroundTruth")):
        os.makedirs(os.path.join(path_animations,"GroundTruth"))
                  
    anim.save(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_7_masses.gif"), writer='imagemagick', fps=20)

                     

plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### Plot generated groundtruth for 11 mass system

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 11
edges = []

time_text = ax3.text(-8, 8, "Frame: "+str(0),fontsize=12)
num_nodes = true_trajectory_11_np.shape[1]

def init():
    for i in range(num_nodes-1):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
                     
    return edges,time_text
    
ax3.set_xlim(-9, 9)
ax3.set_ylim(-9, 9)


def animate(z):
    true_tr = true_trajectory_11_np[z]                                
    time_text.set_text("Frame: "+str(z))        
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],
                                           [true_tr[left,1],true_tr[right,1]])
        
                     
    legend = ax3.legend()
    return legend, edges,time_text

ax3.set_title("Trajectory: n = 11, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_11_masses.gif")):
    print("The file: "+ "ground_truth_trajectory_11_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"GroundTruth")):
        os.makedirs(os.path.join(path_animations,"GroundTruth"))
                  
    anim.save(os.path.join(path_animations,"GroundTruth","ground_truth_trajectory_11_masses.gif"), writer='imagemagick', fps=20)

                     

plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### 4 masses

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 4

edges = []
edges1 = []

time_text = ax3.text(-5, 5, "Frame: "+str(0),fontsize=12)
num_nodes = true_trajectory_4_np.shape[1]
    
def init():
    for i in range(num_nodes-1):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k",label="Prediction"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k"))
    return edges,edges1,time_text
    
ax3.set_xlim(-6, 6)
ax3.set_ylim(-6, 6)


def animate(z):
    
    true_tr = true_trajectory_4_np[z]
    pred_tr = predicted_trajectory_4_np[z]                              
    time_text.set_text("Frame: "+str(z))
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],[true_tr[left,1],true_tr[right,1]])
        edges1[i][0].set_data([pred_tr[left,0],pred_tr[right,0]],[pred_tr[left,1],pred_tr[right,1]])
        
    legend = ax3.legend()
    return legend,edges,edges1,time_text


ax3.set_title("Rollout Trajectory: n = 4, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"FullRollout","trajectory_4_masses.gif")):
    print("The file: "+ "trajectory_4_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"FullRollout")):
        os.mkdir(os.path.join(path_animations,"FullRollout"))
                  
    anim.save(os.path.join(path_animations,"FullRollout","trajectory_4_masses.gif"), writer='imagemagick', fps=20)

               
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### 7 masses

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 7
edges = []
edges1 = []

num_nodes = true_trajectory_7_np.shape[1]
time_text = ax3.text(-35, 35, "Frame: "+str(0),fontsize=12)
    
def init():
    for i in range(num_nodes):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k",label="Prediction"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k"))
    return edges,edges1,time_text
    
ax3.set_xlim(-40, 40)
ax3.set_ylim(-40, 40)


def animate(z):
    true_tr = true_trajectory_7_np[z]
    pred_tr = predicted_trajectory_7_np[z]                              
    time_text.set_text("Frame: "+str(z))
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],[true_tr[left,1],true_tr[right,1]])
        edges1[i][0].set_data([pred_tr[left,0],pred_tr[right,0]],[pred_tr[left,1],pred_tr[right,1]])
    legend = ax3.legend()
    return edges,edges1,legend,time_text




ax3.set_title("Rollout Trajectory: n = 7, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"FullRollout","trajectory_7_msses.gif")):
    print("The file: "+ "trajectory_7_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"FullRollout")):
        os.mkdir(os.path.join(path_animations,"FullRollout"))
                  
    anim.save(os.path.join(path_animations,"FullRollout","trajectory_7_masses.gif"), writer='imagemagick', fps=20)

    
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### 11 masses

# %%
# Visualize trajectories
plt.close('all')
fig_animate3 = plt.figure(1, figsize=(6, 6))
ax3 = fig_animate3.add_subplot(1, 1, 1)

# Visualize trajectories for number_of_masses = 11
edges = []
edges1 = []

num_nodes = true_trajectory_11_np.shape[1]
time_text = ax3.text(-35, 35, "Frame: "+str(0),fontsize=12)
    
def init():
    for i in range(num_nodes):
        if(i==0):
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r",label="Truth"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k",label="Prediction"))
        else:
            edges.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="r"))
            edges1.append(ax3.plot([],[], linestyle='-', marker='o', markersize=5, color="k"))
    return edges,edges1,time_text
    
ax3.set_xlim(-40, 40)
ax3.set_ylim(-40, 40)


def animate(z):
    true_tr = true_trajectory_11_np[z]
    pred_tr = predicted_trajectory_11_np[z]                              
    time_text.set_text("Frame: "+str(z))
    for i in range(num_nodes-1):
        left = i
        right = i+1
        
        if (right==num_nodes):
            break
                     
        edges[i][0].set_data([true_tr[left,0],true_tr[right,0]],[true_tr[left,1],true_tr[right,1]])
        edges1[i][0].set_data([pred_tr[left,0],pred_tr[right,0]],[pred_tr[left,1],pred_tr[right,1]])
    legend = ax3.legend()
    return edges,edges1,legend,time_text




ax3.set_title("Rollout Trajectory: n = 11, k = "+str(np.round(spring_const,2))+", d = "+str(np.round(damping_ratio,2)))
ax3.set_xlabel("x")
ax3.set_ylabel("y")

anim = animation.FuncAnimation(fig_animate3, animate,init_func = init, interval = step_size * 1000, frames=num_time_steps, blit=False, repeat=False)
#Save animation
if os.path.exists(os.path.join(path_animations,"FullRollout","trajectory_11_msses.gif")):
    print("The file: "+ "trajectory_11_masses.gif" + "already exists. Delete it before saving a new animation!")
else:
    if not os.path.exists(os.path.join(path_animations,"FullRollout")):
        os.mkdir(os.path.join(path_animations,"FullRollout"))
                  
    anim.save(os.path.join(path_animations,"FullRollout","trajectory_11_masses.gif"), writer='imagemagick', fps=20)

    
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/bence/miniconda3/envs/tensorEnv/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="600">
